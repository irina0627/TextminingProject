# %%
import re
from pandas import DataFrame
import numpy as np
import matplotlib.font_manager as fm
import os
import matplotlib.pyplot as plt
import pandas as pd
from konlpy.tag import Kkma
import nltk
kkma = Kkma()
from wordcloud import WordCloud
from konlpy.tag import Twitter
from collections import Counter

# %%
#csv 불러오기
df = pd.read_csv('C:/Users/User/Desktop/개발_전처리/QA(QualityAssurance).csv',encoding = 'utf-8')
df
# Out:
#                                                 주요 업무  \
# 0    신규 개발 프로젝트 기획 및 설계 신규 개발 프로젝트 개발 진행 관리 빌드 점검시...
# 1    iOS APP 서비스의 분석 및 개발 테스트 및 지속적인 최적화를 담당합니다 UX...
# 2                    광고 SDK 개발 및 유지보수 인하우스 서비스 iOS 개발
# 3    React Native 기반 앱 퍼블리싱 및 프론트엔드 작업 javascript ...
# 4    전자영수증 솔루션 고도화 빅데이터AI 연구 개발사용 기술Java Spring   ...
# ..                                                ...
# 86   OnDevice 기반 마이데이터 거래 플랫폼 및 어플리케이션 개발Android 자...
# 87   비사이드코리아의 어플리케이션 개발 및 배포 테스트 작성 및 여러 개발자들이 협업하...
# 88   신규 개발 프로젝트 기획 및 설계 신규 개발 프로젝트 개발 진행 관리 빌드 점검시...
# 89   전자영수증 솔루션 고도화 빅데이터AI 연구 개발사용 기술Java Spring   ...
# 90   Flutter 기반 네이티브 앱 개발 윈도우 어플리케이션 개발 Google Pla...
#
#                                           자격요건 및 우대사항
# 0    Cloud Server 개발 및 운영 경험 AWSEC2 Auto Scale Clo...
# 1    Swift로 개발 가능하신 분 iOS 앱 개발과 유지보수 배포 경험이 1년 이상 ...
# 2    컴퓨터공학 전산학 수학 등 직무 관련 전공자 유관 경력 3년 이상 1차 면접에서 ...
# 3    React Native 앱 개발 프로젝트 최소 3건 이상 애니메이션 적용 경험 파...
# 4    JAVA 안드로이드 IOS 앱개발 웹개발 프로토콜 설계 등 분야별 능통자 핀테크 ...
# ..                                                ...
# 86  Android 3년 이상 Android 개발 경험을 보유한 자기 주도적인 성향의 개...
# 87   컴퓨터 공학 관련 학위를 소지하거나 Flutter 개발 경험이 있으신 분 탄탄한 ...
# 88   Cloud Server 개발 및 운영 경험 AWSEC2 Auto Scale Clo...
# 89   JAVA 안드로이드 IOS 앱개발 웹개발 프로토콜 설계 등 분야별 능통자 핀테크 ...
# 90   C CPP Flutter 언어 중 최소 2개 개발 경력 5년 이상 Native 어...
#
# [91 rows x 2 columns]

# %%
#사용할 column 선택
df = df[['자격요건 및 우대사항']]
df
# Out:
#                                           자격요건 및 우대사항
# 0    Cloud Server 개발 및 운영 경험 AWSEC2 Auto Scale Clo...
# 1    Swift로 개발 가능하신 분 iOS 앱 개발과 유지보수 배포 경험이 1년 이상 ...
# 2    컴퓨터공학 전산학 수학 등 직무 관련 전공자 유관 경력 3년 이상 1차 면접에서 ...
# 3    React Native 앱 개발 프로젝트 최소 3건 이상 애니메이션 적용 경험 파...
# 4    JAVA 안드로이드 IOS 앱개발 웹개발 프로토콜 설계 등 분야별 능통자 핀테크 ...
# ..                                                ...
# 86  Android 3년 이상 Android 개발 경험을 보유한 자기 주도적인 성향의 개...
# 87   컴퓨터 공학 관련 학위를 소지하거나 Flutter 개발 경험이 있으신 분 탄탄한 ...
# 88   Cloud Server 개발 및 운영 경험 AWSEC2 Auto Scale Clo...
# 89   JAVA 안드로이드 IOS 앱개발 웹개발 프로토콜 설계 등 분야별 능통자 핀테크 ...
# 90   C CPP Flutter 언어 중 최소 2개 개발 경력 5년 이상 Native 어...
#
# [91 rows x 1 columns]

# %%
#txt로 저장
i = 'C:/Users/User/Desktop/개발_전처리/QA(QualityAssurance)(자격요건 및 우대사항).txt'
df.to_csv(i, sep = "\t", index = False, encoding='utf-8')

# %%
from konlpy.corpus import kobill
doc_ko = open(i, encoding='utf-8').read()
doc_ko
# Out:
# '자격요건 및 우대사항\n Cloud Server 개발 및 운영 경험 AWSEC2 Auto Scale Cloud front S3 등 프로젝트 PLPM 등 수행 및 업무 시스템 구축 경험 테크니컬 분석설계 역량 AndroidIOS 개발 경험 네이티브 플러터 리액트 네이티브 등 모바일 크로스 플랫폼 관련 경험 서브 능력 Python JS RDB 개발 경험 Flask Django Vuejs MariaDBMySQL 사용 혹은 관련 겅험 관련 경력자\n Swift로 개발 가능하신 분 iOS 앱 개발과 유지보수 배포 경험이 1년 이상 진행 경험 있으신 분 네이티브 지원 기능에 대한 이해가 높으신 분 개발 목표에 대한 책임감이 있으신 분 주도적으로 문제를 해결하고 책임감 있으신 분 코드 퀄리티에 지속적으로 고민하시는 분 새로운 기술에 대한 관심과 습득사용에 능동적인 분 코드리뷰 경험 있으신 분 Modular Architecture 대한 이해 MVVM 사용하여 프로젝트 진행 경험 SPM 대한 이해 CICD 경험 단위 테스트 경험 컴퓨터 공학 전공\n 컴퓨터공학 전산학 수학 등 직무 관련 전공자 유관 경력 3년 이상 1차 면접에서 포트폴리오 필수 제출 광고 솔루션 경험  초기 앱 서비스 개발 경험\n React Native 앱 개발 프로젝트 최소 3건 이상 애니메이션 적용 경험 파이어베이스 연동 경험 Android iOS 복수 개발 경험 카메라 마이크 블루투스 및 하드웨어 제어 경험\n JAVA 안드로이드 IOS 앱개발 웹개발 프로토콜 설계 등 분야별 능통자 핀테크 빅데이터AI 분야 업계 종사 경력 앱 및 웹 개발 경력\n iOS 개발경험이 4년 이상이거나 그에 준하는 실력을 보유하고 있으셔야 합니다 Swift 언어에 대한 높은 이해도를 기반으로 제품을 출시한 경험이 있으셔야 합니다 반응형 프로그래밍 eg RxSwift Combine의 경험이 필요합니다 앱 아키텍처에 대해 고민하고 적용했던 경험이 있으셔야 합니다      MVVM MVP 등의 디자인패턴을 적용해본 경험      공통적으로 쓰이는 코드를 모듈화한 경험 등 Apple Human Interface Guidelines에 대한 이해가 필요합니다 UnitTest 작성 경험이 있으셔야 합니다 다양한 CrashReporting Analytics 도구들을 이용하여 문제를 분석하고 해결할 수 있어야 합니다 Xcode에서 제공하는 View hierarchy Memory graph Debug navigator 등을 이용한 이슈 해결 경험이 있으셔야 합니다 프로젝트에서 필요한 외부 라이브러리를 적절한 요구조건에 맞게 선택하고 검증 및 적용할 수 있어야 합니다 AB 테스팅을 위한 도구사용 및 코드분기 경험이 필요합니다 접근성에 대한 이해가 있는 분을 우대합니다 CICD 설계 및 유지보수 경험이 있는 분을 우대합니다 모듈화 등을 통해 전반적인 프로젝트 관리 및 유지보수성을 높인 경험이 있으면 더욱 좋습니다 10명 이상의 엔지니어와 함께 6개월 이상의 프로젝트에 깊게 참여했던 경험을 우대합니다 Instrument 등을 사용하여 디버깅 난이도가 높은 이슈를 해결한 경험이 있으면 더욱 좋습니다 새로운 기술이나 개발 패러다임에 관심있고 꾸준히 학습하는 분이면 더욱 좋습니다 오픈소스 프로젝트에 기여한 경험을 우대합니다 내 작업물을 문서나 외부 공유용 Readme 블로그 등 으로 기록하고 업데이트 하는 습관을 가지신 분이면 더욱 좋습니다\n Android  iOS 배포 경험 및 개발유지 보수 경력 있으신 분 Android  iOS 아키텍쳐 설계 및 소프트웨어 디자인 패턴에 대한 이해도가 있으신 분 Web 개발의 경우는 Vuejs React Anglar 또는 이에 준하는 프레임워크 관련 경력이 있으신 분 코드 리뷰와 지식 공유에 적극적이신 분 문제 해결 및 코드 품질 개선에 적극적이신 분 Kotlin  Swift 개발 언어에 능숙하신 분 축구 좋아하시는 분 호날두 좋아하시는 분 호날두 싫어하시는 분 Z  D 아시는 분\n  모바일 애플리케이션 개발자로서의 입증된 경험  모바일 애플리케이션 설계 및 구축 경험자  Swift Kotlin과 같은 적어도 하나의 프로그래밍 언어로 프로그래밍 할 수 있는 기능 구현 경험자  소프트웨어 설계 및 프로그래밍 원리에 대한 탁월한 이해  의사소통 능력이 뛰어난 팀 플레이어  분석적 사고 및 문제 해결 능력  세부 정보 및 시간 관리 기술에 대한 높은 관심  컴퓨터 공학 또는 관련 분야의 BScBA MScMA우대사항  4년 이상 모바일 애플리케이션 설계 및 구축 경험자IOS  새로운 개발 언어 및 환경을 학습할 수 있는 능력과 의지가 있는자  유연한agile 개발 방식 경험자  멀티플랫폼 개발 경험자예 iOS Android  코드 리뷰 및 개선 가능자  영어 능통자 \n ObjectiveCSwift을 이용한 네이티브 앱 서비스 개발 경력자 Custom UI 및 다양한 디자인은 UIUX 개발 경험자 상용 서비스 개발 및 유지보수 경험자 RESTFUL API에 대한 기본적인 이해를 가지신 분 MVPMVVM 등 디자인 패턴에 대한 이해와 경험 AACAndroid Architecture Components를 통한 개발 경험자 Live StreamingHLS RTSP 등 Client 개발 경험자 오픈소스 분석 및 사용 경험자 메신저 앱 개발 경험자\n 클래스유의 신념 미션 비전에 공감하시는 분 Swift or Kotlin개발 경험업무경험 실제 서비스를 만들어 본 운영해 본 경험이 있으신분프로젝트 주도 경험\n iOS native 개발 경력이 2년 이상이신 분 상용 서비스 개발 및 운영 경험이 있으신 분 MVP MVVM MVC 등의 디자인 패턴을 이용한 개발 경험이 있으신 분 UIUX에 대한 이해 및 협업 경험이 있으신 분 REST API에 대한 이해가 있으신 분 모바일웹 환경을 위한 API 시스템 개발 경험 사용기술  ObjectiveC  Swift 공통 개발 환경  GitLab을 통한 코드 관리 및 코드 리뷰  Jira Confluence Figma Slack Notion 사용 Cross Platform 가능자 Reactnative 프로젝트 경험\n Android 실무 개발 및 배포 경력이 7년 이상이신 분 코드부터 테스팅까지 꼼꼼하게 잘 챙기시는 분 팀 및 개인의 성장을 위해 노력하시는 분 동료들과 함께 성장하기 위해 배운 내용을 바탕으로 공유를 잘하시는 분 Coroutine을 능숙하게 잘 사용하시는 분 MVI  클린 아키텍쳐를 적용해 보신 분 Compose를 적용해 보신 분  포트폴리오가 있으신 경우 첨부해 주세요  개인 GitHub 개발 블로그 등이 있을 경우 지원서에 URL을 명시해 주세요\n iOS 경력 1년 이상 문제를 찾고 해결하는 데 재미를 느끼시는 분 능동적으로 개발 관련 문서 탐독 및 지식 습득이 원활하신 분 성장하는 회사에서 같이 개발 문화를 만들어나가실 분 자기가 만든 앱이 사람들에게 쓰일 때 뿌듯하신 분 자기 코드를 남에게 설명하는 게 어렵지 않으신 분 git을 다룰 줄 아시는 분 iOS 앱 직접 출시 경험 음악 관련 앱 제작 경험 KPOP 팬덤 문화에 대한 이해 오픈소스 프로젝트 참여 경험 영어를 통한 개발 정보 습득이 원활하신 분 RxSwift와 같은 반응형 프로그래밍 경험 체계적으로 문서화하는 것에 즐거움을 느끼시는 분\n이런 분을 원해요 iOS 개발 경력 5년에 준하는 실력을 보유하신 분을 원해요 Clean Architecture에 대한 이해도가 높으신 분을 원해요 모듈화 및 테스터블한 개발에 익숙하신 분을 원해요 사용자 중심의 사고를 하며 제품을 개발하시는 분을 원해요 자율적이며 성장을 지향하고 커뮤니케이션이 원할하신 분을 원해요 동료와 배움을 적극적으로 나누시는 분을 원해요 멘토링 코칭이런 분이시라면 더 좋아요 SwiftUI TCA에 대한 이해도가 높으신 분이시라면 더 좋아요 프로세스 자동화에 전문성이 있으신 분이시라면 더 좋아요 글로벌 및 대규모 서비스를 개발해보신 분이시라면 더 좋아요 광고 및 인앱결제 구현 경험 및 도메인 전문성이 있으신 분이시라면 더 좋아요 수면 습관 루틴 등 개인 생산성에 관심이 높으신 분이시라면 더 좋아요\n 학력  학사 이상 ...

# %%
from konlpy.tag import Okt; t = Okt()
tokens_ko = t.nouns(doc_ko)
tokens_ko
# Out:
# ['자격',
#  '요건',
#  '및',
#  '우대',
#  '사항',
#  '개발',
#  '및',
#  '운영',
#  '경험',
#  '등',
#  '프로젝트',
#  '등',
#  '수행',
#  '및',
#  '업무',
#  '시스템',
#  '구축',
#  '경험',
#  '테크니컬',
#  '분석',
#  '설계',
#  '역량',
#  '개발',
#  '경험',
#  '네이티',
#  '브',
#  '플러터',
#  '리액트',
#  '네이티',
#  '브',
#  '등',
#  '모바일',
#  '크로스',
#  '플랫폼',
#  '관련',
#  '경험',
#  '서브',
#  '능력',
#  '개발',
#  '경험',
#  '사용',
#  '관련',
#  '겅험',
#  '관련',
#  '경력',
#  '로',
#  '개발',
#  '분',
#  '앱',
#  '개발',
#  '유지',
#  '보수',
#  '배포',
#  '경험',
#  '이상',
#  '진행',
#  '경험',
#  '분',
#  '네이티',
#  '브',
#  '지원',
#  '기능',
#  '대한',
#  '이해',
#  '분',
#  '개발',
#  '목표',
#  '대한',
#  '책임감',
#  '분',
#  '주도',
#  '문제',
#  '해결',
#  '책임감',
#  '분',
#  '코드',
#  '퀄리티',
#  '지속',
#  '고민',
#  '분',
#  '기술',
#  '대한',
#  '관심',
#  '습득',
#  '사용',
#  '능동',
#  '분',
#  '코드',
#  '리뷰',
#  '경험',
#  '분',
#  '대한',
#  '이해',
#  '사용',
#  '프로젝트',
#  '진행',
#  '경험',
#  '대한',
#  '이해',
#  '경험',
#  '단위',
#  '테스트',
#  '경험',
#  '컴퓨터',
#  '공학',
#  '전공',
#  '컴퓨터공학',
#  '전산학',
#  '수학',
#  '등',
#  '직무',
#  '관련',
#  '전공자',
#  '유관',
#  '경력',
#  '이상',
#  '차',
#  '면접',
#  '포트폴리오',
#  '필수',
#  '제출',
#  '광고',
#  '솔루션',
#  '경험',
#  '초기',
#  '앱',
#  '서비스',
#  '개발',
#  '경험',
#  '앱',
#  '개발',
#  '프로젝트',
#  '최소',
#  '건',
#  '이상',
#  '애니메이션',
#  '적용',
#  '경험',
#  '파이어',
#  '베이스',
#  '연동',
#  '경험',
#  '복수',
#  '개발',
#  '경험',
#  '카메라',
#  '마이크',
#  '블루투스',
#  '및',
#  '하드웨어',
#  '제어',
#  '경험',
#  '안드로이드',
#  '앱',
#  '개발',
#  '웹',
#  '개발',
#  '프로토콜',
#  '설계',
#  '등',
#  '분야',
#  '별',
#  '능통',
#  '핀',
#  '테크',
#  '빅데이터',
#  '분야',
#  '업계',
#  '종사',
#  '경력',
#  '앱',
#  '및',
#  '웹',
#  '개발',
#  '경력',
#  '개발',
#  '경험',
#  '이상',
#  '거나',
#  '그',
#  '준',
#  '실력',
#  '보유',
#  '언어',
#  '대한',
#  '이해도',
#  '기반',
#  '제품',
#  '출시',
#  '경험',
#  '반응',
#  '프로그래밍',
#  '의',
#  '경험',
#  '앱',
#  '아키텍처',
#  '대해',
#  '고민',
#  '적용',
#  '경험',
#  '등',
#  '디자인',
#  '패턴',
#  '적용',
#  '경험',
#  '공통',
#  '코드',
#  '모듈',
#  '경험',
#  '등',
#  '대한',
#  '이해',
#  '작성',
#  '경험',
#  '도구',
#  '이용',
#  '문제',
#  '분석',
#  '해결',
#  '수',
#  '제공',
#  '등',
#  '이용',
#  '이슈',
#  '해결',
#  '경험',
#  '프로젝트',
#  '외부',
#  '라이브러리',
#  '조건',
#  '선택',
#  '검증',
#  '및',
#  '적용',
#  '수',
#  '테',
#  '스팅',
#  '위',
#  '도구',
#  '사용',
#  '및',
#  '코드',
#  '분기',
#  '경험',
#  '접근성',
#  '대한',
#  '이해',
#  '분',
#  '우대',
#  '설계',
#  '및',
#  '유지',
#  '보수',
#  '경험',
#  '분',
#  '우대',
#  '모듈',
#  '등',
#  '통해',
#  '전반',
#  '프로젝트',
#  '관리',
#  '및',
#  '유지',
#  '보수',
#  '경험',
#  '더욱',
#  '명',
#  '이상',
#  '엔지니어',
#  '개월',
#  '이상',
#  '프로젝트',
#  '참여',
#  '경험',
#  '우대',
#  '등',
#  '사용',
#  '디버깅',
#  '난이도',
#  '이슈',
#  '해결',
#  '경험',
#  '더욱',
#  '기술',
#  '개발',
#  '패러다임',
#  '관심',
#  '학습',
#  '더욱',
#  '오픈소스',
#  '프로젝트',
#  '기여',
#  '경험',
#  '우대',
#  '내',
#  '작업',
#  '물',
#  '문서',
#  '외부',
#  '유용',
#  '블로그',
#  '등',
#  '기록',
#  '업데이트',
#  '습관',
#  '더욱',
#  '배포',
#  '경험',
#  '및',
#  '개발',
#  '유지',
#  '보수',
#  '경력',
#  '분',
#  '아키텍쳐',
#  '설계',
#  '및',
#  '소프트웨어',
#  '디자인',
#  '패턴',
#  '대한',
#  '이해도',
#  '분',
#  '개발',
#  '경우',
#  '이',
#  '준',
#  '프레임워크',
#  '관련',
#  '경력',
#  '분',
#  '코드',
#  '리뷰',
#  '지식',
#  '공유',
#  '적극',
#  '분',
#  '문제',
#  '해결',
#  '및',
#  '코드',
#  '품질',
#  '개선',
#  '적극',
#  '분',
#  '개발',
#  '언어',
#  '분',
#  '축구',
#  '분',
#  '호날두',
#  '분',
#  '호날두',
#  '분',
#  '아시',
#  '분',
#  '모바일',
#  '애플리케이션',
#  '개발자',
#  '로서',
#  '입증',
#  '경험',
#  '모바일',
#  '애플리케이션',
#  '설계',
#  '및',
#  '구축',
#  '경험',
#  '과',
#  '하나',
#  '프로그래밍',
#  '언어',
#  '프로그래밍',
#  '수',
#  '기능',
#  '구현',
#  '경험',
#  '소프트웨어',
#  '설계',
#  '및',
#  '프로그래밍',
#  '원리',
#  '대한',
#  '이해',
#  '의사소통',
#  '능력',
#  '팀',
#  '플레이어',
#  '분석',
#  '사고',
#  '및',
#  '문제',
#  '해결',
#  '능력',
#  '세부',
#  '정보',
#  '및',
#  '시간',
#  '관리',
#  '기술',
#  '대한',
#  '관심',
#  '컴퓨터',
#  '공학',
#  '관련',
#  '분야',
#  '우대',
#  '사항',
#  '이상',
#  '모바일',
#  '애플리케이션',
#  '설계',
#  '및',
#  '구축',
#  '경험',
#  '개발',
#  '언어',
#  '및',
#  '환경',
#  '학습',
#  '수',
#  '능력',
#  '의지',
#  '개발',
#  '방식',
#  '경험',
#  '멀티플랫폼',
#  '개발',
#  '경험',
#  '예',
#  '코드',
#  '리뷰',
#  '및',
#  '개선',
#  '가능',
#  '영어',
#  '능통',
#  '이용',
#  '네이티',
#  '브',
#  '앱',
#  '서비스',
#  '개발',
#  '경력',
#  '및',
#  '디자인',
#  '개발',
#  '경험',
#  '상용',
#  '서비스',
#  '개발',
#  '및',
#  '유지',
#  '보수',
#  '경험',
#  '대한',
#  '기본',
#  '이해',
#  '분',
#  '등',
#  '디자인',
#  '패턴',
#  '대한',
#  '이해',
#  '경험',
#  '를',
#  '통한',
#  '개발',
#  '경험',
#  '등',
#  '개발',
#  '경험',
#  '오픈소스',
#  '분석',
#  '및',
#  '사용',
#  '경험',
#  '메신저',
#  '앱',
#  '개발',
#  '경험',
#  '클래스',
#  '유의',
#  '신념',
#  '미션',
#  '공감',
#  '분',
#  '개발',
#  '경험',
#  '업무',
#  '경험',
#  '실제',
#  '서비스',
#  '운영',
#  '경험',
#  '신분',
#  '프로젝트',
#  '주도',
#  '경험',
#  '개발',
#  '경력',
#  '이상',
#  '분',
#  '상용',
#  '서비스',
#  '개발',
#  '및',
#  '운영',
#  '경험',
#  '분',
#  '등',
#  '디자인',
#  '패턴',
#  '이용',
#  '개발',
#  '경험',
#  '분',
#  '대한',
#  '이해',
#  '및',
#  '협업',
#  '경험',
#  '분',
#  '대한',
#  '이해',
#  '분',
#  '모바일',
#  '웹',
#  '환경',
#  '위',
#  '시스템',
#  '개발',
#  '경험',
#  '사용',
#  '기술',
#  '공통',
#  '개발',
#  '환경',
#  '통한',
#  '코드',
#  '관리',
#  '및',
#  '코드',
#  '리뷰',
#  '사용',
#  '가능',
#  '프로젝트',
#  '경험',
#  '실무',
#  '개발',
#  '및',
#  '배포',
#  '경력',
#  '이상',
#  '분',
#  '코드',
#  '테',
#  '스팅',
#  '분',
#  '팀',
#  '및',
#  '개인',
#  '성장',
#  '위해',
#  '노력',
#  '분',
#  '동료',
#  '위해',
#  '내용',
#  '바탕',
#  '공유',
#  '분',
#  '사용',
#  '분',
#  '클린',
#  '아키텍쳐',
#  '적용',
#  '보신',
#  '분',
#  '를',
#  '적용',
#  '보신',
#  '분',
#  '포트폴리오',
#  '경우',
#  '첨부',
#  '개인',
#  '개발',
#  '블로그',
#  '등',
#  '경우',
#  '원서',
#  '명시',
#  '경력',
#  '이상',
#  '문제',
#  '해결',
#  '데',
#  '재미',
#  '분',
#  '능동',
#  '개발',
#  '관련',
#  '문서',
#  '탐독',
#  '및',
#  '지식',
#  '습득',
#  '분',
#  '회사',
#  '개발',
#  '문화',
#  '분',
#  '자기',
#  '앱',
#  '사람',
#  '때',
#  '분',
#  '자기',
#  '코드',
#  '남',
#  '설명',
#  '게',
#  '분',
#  '줄',
#  '아시',
#  '분',
#  '앱',
#  '직접',
#  '출시',
#  '경험',
#  '음악',
#  '관련',
#  '앱',
#  '제작',
#  '경험',
#  '팬덤',
#  '문화',
#  '대한',
#  '이해',
#  '오픈소스',
#  '프로젝트',
#  '참여',
#  '경험',
#  '영어',
#  '통한',
#  '개발',
#  '정보',
#  '습득',
#  '분',
#  '반응',
#  '프로그래밍',
#  '경험',
#  '체계',
#  '문서',
#  '것',
#  '즐거움',
#  '분',
#  '분',
#  '개발',
#  '경력',
#  '준',
#  '실력',
#  '보유',
#  '분',
#  '대한',
#  '이해도',
#  '분',
#  '모듈',
#  '및',
#  '테스터블',
#  '개발',
#  '분',
#  '사용자',
#  '중심',
#  '사고',
#  '제품',
#  '개발',
#  '분',
#  '자율',
#  '성장',
#  '지향',
#  '커뮤니케이션',
#  '분',
#  '동료',
#  '배움',
#  '적극',
#  '분',
#  '멘토링',
#  '코칭',
#  '더',
#  '대한',
#  '이해도',
#  '더',
#  '프로세스',
#  '자동화',
#  '전문성',
#  '더',
#  '글로벌',
#  '및',
#  '대규모',
#  '서비스',
#  '개발',
#  '더',
#  '광고',
#  '및',
#  '인앱',
#  '결제',
#  '구현',
#  '경험',
#  '및',
#  '도메인',
#  '전문성',
#  '더',
#  '수면',
#  '습관',
#  '루틴',
#  '등',
#  '개인',
#  '생산',
#  '관심',
#  '더',
#  '학력',
#  '학사',
#  '이상',
#  '컴퓨터',
#  '전자전',
#  '의공학',
#  '경력',
#  '이상',
#  '의료기기',
#  '개발',
#  '경험',
#  '개발',
#  '개발',
#  '경험',
#  '스킬',
#  '초음파',
#  '의료기기',
#  '작업',
#  '경험',
#  '경험',
#  '이상',
#  '개발',
#  '경력',
#  '그',
#  '준',
#  '경험',
#  '및',
#  '대한',
#  '기본',
#  '이해',
#  '분',
#  '및',
#  '활용',
#  '구성',
#  '분',
#  '코드',
#  '기반',
#  '통한',
#  '구성',
#  '분',
#  '비',
#  '동기',
#  '네트워크',
#  '처리',
#  '대한',
#  '기본',
#  '이해',
#  '분',
#  '디자인',
#  '패턴',
#  '대한',
#  '이해',
#  '분',
#  '사용',
#  '경험',
#  '및',
#  '이',
#  '대한',
#  '기본',
#  '이해',
#  '분',
#  '우대',
#  '를',
#  '활용',
#  '배포',
#  '자동화',
#  '경험',
#  '분',
#  '우대',
#  '등',
#  '아키텍쳐',
#  '대한',
#  '관심',
#  '및',
#  '이해',
#  '분',
#  '우대',
#  '사용',
#  '경험',
#  '분',
#  '우대',
#  '사용',
#  '경험',
#  '분',
#  '우대',
#  '사용',
#  '경험',
#  '분',
#  '어플리케이션',
#  '개발',
#  '경험',
#  '최소',
#  '이상',
#  '그',
#  '준',
#  '역량',
#  '보유',
#  '분',
#  '개발',
#  '경험',
#  '분',
#  '코드',
#  '품질',
#  '향상',
#  '관심',
#  '분',
#  '테스트',
#  '및',
#  '자동화',
#  '관심',
#  '분',
#  '기술',
#  '데',
#  '함',
#  '프로그래밍',
#  '분',
#  '프로젝트',
#  '대한',
#  '십',
#  '가지',
#  '주도',
#  '일',
#  '분',
#  '개인',
#  '애플리케이션',
#  '개발',
#  '경험',
#  '분',
#  '기획',
#  '디자인',
#  '서버',
#  '직',
#  '소통',
#  '및',
#  '협업',
#  '경험',
#  '분',
#  '오픈소스',
#  '기술',
#  '블로그',
#  '활동',
#  '경험',
#  '분',
#  '개발',
#  '경험',
#  '를',
#  '사용',
#  '구성',
#  '경험',
#  '구성',
#  '경험',
#  '테스트',
#  '작성',
#  '경험',
#  '를',
#  '통한',
#  '소프트웨어',
#  '프로세스',
#  '관리',
#  '경험',
#  '자료구조',
#  '알고리즘',
#  '디자인',
#  '패턴',
#  '대한',
#  '이해도',
#  '분',
#  '이상',
#  '개발',
#  '경험',
#  '구현',
#  '경험',
#  '태블릿',
#  '용',
#  '앱',
#  '개발',
#  '경험',
#  '기반',
#  '개발',
#  '경험',
#  '기반',
#  '동영상',
#  '스트리밍',
#  '서비스',
#  '개발',
#  '경험',
#  '대한',
#  '이해도',
#  '분',
#  '개발',
#  '경험',
#  '스크럼',
#  '칸반',
#  '기반',
#  '애자',
#  '일',
#  '개발',
#  '프로세스',
#  '참여',
#  '경험',
#  '개발',
#  '팀',
#  '리드',
#  '경험',
#  '모바일',
#  '파트',
#  '리더',
#  '커리어',
#  '확장',
#  '분',
#  '안드로이드',
#  '소프트웨어',
#  '개발',
#  '관련',
#  '이상',
#  '업무',
#  '경력',
#  '보유',
#  '분',
#  '가지',
#  '언어',
#  '이상',
#  '사용',
#  '경험',
#  '분',
#  '클라우드',
#  '사용',
#  '경험',
#  '분',
#  '운영',
#  '체제',
#  '소프트웨어',
#  '디자인',
#  '패턴',
#  '고가용성',
#  '및',
#  '확장',
#  '대한',
#  '이해도',
#  '분',
#  '링크',
#  '제출',
#  '이상',
#  '풀',
#  '사이클',
#  '제품',
#  '개발',
#  '업무',
#  '경험',
#  '보유',
#  '분',
#  '코드',
#  '리뷰',
#  '소스',
#  '코드',
#  '베이스',
#  '관리',
#  '빌드',
#  '프로세스',
#  '테스트',
#  '및',
#  '배포',
#  '소프트웨어',
#  '프로덕션',
#  '운영',
#  '조직',
#  '리드',
#  '안드로이드',
#  '기반',
#  '영상',
#  '처리',
#  '경험',
#  '분',
#  '개발',
#  '및',
#  '운영',
#  '발생',
#  ...]

# %%
ko = nltk.Text(tokens_ko, name = 'work')
print(len(ko.tokens))
print(len(set(ko.tokens)))
ko.vocab()
# Out:
# 4617
# 595
# FreqDist({'경험': 406, '분': 402, '개발': 295, '및': 148, '대한': 120, '이상': 78, '등': 77, '사용': 70, '경력': 68, '이해': 66, ...})

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:\Windows\Fonts\malgun.ttf").get_name()
rc('font', family=font_name)

# %%
stop_words = [
    '개발','사용','이해','기반','필수','가능','우대','경험','관심','활용','관련','능력','이해도','대한','보유','이상','실행','디지털','제안','플루','인','제작','수립','신규','업무','사','경력','분','및','해결', '일', '등', '직', '더', '위', '수', '팀', '자사', '마','피', '내']

ko = [each_word for each_word in ko if each_word not in stop_words]
ko
# Out:
# ['자격',
#  '요건',
#  '사항',
#  '운영',
#  '프로젝트',
#  '수행',
#  '시스템',
#  '구축',
#  '테크니컬',
#  '분석',
#  '설계',
#  '역량',
#  '네이티',
#  '브',
#  '플러터',
#  '리액트',
#  '네이티',
#  '브',
#  '모바일',
#  '크로스',
#  '플랫폼',
#  '서브',
#  '겅험',
#  '로',
#  '앱',
#  '유지',
#  '보수',
#  '배포',
#  '진행',
#  '네이티',
#  '브',
#  '지원',
#  '기능',
#  '목표',
#  '책임감',
#  '주도',
#  '문제',
#  '책임감',
#  '코드',
#  '퀄리티',
#  '지속',
#  '고민',
#  '기술',
#  '습득',
#  '능동',
#  '코드',
#  '리뷰',
#  '프로젝트',
#  '진행',
#  '단위',
#  '테스트',
#  '컴퓨터',
#  '공학',
#  '전공',
#  '컴퓨터공학',
#  '전산학',
#  '수학',
#  '직무',
#  '전공자',
#  '유관',
#  '차',
#  '면접',
#  '포트폴리오',
#  '제출',
#  '광고',
#  '솔루션',
#  '초기',
#  '앱',
#  '서비스',
#  '앱',
#  '프로젝트',
#  '최소',
#  '건',
#  '애니메이션',
#  '적용',
#  '파이어',
#  '베이스',
#  '연동',
#  '복수',
#  '카메라',
#  '마이크',
#  '블루투스',
#  '하드웨어',
#  '제어',
#  '안드로이드',
#  '앱',
#  '웹',
#  '프로토콜',
#  '설계',
#  '분야',
#  '별',
#  '능통',
#  '핀',
#  '테크',
#  '빅데이터',
#  '분야',
#  '업계',
#  '종사',
#  '앱',
#  '웹',
#  '거나',
#  '그',
#  '준',
#  '실력',
#  '언어',
#  '제품',
#  '출시',
#  '반응',
#  '프로그래밍',
#  '의',
#  '앱',
#  '아키텍처',
#  '대해',
#  '고민',
#  '적용',
#  '디자인',
#  '패턴',
#  '적용',
#  '공통',
#  '코드',
#  '모듈',
#  '작성',
#  '도구',
#  '이용',
#  '문제',
#  '분석',
#  '제공',
#  '이용',
#  '이슈',
#  '프로젝트',
#  '외부',
#  '라이브러리',
#  '조건',
#  '선택',
#  '검증',
#  '적용',
#  '테',
#  '스팅',
#  '도구',
#  '코드',
#  '분기',
#  '접근성',
#  '설계',
#  '유지',
#  '보수',
#  '모듈',
#  '통해',
#  '전반',
#  '프로젝트',
#  '관리',
#  '유지',
#  '보수',
#  '더욱',
#  '명',
#  '엔지니어',
#  '개월',
#  '프로젝트',
#  '참여',
#  '디버깅',
#  '난이도',
#  '이슈',
#  '더욱',
#  '기술',
#  '패러다임',
#  '학습',
#  '더욱',
#  '오픈소스',
#  '프로젝트',
#  '기여',
#  '작업',
#  '물',
#  '문서',
#  '외부',
#  '유용',
#  '블로그',
#  '기록',
#  '업데이트',
#  '습관',
#  '더욱',
#  '배포',
#  '유지',
#  '보수',
#  '아키텍쳐',
#  '설계',
#  '소프트웨어',
#  '디자인',
#  '패턴',
#  '경우',
#  '이',
#  '준',
#  '프레임워크',
#  '코드',
#  '리뷰',
#  '지식',
#  '공유',
#  '적극',
#  '문제',
#  '코드',
#  '품질',
#  '개선',
#  '적극',
#  '언어',
#  '축구',
#  '호날두',
#  '호날두',
#  '아시',
#  '모바일',
#  '애플리케이션',
#  '개발자',
#  '로서',
#  '입증',
#  '모바일',
#  '애플리케이션',
#  '설계',
#  '구축',
#  '과',
#  '하나',
#  '프로그래밍',
#  '언어',
#  '프로그래밍',
#  '기능',
#  '구현',
#  '소프트웨어',
#  '설계',
#  '프로그래밍',
#  '원리',
#  '의사소통',
#  '플레이어',
#  '분석',
#  '사고',
#  '문제',
#  '세부',
#  '정보',
#  '시간',
#  '관리',
#  '기술',
#  '컴퓨터',
#  '공학',
#  '분야',
#  '사항',
#  '모바일',
#  '애플리케이션',
#  '설계',
#  '구축',
#  '언어',
#  '환경',
#  '학습',
#  '의지',
#  '방식',
#  '멀티플랫폼',
#  '예',
#  '코드',
#  '리뷰',
#  '개선',
#  '영어',
#  '능통',
#  '이용',
#  '네이티',
#  '브',
#  '앱',
#  '서비스',
#  '디자인',
#  '상용',
#  '서비스',
#  '유지',
#  '보수',
#  '기본',
#  '디자인',
#  '패턴',
#  '를',
#  '통한',
#  '오픈소스',
#  '분석',
#  '메신저',
#  '앱',
#  '클래스',
#  '유의',
#  '신념',
#  '미션',
#  '공감',
#  '실제',
#  '서비스',
#  '운영',
#  '신분',
#  '프로젝트',
#  '주도',
#  '상용',
#  '서비스',
#  '운영',
#  '디자인',
#  '패턴',
#  '이용',
#  '협업',
#  '모바일',
#  '웹',
#  '환경',
#  '시스템',
#  '기술',
#  '공통',
#  '환경',
#  '통한',
#  '코드',
#  '관리',
#  '코드',
#  '리뷰',
#  '프로젝트',
#  '실무',
#  '배포',
#  '코드',
#  '테',
#  '스팅',
#  '개인',
#  '성장',
#  '위해',
#  '노력',
#  '동료',
#  '위해',
#  '내용',
#  '바탕',
#  '공유',
#  '클린',
#  '아키텍쳐',
#  '적용',
#  '보신',
#  '를',
#  '적용',
#  '보신',
#  '포트폴리오',
#  '경우',
#  '첨부',
#  '개인',
#  '블로그',
#  '경우',
#  '원서',
#  '명시',
#  '문제',
#  '데',
#  '재미',
#  '능동',
#  '문서',
#  '탐독',
#  '지식',
#  '습득',
#  '회사',
#  '문화',
#  '자기',
#  '앱',
#  '사람',
#  '때',
#  '자기',
#  '코드',
#  '남',
#  '설명',
#  '게',
#  '줄',
#  '아시',
#  '앱',
#  '직접',
#  '출시',
#  '음악',
#  '앱',
#  '팬덤',
#  '문화',
#  '오픈소스',
#  '프로젝트',
#  '참여',
#  '영어',
#  '통한',
#  '정보',
#  '습득',
#  '반응',
#  '프로그래밍',
#  '체계',
#  '문서',
#  '것',
#  '즐거움',
#  '준',
#  '실력',
#  '모듈',
#  '테스터블',
#  '사용자',
#  '중심',
#  '사고',
#  '제품',
#  '자율',
#  '성장',
#  '지향',
#  '커뮤니케이션',
#  '동료',
#  '배움',
#  '적극',
#  '멘토링',
#  '코칭',
#  '프로세스',
#  '자동화',
#  '전문성',
#  '글로벌',
#  '대규모',
#  '서비스',
#  '광고',
#  '인앱',
#  '결제',
#  '구현',
#  '도메인',
#  '전문성',
#  '수면',
#  '습관',
#  '루틴',
#  '개인',
#  '생산',
#  '학력',
#  '학사',
#  '컴퓨터',
#  '전자전',
#  '의공학',
#  '의료기기',
#  '스킬',
#  '초음파',
#  '의료기기',
#  '작업',
#  '그',
#  '준',
#  '기본',
#  '구성',
#  '코드',
#  '통한',
#  '구성',
#  '비',
#  '동기',
#  '네트워크',
#  '처리',
#  '기본',
#  '디자인',
#  '패턴',
#  '이',
#  '기본',
#  '를',
#  '배포',
#  '자동화',
#  '아키텍쳐',
#  '어플리케이션',
#  '최소',
#  '그',
#  '준',
#  '역량',
#  '코드',
#  '품질',
#  '향상',
#  '테스트',
#  '자동화',
#  '기술',
#  '데',
#  '함',
#  '프로그래밍',
#  '프로젝트',
#  '십',
#  '가지',
#  '주도',
#  '개인',
#  '애플리케이션',
#  '기획',
#  '디자인',
#  '서버',
#  '소통',
#  '협업',
#  '오픈소스',
#  '기술',
#  '블로그',
#  '활동',
#  '를',
#  '구성',
#  '구성',
#  '테스트',
#  '작성',
#  '를',
#  '통한',
#  '소프트웨어',
#  '프로세스',
#  '관리',
#  '자료구조',
#  '알고리즘',
#  '디자인',
#  '패턴',
#  '구현',
#  '태블릿',
#  '용',
#  '앱',
#  '동영상',
#  '스트리밍',
#  '서비스',
#  '스크럼',
#  '칸반',
#  '애자',
#  '프로세스',
#  '참여',
#  '리드',
#  '모바일',
#  '파트',
#  '리더',
#  '커리어',
#  '확장',
#  '안드로이드',
#  '소프트웨어',
#  '가지',
#  '언어',
#  '클라우드',
#  '운영',
#  '체제',
#  '소프트웨어',
#  '디자인',
#  '패턴',
#  '고가용성',
#  '확장',
#  '링크',
#  '제출',
#  '풀',
#  '사이클',
#  '제품',
#  '코드',
#  '리뷰',
#  '소스',
#  '코드',
#  '베이스',
#  '관리',
#  '빌드',
#  '프로세스',
#  '테스트',
#  '배포',
#  '소프트웨어',
#  '프로덕션',
#  '운영',
#  '조직',
#  '리드',
#  '안드로이드',
#  '영상',
#  '처리',
#  '운영',
#  '발생',
#  '장',
#  '단기',
#  '문제',
#  '스텀',
#  '하드웨어',
#  '버전',
#  '안드로이드',
#  '광고',
#  '산업',
#  '컴퓨터',
#  '공학',
#  '전공',
#  '그',
#  '준',
#  '를',
#  '웹앱',
#  '비즈니스',
#  '요구사항',
#  '로직',
#  '설계',
#  '구현',
#  '운영',
#  '프로',
#  '페셔널',
#  '코딩',
#  '스타트업',
#  '이',
#  '환경',
#  '성과',
#  '정의',
#  '의도',
#  '대로',
#  '동작',
#  '변경',
#  '내용',
#  '스스로',
#  '검증',
#  '발견',
#  '문제',
#  '스스로',
#  '문제',
#  '파악',
#  '근본',
#  '문제',
#  '방법',
#  '제시',
#  '구현',
#  '안드로이드',
#  '가지',
#  '비',
#  '동기',
#  '프로그래밍',
#  '버전',
#  '관리',
#  '도구',
#  '디자인',
#  '패턴',
#  '리팩토링',
#  '기본',
#  '지식',
#  '가지',
#  '매버릭스',
#  '작성',
#  '앱',
#  '최적화',
#  '아키텍처',
#  '설계',
#  '코드',
#  '리팩토링',
#  '자기',
#  '주도',
#  '것',
#  '동료',
#  '수평',
#  '커뮤니케이션',
#  '환경',
#  '나은',
#  '문화',
#  '데',
#  '기여',
#  '애정',
#  '열정',
#  '완성',
#  '서비스',
#  '제공',
#  '안드로이드',
#  '기술',
#  '주요',
#  '기술',
#  '협업',
#  '도구',
#  '그',
#  '준',
#  '역량',
#  '플랫폼',
#  '커뮤니케이션',
#  '협업',
#  '디자인',
#  '패턴',
#  '적용',
#  '성능',
#  '최적화',
#  '분앱',
#  '스토어',
#  '런칭',
#  '서비스',
#  '운영',
#  '적극',
#  '코드',
#  '리뷰',
#  '통한',
#  '협업',
#  '코드',
#  '개선',
#  '포트폴리오',
#  '첨부',
#  '본인',
#  '가치',
#  '리눅스',
#  '유닉스',
#  '언어',
#  '프로그램',
#  '용량',
#  '데이터',
#  '분석',
#  '처리',
#  '금융',
#  '뱅킹',
#  '증권',
#  '서버',
#  '서비스',
#  '아키',
#  '택쳐',
#  '프레임워크',
#  '라이브러리',
#  '욕심',
#  '방법론',
#  '코드',
#  '개선',
#  '어플리케이션',
#  '구조',
#  '설계',
#  '코드',
#  '리뷰',
#  '품질',
#  '향상',
#  '활동',
#  '적극',
#  '협업',
#  '커뮤니케이션',
#  '문화',
#  '만들기',
#  '의',
#  '가이드라인',
#  '디자인',
#  '패턴',
#  '대중',
#  '라이브러리',
#  '주요',
#  '기술',
#  '역량',
#  '서비스',
#  '오픈소스',
#  '기술',
#  '학습',
#  '스토어',
#  '앱',
#  '배포',
#  '운영',
#  '디버깅',
#  '지식',
#  '도구',
#  '즉시',
#  '출근',
#  '영어',
#  '일본어',
#  '안드로이드',
#  '안드로이드',
#  '기술',
#  '안드로이드',
#  '프로세스',
#  '문제',
#  '분석',
#  '능동',
#  '책임감',
#  '자세',
#  '커뮤니케이션',
#  '협업',
#  '오픈',
#  '소스',
#  '프로젝트',
#  '참여',
#  '네이티',
#  '브',
#  '앱',
#  '네이티',
#  '브',
#  '앱',
#  '프로젝트',
#  '시작',
#  '배포',
#  '싸이클',
#  '신',
#  '최신',
#  '트렌드',
#  '이용',
#  '문제',
#  '때',
#  '발',
#  '대처',
#  '디버깅',
#  '스킬',
#  '분업',
#  '협력',
#  '통한',
#  '팀워크',
#  '커뮤니케이션',
#  '최신',
#  '기술',
#  '지속',
#  '형상관리',
#  '도구',
#  '아키텍쳐',
#  '코드',
#  '패턴',
#  '코드',
#  '베이스',
#  '작성',
#  '코드',
#  '개선',
#  '코드',
#  '리뷰',
#  '유닛',
#  '테스트',
#  '테스트',
#  '작성',
#  '슬랙',
#  '이슈',
#  '관리',
#  '도구',
#  '서비스',
#  '출시',
#  '연동',
#  '협업',
#  '커뮤니케이션',
#  '언어',
#  '아키텍쳐',
#  '앱',
#  '성능',
#  '최적화',
#  '신분',
#  '대해',
#  '미만',
#  '패턴',
#  '네트워크',
#  '모듈',
#  '스레드',
#  '비',
#  '동기',
#  '입출력',
#  '플랫폼',
#  '커뮤니케이션',
#  '능동',
#  '협업',
#  '자세',
#  '코드',
#  '리뷰',
#  '문화',
#  '긍정',
#  '태도',
#  '증권사',
#  '연동',
#  '분석',
#  '자료',
#  '구조',
#  '알고리즘',
#  '실무',
#  '적용',
#  '앱',
#  '프로파일링',
#  '최적화',
#  '적용',
#  '의',
#  '방식',
#  '서비스',
#  '유지',
#  '보수',
#  '로',
#  '제품',
#  '출시',
#  '기본',
#  '기능',
#  '요구사항',
#  '설계',
#  '구현',
#  '테스트',
#  '확장',
#  '지향',
#  '리팩토링',
#  '버전',
#  '관리',
#  '체계',
#  '코드',
#  '관리',
#  '환경',
#  '라이브러리',
#  '지식',
#  '습득',
#  '기본',
#  '영어',
#  '쓰기',
#  '회화',
#  '해외여행',
#  '결격',
#  '사유',
#  '서비스',
#  '그',
#  '준',
#  '앱',
#  '테스트',
#  '배포',
#  '자동화',
#  '다른',
#  '개발자',
#  '협업',
#  '프로세스',
#  '구축',
#  '오픈소스',
#  '참여',
#  '앱',
#  '배포',
#  '앱',
#  '배포',
#  '앱스토어',
#  '인하',
#  '우스',
#  '커뮤니케이션',
#  '역량',
#  '자',
#  '연동',
#  '연동',
#  '동작',
#  '사용자',
#  '정보',
#  '수집',
#  '포괄',
#  '서비스',
#  '구조',
#  '대해',
#  '분앱',
#  '기획',
#  '디자인',
#  '커뮤니케이션',
#  '사용자',
#  '중심',
#  '제품',
#  '최적화',
#  '분가',
#  '앞서서',
#  '것',
#  '에너지',
#  '소비',
#  '일이',
#  '우리',
#  '것',
#  '시도',
#  '남',
#  '못',
#  '길',
#  '개척',
#  '즐거움',
#  '사람',
#  '요',
#  '퀄',
#  '정답',
#  '과제',
#  '도전',
#  '것',
#  '가치',
#  '사람',
#  '곳',
#  '만약',
#  '아래',
#  '가치',
#  '부합',
#  '생각',
#  '우리',
#  '가치',
#  '세상',
#  '제공',
#  '것',
#  '흥미',
#  '반드시',
#  '목표',
#  '존재',
#  '위해',
#  '이',
#  '본인',
#  '것',
#  '항상',
#  '인지',
#  '자세',
#  '소통',
#  '협력',
#  '사람',
#  '개인',
#  '성장',
#  '추구',
#  '고객',
#  '가치',
#  '대해',
#  '고민',
#  '존중',
#  '행동',
#  '커뮤니케이션',
#  '분자',
#  '율과',
#  '책임',
#  '분할',
#  '줄',
#  '의',
#  '관점',
#  '생각',
#  '행동',
#  '언어',
#  '중',
#  '최소',
#  '개',
#  '어플리케이션',
#  '데이터',
#  '통신',
#  '분산',
#  '버전',
#  '관리',
#  '환경',
#  '키',
#  '오스',
#  '분야',
#  '통신',
#  '장치',
#  '제어',
#  '어플리케이션',
#  '스타트업',
#  '진취',
#  '열정',
#  '사람',
#  '데이터',
#  '통신',
#  '프로토콜',
#  '사람',
#  '그',
#  '준',
#  '실력',
#  '플랫폼',
#  '언어',
#  '실제',
#  '운영',
#  '앱',
#  '운영',
#  '연동',
#  '배포',
#  '관리',
#  ...]

# %%
ko = nltk.Text(ko, name= 'Work')
plt.figure(figsize=(12,6))
ko.plot(10)
plt.show()

# %%
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException
from nltk.corpus import stopwords

# NLTK 불용어 목록 로드
stop_words = set(stopwords.words('english'))

#불용어 목록 추가
user_defined_stopwords = ['restful','native']
stop_words.update(user_defined_stopwords)

# 파일에서 텍스트를 읽는 함수
def read_file(file_name):
    with open(file_name, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

# 텍스트를 영어 단어로만 토큰화하는 함수
def tokenize(text):
    words = re.findall(r'\b[a-zA-Z]+\b', text.lower())
    filtered_words = [word for word in words if word not in stop_words]
    return filtered_words

# 단어 빈도를 줄 그래프로 그리는 함수
def plot_word_frequencies(frequencies):
    sorted_words = sorted(frequencies.items(), key=lambda x: x[1], reverse=True)

    words = [word for word, count in sorted_words[:15]]
    counts = [count for word, count in sorted_words[:15]]

    plt.figure(figsize=(10, 6))
    plt.plot(words, counts, marker='o')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()


# 메인 스크립트
file_name = i
text = read_file(file_name)
words = tokenize(text)
word_frequencies = Counter(words)
plot_word_frequencies(word_frequencies)
