# %%
import pandas as pd
import numpy as np

# %%
review_df = pd.read_csv('C:/TextminingProject//concatdataset/review_df.csv')
print(len(review_df))
# Out:
# 48470

# %%
review_df
# Out:
#           직무 고용 현황 근무지        날짜   별점  \
# 0      금융/재무   현직원  서울       NaN  5.0
# 1        디자인   현직원  서울       NaN  4.0
# 2      금융/재무   현직원  서울       NaN  5.0
# 3      기획/경영   전직원  서울       NaN  5.0
# 4      금융/재무   전직원  서울  2023. 08  3.0
# ...      ...   ...  ..       ...  ...
# 48465  영업/제휴   전직원  경기  2019. 06  3.0
# 48466    전문직   전직원  해외  2019. 06  1.0
# 48467  영업/제휴   현직원  해외  2019. 05  3.0
# 48468  생산/제조   전직원  경기  2019. 04  2.0
# 48469  유통/무역   현직원  경기  2018. 08  1.0
#
#                                                       요약  \
# 0               "수평적문화 , 워라밸 ,복지포인트 많이줌, 직원의견 긍정적으로 수렴."
# 1      "스타트업의 성격이 있어, 개인의 역할이 중요하다! 운영부터 구축까지 다양한 범위의...
# 2           "워라밸 균형, 시차 출근제, 수평적인 분위기, 영어이름, 젊은 사람들이 많음"
# 3                    "하고자하는 의욕이 있다면 충분히 성장하고 발전할 수 있는 곳"
# 4      "팀바팀이지만 서로 단합이 안되고 깎아내리기가 난무한 기업. 중재자도 없고 서로 일...
# ...                                                  ...
# 48465  "위치는 좀 멀지만 회사 시설이 좋고 외관이 예쁘다. 구내식당이 있어 식사해결 가능...
# 48466               "회사가 30년이 이상 운영되어서 그런지...\r좀 고였습니다."
# 48467         "약간 올드하지만 새롭게 가려는 경향이 있음. 근데 따라가기가 쉽지 않음."
# 48468  "연봉은 괜찮았지만 나머지는 다 별로였던 회사..바이어 앞에 납작 엎드려야 하고 팀...
# 48469        "임직원을 소모품처럼 생각하는 회사.\r임원에 대한 대우만 좋은 회사입니다."
#
#                                                       장점  \
# 0      \n자동차보험 시장점유율이 빠르게 확보되는 중으로 성장성이 기대됨. 대물직원은 자회...
# 1      \n연차를 개인의 스케줄에 맞게 사용할 수 있다. 부서마다 다르겠지만, 다양성을 존...
# 2      \n직급 또는 직책으로 부르지 않고 스스로 지은 영어이름으로 부르며 사무실 분위기는...
# 3      \n연차를 마음대로 씀. 기업이 커나가는 과정을 직접 눈으로 지켜볼 수 있음. 기획...
# 4              \n워라빌이 철저히 지켜짐. 팀 사람들은 좋음. 전체적으로 활기찬 느낌\n
# ...                                                  ...
# 48465  \n구내식당이 있어 식비가 안들어서 좋다. 시설이 깨끗하고 화장실이 깔끔해서 이용하...
# 48466  \n예전에는 돈이라고 했던 것 같은데.... 저는 별로 와 닿지 않네요...\r영업...
# 48467  \n연봉이 동종 업계에서는 많은편에 속하고, 업무강도가 빡쎄기에 다른데 이직하면 좀...
# 48468  \n연봉은 그냥 평범.인센을 잘줌.사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...
# 48469  \n1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다.\r사내 식당이 있어 밥...
#
#                                                       단점  \
# 0                \n일이 많고, 체계가 좀 부족하다는 점.차차 나아질거라고 봅니다.\n
# 1      \n기본으로 제공되는 물품이 너무 적다.. 커피머신은 있지만 캡슐은 개인 구비해야하...
# 2      \n부서간 알앤알이 명확하지않고, 명확하지 않은 만큼 일을 미루는 경향이 있기도 합...
# 3                 \n주니어가 많아서 일을 차근차근 배운다기 보다 부딪치면서 배운다\n
# 4           \n불필요한 회의와 에너지 낭비가 많음. 그 에너지를 일하는대 쏟으면 좋갰음\n
# ...                                                  ...
# 48465  \n사무실 청소해주는 사람이 없어서 매우 더럽다. 임원방은 막내들이 청소함. 야근이...
# 48466  \n회사가 속이 빈 느낌 입니다.\r안을 채우고 싶어도 기존에 계신 분들이 좀 갑갑...
# 48467     \n같은 보고서가 여러개, 시스템을 사용하는데 그걸 사용하지 않고 계속 취합함.\n
# 48468  \n연차 쓰는거에 눈치 엄청 줌. 고인물 많고 직원 복지 없었던걸로 기억... 동네...
# 48469  \n단순업무가 매우 많으며, 각 부서, 직무별 업무영역과 책임이 불분명하여, 문제 ...
#
#                                              경영진에게 바라는 점
# 0      \n앞으로 더 적극적으로 마케팅하고 내실을 다져 탄탄한 보험회사로 성장하길 기원합니...
# 1      \n아직은 체계가 덜 잡혀 있는 느낌이 있습니다. 앞으로 더 체계가 잡혔으면 좋겠습...
# 2                      \n작은 회사인만큼 직원들의 말에 귀기울여주기 바랍니다.\n
# 3                    \n경영진의 생각이 직원들에게 잘 전달될 수 있었으면 좋겠다\n
# 4       \n제발 직원들의 목소리에 귀를 기울여주었으면. 쓸데없는 보고와 회의 좀 줄이세요.\n
# ...                                                  ...
# 48465  \n건물 외관과 환경만 신경쓰지 말고 직원복지에 좀 더 신경썼으면. 사무실 내도 청...
# 48466      \n바이어도 중요하지만 종업원도 내부고객이라는 점 \r생각해주시면 고맙습니다.\n
# 48467                           \n휴가 관련에 좀 도 신경이 필요합니다\n
# 48468  \n직원들을 생각해 주세요. 매출만 잘나온다고 좋은 회사는 아니라고 생각합니다. 제...
# 48469  \n보수적인 마인드 보다는, 지속적인 투자를 통해 발전하고자 하는 의지를 내비추었으...
#
# [48470 rows x 9 columns]

# %%
review_df['직무'].unique()
# Out:
# array(['금융/재무', '디자인', '기획/경영', '개발', '마케팅/시장조사', '전문직', '서비스/고객지원',
#        '데이터', '인사/총무', '교육', '영업/제휴', '생산/제조', '미디어/홍보', '유통/무역', '기타',
#        '엔지니어링', nan, '연구개발', '생산관리/품질관리', '특수계층/공공',
#        '\n          현직원\n      ', '\n          전직원\n      ', '법률/법무',
#        '의약'], dtype=object)

# %%
delete1 = review_df[review_df['직무'] == '\n          현직원\n      '].index
delete2 = review_df[review_df['직무'] == '\n          전직원\n      '].index
review_df = review_df.drop(delete1)
review_df = review_df.drop(delete2)

# %%
review_df['직무'].unique()
# Out:
# array(['금융/재무', '디자인', '기획/경영', '개발', '마케팅/시장조사', '전문직', '서비스/고객지원',
#        '데이터', '인사/총무', '교육', '영업/제휴', '생산/제조', '미디어/홍보', '유통/무역', '기타',
#        '엔지니어링', nan, '연구개발', '생산관리/품질관리', '특수계층/공공', '법률/법무', '의약'],
#       dtype=object)

# %%
review_df = review_df.dropna()
review_df['직무'].unique()
# Out:
# array(['금융/재무', '기획/경영', '개발', '마케팅/시장조사', '디자인', '전문직', '서비스/고객지원',
#        '데이터', '인사/총무', '교육', '영업/제휴', '생산/제조', '미디어/홍보', '유통/무역', '기타',
#        '엔지니어링', '연구개발', '생산관리/품질관리', '특수계층/공공', '법률/법무', '의약'],
#       dtype=object)

# %%
review_df
# Out:
#           직무 고용 현황 근무지        날짜   별점  \
# 4      금융/재무   전직원  서울  2023. 08  3.0
# 5      기획/경영   현직원  서울  2023. 07  3.0
# 6         개발   현직원  서울  2023. 06  4.0
# 7      금융/재무   현직원  서울  2023. 04  4.0
# 8         개발   현직원  서울  2023. 04  5.0
# ...      ...   ...  ..       ...  ...
# 48465  영업/제휴   전직원  경기  2019. 06  3.0
# 48466    전문직   전직원  해외  2019. 06  1.0
# 48467  영업/제휴   현직원  해외  2019. 05  3.0
# 48468  생산/제조   전직원  경기  2019. 04  2.0
# 48469  유통/무역   현직원  경기  2018. 08  1.0
#
#                                                       요약  \
# 4      "팀바팀이지만 서로 단합이 안되고 깎아내리기가 난무한 기업. 중재자도 없고 서로 일...
# 5               "기존 보험사와 다르다고 주장하나…잘 모르겠음 대체 뭘 만들고 싶은걸까"
# 6       "본인이 먹거리를 찾아먹으면 충분히 성장할 수 있는 회사 워라벨 좋고, 사람들 좋은곳"
# 7      "극상의 워라밸 경험 가능.. 하지만 그렇게 워라밸 좋은게 정말 좋은걸까? 숫자는 ...
# 8      "기존 금융출신이면 편하고 자유롭고플랫폼 출신이면 금융이 답답해 보일수 있지만타금융...
# ...                                                  ...
# 48465  "위치는 좀 멀지만 회사 시설이 좋고 외관이 예쁘다. 구내식당이 있어 식사해결 가능...
# 48466               "회사가 30년이 이상 운영되어서 그런지...\r좀 고였습니다."
# 48467         "약간 올드하지만 새롭게 가려는 경향이 있음. 근데 따라가기가 쉽지 않음."
# 48468  "연봉은 괜찮았지만 나머지는 다 별로였던 회사..바이어 앞에 납작 엎드려야 하고 팀...
# 48469        "임직원을 소모품처럼 생각하는 회사.\r임원에 대한 대우만 좋은 회사입니다."
#
#                                                       장점  \
# 4              \n워라빌이 철저히 지켜짐. 팀 사람들은 좋음. 전체적으로 활기찬 느낌\n
# 5                \n다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯\n
# 6      \n부바부지만 워라벨이 좋습니다. 일정조율이나 이런 부분도 먼저 물어보고 조율을 합...
# 7      \n워라밸 좋음\r일안하는or하기싫은 사람에게는 천국\r유한 분위기\r 아무튼 30...
# 8      \n성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨+초...
# ...                                                  ...
# 48465  \n구내식당이 있어 식비가 안들어서 좋다. 시설이 깨끗하고 화장실이 깔끔해서 이용하...
# 48466  \n예전에는 돈이라고 했던 것 같은데.... 저는 별로 와 닿지 않네요...\r영업...
# 48467  \n연봉이 동종 업계에서는 많은편에 속하고, 업무강도가 빡쎄기에 다른데 이직하면 좀...
# 48468  \n연봉은 그냥 평범.인센을 잘줌.사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...
# 48469  \n1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다.\r사내 식당이 있어 밥...
#
#                                                       단점  \
# 4           \n불필요한 회의와 에너지 낭비가 많음. 그 에너지를 일하는대 쏟으면 좋갰음\n
# 5      \n다양한 업종이 모였으나 사일로가 굉장히 높음 협업은 사실상 어렵고 친분 또는 위...
# 6      \n스타트업 마인드와 대기업마인드가 적당히 안좋게 섞여있습니다. 일단 프로젝트를 진...
# 7      \n팀장 이상급부터 급격한 질저하\r그에따른 하루가 멀다하고 바뀌는 형편없는 지시들...
# 8      \n대기업의 단점 과 스타트업 단점이 있는곳성장하는 조직이다 보니 넓게 많은걸 해야...
# ...                                                  ...
# 48465  \n사무실 청소해주는 사람이 없어서 매우 더럽다. 임원방은 막내들이 청소함. 야근이...
# 48466  \n회사가 속이 빈 느낌 입니다.\r안을 채우고 싶어도 기존에 계신 분들이 좀 갑갑...
# 48467     \n같은 보고서가 여러개, 시스템을 사용하는데 그걸 사용하지 않고 계속 취합함.\n
# 48468  \n연차 쓰는거에 눈치 엄청 줌. 고인물 많고 직원 복지 없었던걸로 기억... 동네...
# 48469  \n단순업무가 매우 많으며, 각 부서, 직무별 업무영역과 책임이 불분명하여, 문제 ...
#
#                                              경영진에게 바라는 점
# 4       \n제발 직원들의 목소리에 귀를 기울여주었으면. 쓸데없는 보고와 회의 좀 줄이세요.\n
# 5             \n심각합니다…이대로 가면 폭망 확정임 인력 이탈 이유를 생각좀 해보세요\n
# 6      \n열정적인 회사사람들이 많습니다. 이런 사람들에게 동기부여를 할 수 있도록 도와주...
# 7          \n생각하고 일하자\r주주사 눈치만 보지말고.. 대체 뭘 하고싶은건지 모르겠어\n
# 8                  \n최고의 복지는 돈 이라고 생각하는 직장인들이 많을꺼라 생각함\n
# ...                                                  ...
# 48465  \n건물 외관과 환경만 신경쓰지 말고 직원복지에 좀 더 신경썼으면. 사무실 내도 청...
# 48466      \n바이어도 중요하지만 종업원도 내부고객이라는 점 \r생각해주시면 고맙습니다.\n
# 48467                           \n휴가 관련에 좀 도 신경이 필요합니다\n
# 48468  \n직원들을 생각해 주세요. 매출만 잘나온다고 좋은 회사는 아니라고 생각합니다. 제...
# 48469  \n보수적인 마인드 보다는, 지속적인 투자를 통해 발전하고자 하는 의지를 내비추었으...
#
# [47266 rows x 9 columns]

# %%
review_df['장점']
# Out:
# 4                \n워라빌이 철저히 지켜짐. 팀 사람들은 좋음. 전체적으로 활기찬 느낌\n
# 5                  \n다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯\n
# 6        \n부바부지만 워라벨이 좋습니다. 일정조율이나 이런 부분도 먼저 물어보고 조율을 합...
# 7        \n워라밸 좋음\r일안하는or하기싫은 사람에게는 천국\r유한 분위기\r 아무튼 30...
# 8        \n성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨+초...
#                                ...
# 48465    \n구내식당이 있어 식비가 안들어서 좋다. 시설이 깨끗하고 화장실이 깔끔해서 이용하...
# 48466    \n예전에는 돈이라고 했던 것 같은데.... 저는 별로 와 닿지 않네요...\r영업...
# 48467    \n연봉이 동종 업계에서는 많은편에 속하고, 업무강도가 빡쎄기에 다른데 이직하면 좀...
# 48468    \n연봉은 그냥 평범.인센을 잘줌.사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...
# 48469    \n1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다.\r사내 식당이 있어 밥...
# Name: 장점, Length: 47266, dtype: object

# %%
review_df['단점']
# Out:
# 4             \n불필요한 회의와 에너지 낭비가 많음. 그 에너지를 일하는대 쏟으면 좋갰음\n
# 5        \n다양한 업종이 모였으나 사일로가 굉장히 높음 협업은 사실상 어렵고 친분 또는 위...
# 6        \n스타트업 마인드와 대기업마인드가 적당히 안좋게 섞여있습니다. 일단 프로젝트를 진...
# 7        \n팀장 이상급부터 급격한 질저하\r그에따른 하루가 멀다하고 바뀌는 형편없는 지시들...
# 8        \n대기업의 단점 과 스타트업 단점이 있는곳성장하는 조직이다 보니 넓게 많은걸 해야...
#                                ...
# 48465    \n사무실 청소해주는 사람이 없어서 매우 더럽다. 임원방은 막내들이 청소함. 야근이...
# 48466    \n회사가 속이 빈 느낌 입니다.\r안을 채우고 싶어도 기존에 계신 분들이 좀 갑갑...
# 48467       \n같은 보고서가 여러개, 시스템을 사용하는데 그걸 사용하지 않고 계속 취합함.\n
# 48468    \n연차 쓰는거에 눈치 엄청 줌. 고인물 많고 직원 복지 없었던걸로 기억... 동네...
# 48469    \n단순업무가 매우 많으며, 각 부서, 직무별 업무영역과 책임이 불분명하여, 문제 ...
# Name: 단점, Length: 47266, dtype: object

# %%
review_df['장점'] = review_df['장점'].str.replace("\n","")
review_df['장점'] = review_df['장점'].str.replace("\r","")
review_df['장점'] = review_df['장점'].str.replace("\t","")
review_df['장점'] = review_df['장점'].str.replace(",","")
review_df['장점'] = review_df['장점'].str.replace(".","")

# %%
review_df['단점'] = review_df['단점'].str.replace("\n","")
review_df['단점'] = review_df['단점'].str.replace("\r","")
review_df['단점'] = review_df['단점'].str.replace("\t","")
review_df['단점'] = review_df['단점'].str.replace(",","")
review_df['단점'] = review_df['단점'].str.replace(".","")

# %%
review_df['요약'] = review_df['요약'].str.replace("\n","")
review_df['요약'] = review_df['요약'].str.replace("\r","")
review_df['요약'] = review_df['요약'].str.replace("\t","")
review_df['요약'] = review_df['요약'].str.replace(",","")
review_df['요약'] = review_df['요약'].str.replace(".","")

# %%
review_df = review_df[['직무', '장점', '단점','별점']]
review_df
# Out:
#           직무                                                 장점  \
# 4      금융/재무                워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌
# 5      기획/경영                다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯
# 6         개발  부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 합니다 ...
# 7      금융/재무           워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자
# 8         개발  성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨+초고층...
# ...      ...                                                ...
# 48465  영업/제휴  구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용하기 좋...
# 48466    전문직  예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓으면 이...
# 48467  영업/제휴  연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 좀 더 ...
# 48468  생산/제조     연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버원입니다
# 48469  유통/무역  1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 걱정 할...
#
#                                                       단점   별점
# 4                불필요한 회의와 에너지 낭비가 많음 그 에너지를 일하는대 쏟으면 좋갰음  3.0
# 5      다양한 업종이 모였으나 사일로가 굉장히 높음 협업은 사실상 어렵고 친분 또는 위에서...  3.0
# 6      스타트업 마인드와 대기업마인드가 적당히 안좋게 섞여있습니다 일단 프로젝트를 진행할때...  4.0
# 7      팀장 이상급부터 급격한 질저하그에따른 하루가 멀다하고 바뀌는 형편없는 지시들그에 따...  4.0
# 8      대기업의 단점 과 스타트업 단점이 있는곳성장하는 조직이다 보니 넓게 많은걸 해야함팀...  5.0
# ...                                                  ...  ...
# 48465  사무실 청소해주는 사람이 없어서 매우 더럽다 임원방은 막내들이 청소함 야근이 많다 ...  3.0
# 48466  회사가 속이 빈 느낌 입니다안을 채우고 싶어도 기존에 계신 분들이 좀 갑갑합니다같이...  1.0
# 48467           같은 보고서가 여러개 시스템을 사용하는데 그걸 사용하지 않고 계속 취합함  3.0
# 48468  연차 쓰는거에 눈치 엄청 줌 고인물 많고 직원 복지 없었던걸로 기억 동네가 의왕이라...  2.0
# 48469  단순업무가 매우 많으며 각 부서 직무별 업무영역과 책임이 불분명하여 문제 발생시 해...  1.0
#
# [47266 rows x 4 columns]

# %%
review_df['장점']= review_df['장점'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)
review_df['단점']= review_df['단점'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)
# Out:
# C:\Users\sunga\AppData\Local\Temp\ipykernel_20044\2077870131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df['장점']= review_df['장점'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)
# C:\Users\sunga\AppData\Local\Temp\ipykernel_20044\2077870131.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df['단점']= review_df['단점'].str.replace(pat=r'[^\w]',repl=r' ',regex=True)

# %%
review_df_type = review_df.groupby('직무')['별점']
review_df_type.count()
# Out:
# 직무
# 개발           10277
# 교육             911
# 금융/재무          838
# 기타             178
# 기획/경영         6968
# 데이터            568
# 디자인           2788
# 마케팅/시장조사      6768
# 미디어/홍보        2569
# 법률/법무           64
# 생산/제조         1902
# 생산관리/품질관리      991
# 서비스/고객지원      3753
# 엔지니어링          470
# 연구개발          1481
# 영업/제휴         4380
# 유통/무역         1050
# 의약              63
# 인사/총무          813
# 전문직            407
# 특수계층/공공         27
# Name: 별점, dtype: int64

# %%
review_df['별점'].value_counts()
# Out:
# 별점
# 3.0    15222
# 4.0     9861
# 2.0     8651
# 1.0     8409
# 5.0     5123
# Name: count, dtype: int64

# %%
review_df['장점'] = "(긍정)" + review_df['장점'].map(str) + ". " +  "(/긍정)"
review_df
# Out:
# C:\Users\sunga\AppData\Local\Temp\ipykernel_20044\2137912570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df['장점'] = "(긍정)" + review_df['장점'].map(str) + ". " +  "(/긍정)"
#           직무                                                 장점  \
# 4      금융/재무     (긍정)워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌. (/긍정)
# 5      기획/경영     (긍정)다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯. (/긍정)
# 6         개발  (긍정)부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 ...
# 7      금융/재무  (긍정)워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자. ...
# 8         개발  (긍정)성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨...
# ...      ...                                                ...
# 48465  영업/제휴  (긍정)구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용...
# 48466    전문직  (긍정)예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓...
# 48467  영업/제휴  (긍정)연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 ...
# 48468  생산/제조  (긍정)연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...
# 48469  유통/무역  (긍정)1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 ...
#
#                                                       단점   별점
# 4                불필요한 회의와 에너지 낭비가 많음 그 에너지를 일하는대 쏟으면 좋갰음  3.0
# 5      다양한 업종이 모였으나 사일로가 굉장히 높음 협업은 사실상 어렵고 친분 또는 위에서...  3.0
# 6      스타트업 마인드와 대기업마인드가 적당히 안좋게 섞여있습니다 일단 프로젝트를 진행할때...  4.0
# 7      팀장 이상급부터 급격한 질저하그에따른 하루가 멀다하고 바뀌는 형편없는 지시들그에 따...  4.0
# 8      대기업의 단점 과 스타트업 단점이 있는곳성장하는 조직이다 보니 넓게 많은걸 해야함팀...  5.0
# ...                                                  ...  ...
# 48465  사무실 청소해주는 사람이 없어서 매우 더럽다 임원방은 막내들이 청소함 야근이 많다 ...  3.0
# 48466  회사가 속이 빈 느낌 입니다안을 채우고 싶어도 기존에 계신 분들이 좀 갑갑합니다같이...  1.0
# 48467           같은 보고서가 여러개 시스템을 사용하는데 그걸 사용하지 않고 계속 취합함  3.0
# 48468  연차 쓰는거에 눈치 엄청 줌 고인물 많고 직원 복지 없었던걸로 기억 동네가 의왕이라...  2.0
# 48469  단순업무가 매우 많으며 각 부서 직무별 업무영역과 책임이 불분명하여 문제 발생시 해...  1.0
#
# [47266 rows x 4 columns]

# %%
review_df['단점'] = "(부정)" + review_df['단점'].map(str) + ". " +  "(/부정)"
review_df
# Out:
# C:\Users\sunga\AppData\Local\Temp\ipykernel_20044\3978559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df['단점'] = "(부정)" + review_df['단점'].map(str) + ". " +  "(/부정)"
#           직무                                                 장점  \
# 4      금융/재무     (긍정)워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌. (/긍정)
# 5      기획/경영     (긍정)다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯. (/긍정)
# 6         개발  (긍정)부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 ...
# 7      금융/재무  (긍정)워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자. ...
# 8         개발  (긍정)성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨...
# ...      ...                                                ...
# 48465  영업/제휴  (긍정)구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용...
# 48466    전문직  (긍정)예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓...
# 48467  영업/제휴  (긍정)연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 ...
# 48468  생산/제조  (긍정)연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...
# 48469  유통/무역  (긍정)1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 ...
#
#                                                       단점   별점
# 4      (부정)불필요한 회의와 에너지 낭비가 많음 그 에너지를 일하는대 쏟으면 좋갰음. (...  3.0
# 5      (부정)다양한 업종이 모였으나 사일로가 굉장히 높음 협업은 사실상 어렵고 친분 또는...  3.0
# 6      (부정)스타트업 마인드와 대기업마인드가 적당히 안좋게 섞여있습니다 일단 프로젝트를 ...  4.0
# 7      (부정)팀장 이상급부터 급격한 질저하그에따른 하루가 멀다하고 바뀌는 형편없는 지시들...  4.0
# 8      (부정)대기업의 단점 과 스타트업 단점이 있는곳성장하는 조직이다 보니 넓게 많은걸 ...  5.0
# ...                                                  ...  ...
# 48465  (부정)사무실 청소해주는 사람이 없어서 매우 더럽다 임원방은 막내들이 청소함 야근이...  3.0
# 48466  (부정)회사가 속이 빈 느낌 입니다안을 채우고 싶어도 기존에 계신 분들이 좀 갑갑합...  1.0
# 48467  (부정)같은 보고서가 여러개 시스템을 사용하는데 그걸 사용하지 않고 계속 취합함. ...  3.0
# 48468  (부정)연차 쓰는거에 눈치 엄청 줌 고인물 많고 직원 복지 없었던걸로 기억 동네가 ...  2.0
# 48469  (부정)단순업무가 매우 많으며 각 부서 직무별 업무영역과 책임이 불분명하여 문제 발...  1.0
#
# [47266 rows x 4 columns]

# %%
review_df['리뷰'] = review_df['장점'].map(str) + ". " + review_df['단점'].map(str)
review_df
# Out:
# C:\Users\sunga\AppData\Local\Temp\ipykernel_20044\3394062475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df['리뷰'] = review_df['장점'].map(str) + ". " + review_df['단점'].map(str)
#           직무                                                 장점  \
# 4      금융/재무     (긍정)워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌. (/긍정)
# 5      기획/경영     (긍정)다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯. (/긍정)
# 6         개발  (긍정)부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 ...
# 7      금융/재무  (긍정)워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자. ...
# 8         개발  (긍정)성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨...
# ...      ...                                                ...
# 48465  영업/제휴  (긍정)구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용...
# 48466    전문직  (긍정)예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓...
# 48467  영업/제휴  (긍정)연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 ...
# 48468  생산/제조  (긍정)연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...
# 48469  유통/무역  (긍정)1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 ...
#
#                                                       단점   별점  \
# 4      (부정)불필요한 회의와 에너지 낭비가 많음 그 에너지를 일하는대 쏟으면 좋갰음. (...  3.0
# 5      (부정)다양한 업종이 모였으나 사일로가 굉장히 높음 협업은 사실상 어렵고 친분 또는...  3.0
# 6      (부정)스타트업 마인드와 대기업마인드가 적당히 안좋게 섞여있습니다 일단 프로젝트를 ...  4.0
# 7      (부정)팀장 이상급부터 급격한 질저하그에따른 하루가 멀다하고 바뀌는 형편없는 지시들...  4.0
# 8      (부정)대기업의 단점 과 스타트업 단점이 있는곳성장하는 조직이다 보니 넓게 많은걸 ...  5.0
# ...                                                  ...  ...
# 48465  (부정)사무실 청소해주는 사람이 없어서 매우 더럽다 임원방은 막내들이 청소함 야근이...  3.0
# 48466  (부정)회사가 속이 빈 느낌 입니다안을 채우고 싶어도 기존에 계신 분들이 좀 갑갑합...  1.0
# 48467  (부정)같은 보고서가 여러개 시스템을 사용하는데 그걸 사용하지 않고 계속 취합함. ...  3.0
# 48468  (부정)연차 쓰는거에 눈치 엄청 줌 고인물 많고 직원 복지 없었던걸로 기억 동네가 ...  2.0
# 48469  (부정)단순업무가 매우 많으며 각 부서 직무별 업무영역과 책임이 불분명하여 문제 발...  1.0
#
#                                                       리뷰
# 4      (긍정)워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌. (/긍정)...
# 5      (긍정)다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯. (/긍정)...
# 6      (긍정)부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 ...
# 7      (긍정)워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자. ...
# 8      (긍정)성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨...
# ...                                                  ...
# 48465  (긍정)구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용...
# 48466  (긍정)예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓...
# 48467  (긍정)연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 ...
# 48468  (긍정)연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...
# 48469  (긍정)1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 ...
#
# [47266 rows x 5 columns]

# %%
review_df_new = review_df[['직무', '리뷰','별점']]
review_df_new
# Out:
#           직무                                                 리뷰   별점
# 4      금융/재무  (긍정)워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌. (/긍정)...  3.0
# 5      기획/경영  (긍정)다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯. (/긍정)...  3.0
# 6         개발  (긍정)부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 ...  4.0
# 7      금융/재무  (긍정)워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자. ...  4.0
# 8         개발  (긍정)성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨...  5.0
# ...      ...                                                ...  ...
# 48465  영업/제휴  (긍정)구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용...  3.0
# 48466    전문직  (긍정)예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓...  1.0
# 48467  영업/제휴  (긍정)연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 ...  3.0
# 48468  생산/제조  (긍정)연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...  2.0
# 48469  유통/무역  (긍정)1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 ...  1.0
#
# [47266 rows x 3 columns]

# %%
review_df_new.to_csv('review_df_new.txt', sep ='\t', index = False)

# %%
selected = ['데이터','디자인']
review_df_test = review_df_new[review_df_new['직무'].isin(selected)].reset_index(drop=True)
review_df_test
# Out:
#        직무                                                 리뷰   별점
# 0     디자인  (긍정)직원분들이 좋으시고 그래도 분위기는 좋은 편인 것 같다 회사 위치도 괜찮은 ...  3.0
# 1     데이터  (긍정)평등하고 워라벨이 좋은 편이고잘 생각이 안날 정도로 정이 떨어졌다. (/긍정...  3.0
# 2     디자인  (긍정)야근 없고  연차 눈치 안보고 쓸 수 있는거  그리고 없네요. (/긍정). ...  2.0
# 3     디자인  (긍정)연차를 눈치보지 않고 쓸 수 있음 휴가도 자유롭게 사용가능. (/긍정). (...  5.0
# 4     데이터  (긍정)타기업 대비 높은 연봉노멀한 사내 분위기스무스한 직원들는 다른 곳보다 너무 ...  5.0
# ...   ...                                                ...  ...
# 3351  디자인  (긍정)개인법카사용 휴가 자유로운편 근속수당있음 1년 근속시 2주간의 리프레시 휴가...  4.0
# 3352  디자인  (긍정)휴가 사용이 자유로운 편이며 업무에 차질이 없으면 알아서 사용하면 됩니다 1...  2.0
# 3353  디자인  (긍정)스케쥴에 맞춰 윗사람 눈치안보고 연차사용 가능 자유로운 분위기와 직원들의 근...  1.0
# 3354  디자인  (긍정)잔업이 많다 일이 많다 분진이 오지게 많다 밥이 맛있다 화장실이 더럽다 근로...  1.0
# 3355  디자인  (긍정)구내식당 있어서 밥 맛있고 돈 빨리 모을 수 있고회사 뒤에 큰 호수 있다 그...  2.0
#
# [3356 rows x 3 columns]

# %%
review_df_test.to_csv('review_df_test.txt', sep ='\t', index = False)

# %%
review_df_train = review_df_new[~review_df_new['직무'].isin(selected)].reset_index(drop=True)
review_df_train = review_df_train[['리뷰','별점']]
review_df_train
# Out:
#                                                       리뷰   별점
# 0      (긍정)워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌. (/긍정)...  3.0
# 1      (긍정)다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯. (/긍정)...  3.0
# 2      (긍정)부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 ...  4.0
# 3      (긍정)워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자. ...  4.0
# 4      (긍정)성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨...  5.0
# ...                                                  ...  ...
# 43905  (긍정)구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용...  3.0
# 43906  (긍정)예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓...  1.0
# 43907  (긍정)연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 ...  3.0
# 43908  (긍정)연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...  2.0
# 43909  (긍정)1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 ...  1.0
#
# [43910 rows x 2 columns]

# %%
review_df_train['리뷰']
# Out:
# 0        (긍정)워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌. (/긍정)...
# 1        (긍정)다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯. (/긍정)...
# 2        (긍정)부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 ...
# 3        (긍정)워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자. ...
# 4        (긍정)성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨...
#                                ...
# 43905    (긍정)구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용...
# 43906    (긍정)예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓...
# 43907    (긍정)연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 ...
# 43908    (긍정)연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...
# 43909    (긍정)1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 ...
# Name: 리뷰, Length: 43910, dtype: object

# %%
review_df_train['별점'] = review_df_train['별점'].astype(int)
review_df_train['별점']
# Out:
# 0        3
# 1        3
# 2        4
# 3        4
# 4        5
#         ..
# 43905    3
# 43906    1
# 43907    3
# 43908    2
# 43909    1
# Name: 별점, Length: 43910, dtype: int32

# %%
review_df_train.dtypes
# Out:
# 리뷰    object
# 별점     int32
# dtype: object

# %%
review_df_train
# Out:
#                                                       리뷰  별점
# 0      (긍정)워라빌이 철저히 지켜짐 팀 사람들은 좋음 전체적으로 활기찬 느낌. (/긍정)...   3
# 1      (긍정)다양한 업종 배이스 직원과 교류 보험사 중 워라벨은 좋은 편인듯. (/긍정)...   3
# 2      (긍정)부바부지만 워라벨이 좋습니다 일정조율이나 이런 부분도 먼저 물어보고 조율을 ...   4
# 3      (긍정)워라밸 좋음일안하는or하기싫은 사람에게는 천국유한 분위기 아무튼 30글자. ...   4
# 4      (긍정)성장성이 높은 기업이며대기업의 장점 과 스타트업 장점이 있는곳지하철이 연결됨...   5
# ...                                                  ...  ..
# 43905  (긍정)구내식당이 있어 식비가 안들어서 좋다 시설이 깨끗하고 화장실이 깔끔해서 이용...   3
# 43906  (긍정)예전에는 돈이라고 했던 것 같은데 저는 별로 와 닿지 않네요영업쪽은 경력 쌓...   1
# 43907  (긍정)연봉이 동종 업계에서는 많은편에 속하고 업무강도가 빡쎄기에 다른데 이직하면 ...   3
# 43908  (긍정)연봉은 그냥 평범인센을 잘줌사무실 외관이 이쁘고 핸드백 제조 업계에서는 넘버...   2
# 43909  (긍정)1년의 2번 나오는 성과금 수준은 업계 최고 수준입니다사내 식당이 있어 밥 ...   1
#
# [43910 rows x 2 columns]

# %%
review_df_train['별점'].unique()
# Out:
# array([3, 4, 5, 2, 1])

# %%
review_df_train['별점'] = review_df_train['별점'] -1
review_df_train['별점']
# Out:
# 0        2
# 1        2
# 2        3
# 3        3
# 4        4
#         ..
# 43905    2
# 43906    0
# 43907    2
# 43908    1
# 43909    0
# Name: 별점, Length: 43910, dtype: int32

# %%
review_df_train.to_csv('review_df_train.txt', sep ='\t', index = False)

# %%
len(review_df_train)
# Out:
# 43910

# %%
from konlpy.tag import Okt
from tqdm import tqdm
okt = Okt()
train = []
for sentence in tqdm(review_df_train['리뷰']):
    tokenized_sentence = okt.morphs(sentence, stem=True)
    train.append(tokenized_sentence)
# Out:
#   0%|          | 0/43910 [00:00<?, ?it/s]
# 100%|██████████| 43910/43910 [02:42<00:00, 270.95it/s]

# %%
train
# Out:
# [['(',
#   '긍정',
#   ')',
#   '워',
#   '라',
#   '빌다',
#   '철저하다',
#   '지키다',
#   '짐',
#   '팀',
#   '사람',
#   '들',
#   '은',
#   '좋다',
#   '전체',
#   '적',
#   '으로',
#   '활기차다',
#   '느낌',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '불필요하다',
#   '회의',
#   '와',
#   '에너지',
#   '낭비',
#   '가',
#   '많다',
#   '그',
#   '에너지',
#   '를',
#   '일',
#   '하다',
#   '쏟다',
#   '좋다',
#   '개다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '다양하다',
#   '업종',
#   '배',
#   '이스',
#   '직원',
#   '과',
#   '교류',
#   '보험사',
#   '중',
#   '워',
#   '라벨',
#   '은',
#   '좋다',
#   '펴다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '다양하다',
#   '업종',
#   '이',
#   '모이다',
#   '사일로',
#   '가',
#   '굉장하다',
#   '높다',
#   '협업',
#   '은',
#   '사실',
#   '상',
#   '어렵다',
#   '친분',
#   '또는',
#   '위',
#   '에서',
#   '강하다',
#   '쪼',
#   '는',
#   '것',
#   '위주',
#   '로',
#   '진행',
#   '이',
#   '되다',
#   '업무',
#   '환경',
#   '임',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '부바',
#   '부지',
#   '만',
#   '워',
#   '라벨',
#   '이',
#   '좋다',
#   '일정',
#   '조율',
#   '이나',
#   '이렇다',
#   '부분',
#   '도',
#   '먼저',
#   '물어보다',
#   '조율',
#   '을',
#   '하다',
#   '물론',
#   '급하다',
#   '일정',
#   '들',
#   '은',
#   '늘',
#   '있다',
#   '그래도',
#   '최대한',
#   '워',
#   '라벨',
#   '을',
#   '보장',
#   '하다',
#   '주',
#   '려고',
#   '하',
#   '는',
#   '느김입니',
#   '다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '스타트업',
#   '마인드',
#   '와',
#   '대기업',
#   '마인드',
#   '가',
#   '적당하다',
#   '안좋다',
#   '섞이다',
#   '일단',
#   '프로젝트',
#   '를',
#   '진행',
#   '하다',
#   '때',
#   '속도',
#   '가',
#   '더디다',
#   '그렇다고',
#   '대기업',
#   '처럼',
#   '문서',
#   '화가',
#   '잘',
#   '되어다',
#   '않다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '워',
#   '라',
#   '밸',
#   '좋다',
#   '이다',
#   'or',
#   '하다',
#   '싫다',
#   '사람',
#   '에게는',
#   '천국',
#   '유한',
#   '분위기',
#   '아무튼',
#   '30',
#   '글자',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '팀',
#   '장',
#   '이상',
#   '급',
#   '부터',
#   '급격하다',
#   '질',
#   '저',
#   '하그',
#   '에',
#   '따르다',
#   '하루',
#   '가',
#   '멀다',
#   '바뀌다',
#   '형편',
#   '없다',
#   '지시',
#   '들',
#   '그',
#   '에',
#   '따르다',
#   '퍼지다',
#   '매너리즘',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '성장',
#   '성',
#   '이',
#   '높다',
#   '기업',
#   '이며',
#   '대기업',
#   '의',
#   '장점',
#   '과',
#   '스타트업',
#   '장점',
#   '이',
#   '있다',
#   '곳',
#   '지하철',
#   '이',
#   '연결',
#   '되다',
#   '초고',
#   '층뷰',
#   '대표',
#   '님',
#   '마인드',
#   '가',
#   '직원',
#   '들',
#   '을',
#   '많이',
#   '생각',
#   '하다',
#   '느껴지다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '대기업',
#   '의',
#   '단점',
#   '과',
#   '스타트업',
#   '단점',
#   '이',
#   '있다',
#   '곳',
#   '성장하다',
#   '조직',
#   '이다',
#   '보다',
#   '넓다',
#   '많다',
#   '하다',
#   '함팀',
#   '은',
#   '케바케',
#   '자유롭다',
#   '분위기',
#   '가족',
#   '같다',
#   '분위기',
#   '가',
#   '있다',
#   '반면',
#   '군대',
#   '문화',
#   '팀',
#   '도',
#   '분명',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '각종',
#   '복리',
#   '후생',
#   '및',
#   '직원',
#   '들',
#   '처우',
#   '에',
#   '대한',
#   '개선',
#   '점',
#   '을',
#   '찾아가다',
#   '전통',
#   '적',
#   '인',
#   '손',
#   '보사',
#   '에서',
#   '경험',
#   '해보다',
#   '업무',
#   '들',
#   '터치',
#   '가능',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '회의',
#   '및',
#   '뒷받침',
#   '하다',
#   '제반',
#   '서류',
#   '업무',
#   '과도',
#   '인력',
#   '충',
#   '원',
#   '이',
#   '사다',
#   '확장',
#   '속도',
#   '에',
#   '못',
#   '미치다',
#   '그레이',
#   '존',
#   '이',
#   '다수',
#   '존재',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '워',
#   '라',
#   '밸',
#   '은',
#   '보험사',
#   '중',
#   '최고',
#   '인',
#   '듯',
#   '하다',
#   '을지로',
#   '라',
#   '교통',
#   '이',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '노',
#   '는',
#   '사람',
#   '이',
#   '많다',
#   '회사',
#   '방향',
#   '이',
#   '대표',
#   '기분',
#   '따르다',
#   '바뀌다',
#   '팀',
#   '은',
#   '대학교',
#   '동아리',
#   '수준',
#   '이다',
#   '추진',
#   '력',
#   '이',
#   '느리다',
#   '외부',
#   '이미지',
#   '에',
#   '비다',
#   '느리다',
#   '조직',
#   '이다',
#   '팀',
#   '장',
#   '급',
#   '들',
#   '이',
#   '무능하다',
#   '부서',
#   '가',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '리프',
#   '레쉬',
#   '휴가',
#   '유연근무제',
#   '부바',
#   '부',
#   '복장',
#   '자율',
#   '교통',
#   '이',
#   '편리하다',
#   '반',
#   '반',
#   '차',
#   '휴가',
#   '비',
#   '지원',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '경영',
#   '진의',
#   '말',
#   '바꾸다',
#   '시대',
#   '를',
#   '역행',
#   '하다',
#   '경',
#   '영진',
#   '야근',
#   '장려',
#   '한화',
#   '손보',
#   '의',
#   '자회사',
#   '문제',
#   '많다',
#   '캐롯',
#   '플러그',
#   '일방',
#   '적',
#   '인',
#   '본사',
#   '이전',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '를',
#   '아무',
#   '때',
#   '나',
#   '쓸다',
#   '수',
#   '있다',
#   '젊다',
#   '조직',
#   '이라',
#   '회사',
#   '생활',
#   '은',
#   '재미있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '협상',
#   '이나',
#   '승진',
#   '등',
#   '을',
#   '감추다',
#   '자다',
#   '알다',
#   '않다',
#   '투명',
#   '성',
#   '이',
#   '없다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '아직',
#   '대',
#   '외적',
#   '으로는',
#   '이미지',
#   '가',
#   '좋다',
#   '듯',
#   '하다',
#   '신',
#   '기술',
#   '로',
#   '뭔가',
#   '인슈',
#   '어',
#   '테크',
#   '하다',
#   '처럼',
#   '보임',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '속',
#   '빈',
#   '강정',
#   '이다',
#   '좀더',
#   '내다',
#   '다지다',
#   '하다',
#   '눈앞',
#   '에',
#   '실익',
#   '에',
#   '급',
#   '급하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '눈치',
#   '안보',
#   '고',
#   '연차',
#   '쓸다',
#   '있다',
#   '넉넉하다',
#   '복지',
#   '포인트',
#   '및',
#   '체력',
#   '달다',
#   '휴가',
#   '지하철역',
#   '에서',
#   '바로',
#   '회사',
#   '로',
#   '출퇴근',
#   '하다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '회사',
#   '공지',
#   '가',
#   '직원',
#   '들',
#   '에게',
#   '제대로',
#   '공유',
#   '되다',
#   '않다',
#   '누구',
#   '는',
#   '알',
#   '고',
#   '누구',
#   '는',
#   '모르다',
#   '최근',
#   '에',
#   '새롭다',
#   '대표',
#   '님',
#   '오다',
#   '많이',
#   '개선',
#   '되어다',
#   '가다',
#   '중',
#   '다른',
#   '부서',
#   '와의',
#   '협업',
#   '이',
#   '원활하다',
#   '못',
#   '하다',
#   '서로',
#   '의',
#   '주장',
#   '이',
#   '강하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '모회사',
#   '가',
#   '대기업',
#   '이라는',
#   '정도',
#   '퍼',
#   '마일',
#   '보험',
#   '상품',
#   '개념',
#   '자체',
#   '는',
#   '나쁘다',
#   '않다',
#   '많이',
#   '팔',
#   '리기',
#   '는',
#   '하다',
#   '그러나',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '농구단',
#   '문제',
#   '로',
#   '뉴스',
#   '탈',
#   '만큼',
#   '자금',
#   '사정',
#   '좋다',
#   '않다',
#   '정말',
#   '근본',
#   '적',
#   '인',
#   '문제',
#   '는',
#   '플러그',
#   '리스크',
#   '인데',
#   '해결',
#   '되다',
#   '기미',
#   '가',
#   '보이다',
#   '않다',
#   '본업',
#   '은',
#   '위태',
#   '로운',
#   '데',
#   '보여주다',
#   '식',
#   '쇼',
#   '와',
#   '정치가',
#   '판',
#   '을',
#   '치다',
#   '임원진',
#   '중',
#   '에',
#   '조직',
#   '의',
#   '암',
#   '덩어리',
#   '같다',
#   '관',
#   '종형',
#   '무능력자',
#   '존재',
#   '하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '내',
#   '가',
#   '하다',
#   '싶다',
#   '일이',
#   '나',
#   '개선',
#   '되어다',
#   '하다',
#   '점',
#   '들',
#   '을',
#   '의견',
#   '을',
#   '내면',
#   '들어주다',
#   '어떻다',
#   '하다',
#   '하다',
#   '지다',
#   '대해',
#   '다',
#   '같이',
#   '고민',
#   '함',
#   '또한',
#   '젊다',
#   '사람',
#   '들',
#   '이',
#   '많다',
#   '생각',
#   '보다',
#   '꼰대들',
#   '이',
#   '많다',
#   '않다',
#   '젊꼰',
#   '은',
#   '없다',
#   '것',
#   '같다',
#   '복지',
#   '는',
#   '숙박',
#   '비',
#   '지원',
#   '이나',
#   '복지',
#   '포인트',
#   '지급',
#   '등',
#   '나름',
#   '만족스럽다',
#   '움',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '메신저',
#   '에',
#   '누가',
#   '어느',
#   '업무',
#   '를',
#   '담당',
#   '하고',
#   '있다',
#   '지다',
#   '기재',
#   '가',
#   '안되다',
#   '조금',
#   '불편하다',
#   '한화',
#   '계',
#   '열사',
#   '혜택',
#   '을',
#   '더',
#   '늘리다',
#   '주다',
#   '좋다',
#   '스타트업',
#   '이라서',
#   '체계',
#   '가',
#   '조금',
#   '부족함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '수평',
#   '적',
#   '인',
#   '분위기',
#   '워',
#   '라벨',
#   '자유롭다',
#   '연차',
#   '사용',
#   '쾌적하다',
#   '사무실',
#   '역다',
#   '권',
#   '인',
#   '회사',
#   '입지',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '직급',
#   '체계',
#   '가',
#   '없다',
#   '업무',
#   '프로세스',
#   '도',
#   '비',
#   '효율',
#   '본부',
#   '별',
#   '협업',
#   '및',
#   '의사소통',
#   '비',
#   '원활',
#   '낮다',
#   '연봉',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '수평',
#   '적',
#   '인',
#   '분위기',
#   '는',
#   '그래도',
#   '괜찮다',
#   '보다',
#   '복지부',
#   '분',
#   '도',
#   '굉장하다',
#   '좋다',
#   '본사',
#   '에',
#   '한해',
#   '서',
#   '만',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '아직',
#   '인프라',
#   '가',
#   '구축',
#   '되다',
#   '않다',
#   '상황',
#   '에서',
#   '순식간',
#   '에',
#   '가입자',
#   '상승',
#   '곡선',
#   '에',
#   '따르다',
#   '직원',
#   '들',
#   '의',
#   '피로',
#   '감',
#   '이',
#   '누적',
#   '이',
#   '되다',
#   '없다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '워',
#   '라',
#   '밸',
#   '과',
#   '복지',
#   '가',
#   '괜찮다',
#   '편',
#   '이다',
#   '부서',
#   '와',
#   '부서장',
#   '을',
#   '자다',
#   '만나다',
#   '가능하다',
#   '겉',
#   '으로는',
#   '수평',
#   '적',
#   '인척',
#   '함',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '아주',
#   '작다',
#   '일도',
#   '엄청',
#   '있다',
#   '보이',
#   '게',
#   '꾸미다',
#   '무언가',
#   '대단하다',
#   '일',
#   '을',
#   '하다',
#   '척',
#   '하다',
#   '그게',
#   '곧',
#   '그',
#   '사람',
#   '의',
#   '능력',
#   '임',
#   '체계',
#   '가',
#   '전혀',
#   '없다',
#   '부서',
#   '간',
#   '경쟁',
#   '때문',
#   '에',
#   '협업',
#   '은',
#   '있다',
#   '없다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '사용',
#   '자유',
#   '롭고',
#   '능력',
#   '별로',
#   '평가',
#   '받다',
#   '것',
#   '같다',
#   '경력',
#   '직',
#   '많다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '아직',
#   '초기',
#   '단계',
#   '라',
#   '체계',
#   '가',
#   '덜',
#   '잡히다',
#   '듯',
#   '하다',
#   '인사',
#   '관련',
#   '새롭다',
#   '많이',
#   '하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '이',
#   '회사',
#   '으이',
#   '장점',
#   '은',
#   '일단',
#   '해보다',
#   '많다',
#   '본인',
#   '이',
#   '하다',
#   '자하',
#   '면',
#   '하다',
#   '수',
#   '있다',
#   '많다',
#   '물론',
#   '그',
#   '안',
#   '에서',
#   '약간',
#   '의',
#   '정치가',
#   '필요하다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '대기업',
#   '출신',
#   '이라',
#   '그렇다',
#   '엉덩이',
#   '가',
#   '무겁다',
#   '그래서',
#   '프로세서',
#   '의',
#   '진행',
#   '이',
#   '느리다',
#   '감',
#   '이',
#   '있다',
#   '이',
#   '부분',
#   '을',
#   '해결',
#   '하다',
#   '수',
#   '있다',
#   '좀',
#   '더',
#   '좋다',
#   '회사',
#   '가',
#   '되다',
#   '수',
#   '있다',
#   '않다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '자유롭다',
#   '연',
#   '차사',
#   '용역',
#   '하고',
#   '이어지다',
#   '의자',
#   '연봉',
#   '상',
#   '승률',
#   '이',
#   '낮다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '1',
#   '알앤알',
#   '명확하다',
#   '않다',
#   '일',
#   '하다',
#   '힘들다',
#   '2',
#   '인사',
#   '제도',
#   '가',
#   '명확하다',
#   '않다',
#   '본인',
#   '이',
#   '승진',
#   '대상자',
#   '인지도',
#   '알다',
#   '힘들다',
#   '3',
#   '보험',
#   '회사',
#   '인데',
#   '보험',
#   '모르다',
#   '분',
#   '들',
#   '이',
#   '많다',
#   '일',
#   '하다',
#   '힘들다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '영어',
#   '이름',
#   '워',
#   '라벨',
#   '급여',
#   '높다',
#   '편',
#   '복지',
#   '포인트',
#   '숙소',
#   '비',
#   '체력',
#   '달다',
#   '휴가',
#   '5일',
#   '등',
#   '좋다',
#   '점',
#   '은',
#   '꽤',
#   '되다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '퍼',
#   '마일',
#   '자동차',
#   '보험',
#   '외',
#   '에',
#   '다른',
#   '보험',
#   '들',
#   '은',
#   '딱하다',
#   '자다',
#   '될런',
#   '지',
#   '모르다',
#   '기업',
#   '목표',
#   '가',
#   '정확하다',
#   '공유',
#   '안되다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '1',
#   '전체',
#   '적',
#   '으로',
#   '수평',
#   '적',
#   '인',
#   '분위기',
#   '2',
#   '인적',
#   '구성',
#   '이',
#   '젊다',
#   '상',
#   '명',
#   '하복',
#   '식',
#   '문화',
#   '는',
#   '많이',
#   '없다',
#   '3',
#   '연차',
#   '및',
#   '나이',
#   '대비',
#   '다양하다',
#   '중요하다',
#   '업무',
#   '수행',
#   '가능',
#   '4',
#   '초기',
#   '멤버',
#   '로',
#   '조기',
#   '관리자',
#   '진급',
#   '등',
#   '기회',
#   '열리다',
#   '5',
#   '한화',
#   '손보',
#   '와',
#   '동일하다',
#   '복지',
#   '제도',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '급여',
#   '테이블',
#   '부재',
#   '로',
#   '주먹구구',
#   '식',
#   '연봉',
#   '협상',
#   '함',
#   '같다',
#   '연차',
#   '이나',
#   '최대',
#   '1000만원',
#   '이상',
#   '의',
#   '차이',
#   '가',
#   '나기',
#   '도',
#   '함',
#   '물론',
#   '직전',
#   '회사',
#   '연봉',
#   '에',
#   '따르다',
#   '달라지다',
#   '하다',
#   '이후',
#   '에는',
#   '어느',
#   '정도',
#   '보정',
#   '되어다',
#   '하다',
#   '않다',
#   '싶다',
#   '말',
#   '만',
#   '하다',
#   '2년',
#   '째',
#   '변화',
#   '없다',
#   '윗',
#   '선',
#   '은',
#   '아직',
#   '보험사',
#   '의',
#   '보수',
#   '적',
#   '이고',
#   '상',
#   '명',
#   '하복',
#   '식',
#   '의',
#   '문화',
#   '잔존',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '를',
#   '눈치',
#   '안보',
#   '고',
#   '쓸다',
#   '수',
#   '있다',
#   '연차',
#   '추가',
#   '로',
#   '5일',
#   '더줌',
#   '그거',
#   '말고',
#   '별다르다',
#   '복지',
#   '없다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '퍼',
#   '마일',
#   '자동차',
#   '보험',
#   '판매',
#   '말고는',
#   '나머지',
#   '는',
#   '관심',
#   '없다',
#   '회사',
#   '같다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '젊다',
#   '직원',
#   '구성',
#   '대기업',
#   '복지',
#   '제도',
#   '연봉',
#   '도',
#   '나쁘다',
#   '않다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '인력',
#   '부족',
#   '으로',
#   '업무',
#   '과',
#   '다',
#   '근무',
#   '환경',
#   '개선',
#   '필요',
#   '성',
#   '과금',
#   '기준',
#   '필요',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '신생',
#   '손보',
#   '사이다',
#   '보다',
#   '사원',
#   '들',
#   '의',
#   '평균연령',
#   '이',
#   '낮다',
#   '자유롭다',
#   '분위기',
#   '속',
#   '에서',
#   '억압받다',
#   '않다',
#   '근무',
#   '하다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '인력',
#   '이',
#   '부족하다',
#   '업',
#   '무량',
#   '이',
#   '많다',
#   '편이',
#   '고',
#   '신입사원',
#   '의',
#   '경우',
#   '체계',
#   '적',
#   '으로',
#   '교육',
#   '이',
#   '부족함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '사용',
#   '시',
#   '눈치',
#   '보이지',
#   '않다',
#   '사내',
#   '에',
#   '책',
#   '을',
#   '볼',
#   '수',
#   '있다',
#   '공간',
#   '이',
#   '마련',
#   '되어다',
#   '있다',
#   '출퇴근',
#   '시간',
#   '이',
#   '유동',
#   '적임',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '보안',
#   '이',
#   '엄격하다',
#   '재택근무',
#   '가',
#   '까다롭다',
#   '움',
#   '조직',
#   '이',
#   '안정',
#   '되다',
#   '않다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '비교',
#   '적',
#   '젊다',
#   '우수하다',
#   '맨',
#   '파워',
#   '의',
#   '현',
#   '업',
#   '과',
#   '테크',
#   '우대',
#   '하다',
#   '기업',
#   '문화',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '한창',
#   '성장하다',
#   '회사',
#   '라',
#   '사람',
#   '도',
#   '부족하다',
#   '정신',
#   '없다',
#   '전산',
#   '고도화',
#   '시급',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '워',
#   '라벨',
#   '보장',
#   '한화',
#   '계',
#   '열사',
#   '로',
#   '임',
#   '직원',
#   '할인',
#   '제도',
#   '및',
#   '기타',
#   '복리',
#   '후생',
#   '제도',
#   '가',
#   '다양하다',
#   '편',
#   '으로',
#   '나쁘다',
#   '않다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '사내',
#   '정치가',
#   '심하다',
#   '비개',
#   '발인',
#   '력',
#   '에',
#   '대한',
#   '차별',
#   '이',
#   '심하다',
#   '본인',
#   '들',
#   '은',
#   '상당하다',
#   '쿨하다',
#   '오픈',
#   '마인드',
#   '라',
#   '생각',
#   '하다',
#   '틀닥',
#   '꼰대',
#   '부터',
#   '젋',
#   '은',
#   '꼰대',
#   '까지',
#   '꼰',
#   '대',
#   '천국',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '체력',
#   '달다',
#   '휴가',
#   '5일',
#   '을',
#   '더',
#   '주다',
#   '매년',
#   '복지',
#   '포인트',
#   '를',
#   '지급',
#   '하다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '부서',
#   '간',
#   '이해관계',
#   '등',
#   '이나',
#   '금융업',
#   '계',
#   '의',
#   '보수',
#   '적',
#   '인',
#   '업무',
#   '처리',
#   '방식',
#   '등',
#   '이',
#   '단점',
#   '으로',
#   '생각',
#   '되다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '를',
#   '윗사람',
#   '눈치',
#   '안보',
#   '고',
#   '사용',
#   '하다',
#   '수',
#   '있다',
#   '근무',
#   '시간',
#   '이',
#   '자유',
#   '로움',
#   '워',
#   '라',
#   '밸',
#   '이',
#   '훌륭하다',
#   '자유롭다',
#   '업무',
#   '를',
#   '추진',
#   '하다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '업무',
#   '체계',
#   '가',
#   '부족함',
#   '평가',
#   '체계',
#   '가',
#   '부족함',
#   '회사',
#   '비젼',
#   '이',
#   '공유',
#   '되다',
#   '않다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '기본',
#   '연차',
#   '15일',
#   '5일',
#   '더',
#   '줌',
#   '금융',
#   '권',
#   '치고는',
#   '프리',
#   '한',
#   '복장',
#   '과',
#   '분위기',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '금융',
#   '권',
#   '치고',
#   '낮다',
#   '연봉',
#   '부서',
#   '마다',
#   '분위기',
#   '너무',
#   '다르다',
#   '업무',
#   '강도',
#   '복불복',
#   '인',
#   '것',
#   '같다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '금융',
#   '권',
#   '대비',
#   '낮다',
#   '업무',
#   '강도',
#   '부바',
#   '부',
#   '이기다',
#   '하지만',
#   '부서장',
#   '이',
#   '보험',
#   '업',
#   '출신',
#   '이',
#   '아니다',
#   '부서',
#   '는',
#   '나름',
#   '수평',
#   '인',
#   '듯',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '스타트업',
#   '이라고',
#   '하지만',
#   '엄청나다',
#   '불협화음',
#   '을',
#   '자랑',
#   '하다',
#   '대기업',
#   '출신',
#   '부서장',
#   '들',
#   '이',
#   '이렇게',
#   '무능하다',
#   '놀라다',
#   '있다',
#   '체계',
#   '가',
#   '많이',
#   '부족함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '금융',
#   '권',
#   '치고는',
#   '조금',
#   '수평',
#   '적',
#   '일',
#   '지도',
#   '그',
#   '외',
#   '장점',
#   '은',
#   '자다',
#   '모르다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '한화',
#   '손보',
#   '한',
#   '화생',
#   '명',
#   '과',
#   '네이버',
#   '카카오',
#   '의',
#   '단점',
#   '을',
#   '합치다',
#   '빠르다',
#   '적용',
#   '중',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '수평',
#   '적',
#   '인',
#   '호칭',
#   '워',
#   '라',
#   '밸',
#   '이',
#   '그나마',
#   '자다',
#   '지키다',
#   '편',
#   '이다',
#   '부바',
#   '부',
#   '타',
#   '보험사',
#   '대비',
#   '덜',
#   '보수',
#   '적',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '카카오',
#   '에',
#   '밀리다',
#   '도태',
#   '되다',
#   '누적',
#   '되다',
#   '적자',
#   '자동차',
#   '보험',
#   '의',
#   '비중',
#   '이',
#   '너무',
#   '높다',
#   '손익',
#   '개선',
#   '이',
#   '어리다',
#   '쉬다',
#   '새',
#   '없이',
#   '울리다',
#   '대다',
#   '팀',
#   '즈',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '적당하다',
#   '급여',
#   '복지',
#   '포인트',
#   '리',
#   '플래쉬',
#   '포인트',
#   '워',
#   '라벨',
#   '도',
#   '괜춘함',
#   '탄력',
#   '근',
#   '무제',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '체계',
#   '가',
#   '없다',
#   '인사',
#   '발표',
#   '등',
#   '이',
#   '명확하다',
#   '않다',
#   '투명하다',
#   '않다',
#   '스타트업',
#   '의',
#   '단점',
#   '기존',
#   '금융',
#   '사',
#   '단점',
#   '이',
#   '적절하다',
#   '조금씩',
#   '합치다',
#   '짐',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '금융',
#   '권',
#   '치고',
#   '수평',
#   '적',
#   '인',
#   '분위기',
#   '여서',
#   '기존',
#   '은행',
#   '보험사',
#   '등',
#   '근무',
#   '하다',
#   '분',
#   '들',
#   '은',
#   '편하다',
#   '느끼다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '경',
#   '영자',
#   '들',
#   '의',
#   '능력',
#   '에',
#   '대한',
#   '의',
#   '구심',
#   '이',
#   '많이',
#   '듬',
#   '적절하다',
#   '의사결정',
#   '에',
#   '어려움',
#   '이',
#   '있다',
#   '듯',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '사람',
#   '으로',
#   '인하다',
#   '스트레스',
#   '가',
#   '없다',
#   '타',
#   '업종',
#   '비',
#   '금융',
#   '이라',
#   '낮다',
#   '않다',
#   '연봉',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '시작',
#   '한지',
#   '얼마',
#   '되다',
#   '않다',
#   '체계',
#   '가',
#   '없다',
#   '복지',
#   '가',
#   '안좋다',
#   '직원',
#   '을',
#   '챙기다',
#   '중요하다',
#   '회사',
#   '중심',
#   '적',
#   '인',
#   '부분',
#   '이',
#   '강하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '열정',
#   '적',
#   '인',
#   '사람',
#   '이',
#   '많다',
#   '그리고',
#   '일',
#   '하다',
#   '배우다',
#   '점도',
#   '많다',
#   '연차',
#   '나',
#   '영어',
#   '이름',
#   '부르다',
#   '능것',
#   '도',
#   '자유',
#   '롭고',
#   '분위기',
#   '도',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '아직',
#   '네',
#   '임',
#   '벨',
#   '류',
#   '나',
#   '적자',
#   '의',
#   '문제',
#   '가',
#   '있다',
#   '그래서',
#   '걱정',
#   '이',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '자유롭다',
#   '사용',
#   '가능하다',
#   '회사',
#   '위치',
#   '가',
#   '아주',
#   '좋다',
#   '곳',
#   '에',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '계약',
#   '이외',
#   '에',
#   '하나',
#   '도',
#   '없다',
#   '복지',
#   '그냥',
#   '없다',
#   '보다',
#   '되다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '사람',
#   '들',
#   '이',
#   '대부분',
#   '다',
#   '좋다',
#   '순하다',
#   '조용조',
#   '용하다',
#   '유',
#   '데미',
#   '비즈니스',
#   '강의',
#   '공짜',
#   '로',
#   '들다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '성과',
#   '가',
#   '적다',
#   '직원',
#   '들',
#   '한테',
#   '돌아오다',
#   '게',
#   '좀',
#   '적다',
#   '느낌',
#   '이',
#   '들다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '자유롭다',
#   '연차',
#   '를',
#   '사용',
#   '하다',
#   '수',
#   '있다',
#   '환경',
#   '매',
#   '명절',
#   '마다',
#   '회사',
#   '에서',
#   '선물',
#   '을',
#   '주다',
#   '항상',
#   '만족스럽다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '정수기',
#   '사업',
#   '의',
#   '매각',
#   '으로',
#   '인하다',
#   '현재',
#   '웅진',
#   '만의',
#   '장점',
#   '이',
#   '뚜렷하다',
#   '않다',
#   '점',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '하다',
#   '달',
#   '만기',
#   '가',
#   '되다',
#   '하루',
#   '연차',
#   '가',
#   '나오다',
#   '월급',
#   '제',
#   '처럼',
#   '나오다',
#   '때문',
#   '에',
#   '일',
#   '하다',
#   '느낌',
#   '이',
#   '강하다',
#   '들다',
#   '현재',
#   '웅진',
#   '씽크빅',
#   '소속',
#   '으로',
#   '바뀌다',
#   '처우',
#   '가',
#   '좋아지다',
#   '걸',
#   '로',
#   '알다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '그만두다',
#   '하다',
#   '달',
#   '전',
#   '통보',
#   '를',
#   '하다',
#   '함',
#   '하루',
#   '4시간',
#   '만',
#   '근무',
#   '하다',
#   '반나절',
#   '이',
#   '묶이게',
#   '되다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '워',
#   '라',
#   '밸',
#   '이',
#   '매우',
#   '좋다',
#   '사람',
#   '들',
#   '이',
#   '매우',
#   '좋다',
#   '지하',
#   '에',
#   '저렴하다',
#   '카페',
#   '와',
#   '라운지',
#   '가',
#   '있다',
#   '점심시간',
#   '에',
#   '쉬다',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '이',
#   '매우',
#   '짜다',
#   '법카',
#   '가',
#   '개인',
#   '별로',
#   '나오다',
#   '실제',
#   '로',
#   '사용',
#   '하다',
#   '수',
#   '있다',
#   '돈',
#   '이',
#   '너무',
#   '적다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '를',
#   '자유롭다',
#   '쓸다',
#   '수',
#   '있다',
#   '헬',
#   '스케',
#   '어',
#   '라는',
#   '복지',
#   '가',
#   '있다',
#   '회사',
#   '위치',
#   '가',
#   '괜찮다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '업무',
#   '를',
#   '배우다',
#   '수',
#   '있다',
#   '기회',
#   '가',
#   '많다',
#   '않다',
#   '각',
#   '자도',
#   '생으로',
#   '자기',
#   '가',
#   '알다',
#   '배우다',
#   '깨',
#   '달다',
#   '다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '사람',
#   '들',
#   '이',
#   '무난',
#   '하고',
#   '좋다',
#   '서울',
#   '중심',
#   '에',
#   '위치',
#   '하다',
#   '출퇴근',
#   '이',
#   '편리하다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '신입',
#   '들',
#   '이',
#   '들어오다',
#   '조금',
#   '배우다',
#   '퇴사',
#   '율',
#   '이',
#   '잦다',
#   '계속',
#   '아래',
#   '사람',
#   '이',
#   '바뀌다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '쪽팔리다',
#   '정도',
#   '는',
#   '아니다',
#   '네',
#   '임밸류',
#   '쪽팔리다',
#   '정도',
#   '는',
#   '아니다',
#   '급여',
#   '그냥',
#   '그렇다',
#   '복지',
#   '그냥',
#   '무난',
#   '한',
#   '게',
#   '장점',
#   '탈주',
#   '하다',
#   '여기',
#   '도',
#   '나쁘다',
#   '않다',
#   '그치다',
#   '탈주',
#   '를',
#   '계속',
#   '하고프다',
#   '회사',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '특출나다',
#   '장점',
#   '이',
#   '없다',
#   '모든',
#   '게',
#   '다',
#   '단점',
#   '급여',
#   '는',
#   '만족',
#   '스럽지',
#   '않다',
#   '윗',
#   '분들',
#   '너무',
#   '구시대',
#   '적',
#   '사람',
#   '들',
#   'IT',
#   '회사',
#   '라곤',
#   '전혀',
#   '느껴지다',
#   '않다',
#   '업무',
#   '시스템',
#   '복지',
#   '급여',
#   '등등',
#   '모든',
#   '게',
#   '다',
#   '뒤',
#   '떨어지다',
#   '있다',
#   '그냥',
#   '이대로',
#   '간다',
#   '면',
#   '끝',
#   '이',
#   '너무',
#   '자다',
#   '보이다',
#   '회사',
#   '젊다',
#   '사람',
#   '들',
#   '은',
#   '빨리',
#   '빨리',
#   '탈주',
#   '함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '역다',
#   '권',
#   '이라서',
#   '출퇴근',
#   '하다',
#   '좋다',
#   '휴게',
#   '공간',
#   '도',
#   '넓다',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '직원',
#   '들',
#   '은',
#   '많다',
#   '화장실',
#   '이',
#   '작고',
#   '좁다',
#   '불편하다',
#   '음식',
#   '대',
#   '지원',
#   '안',
#   '되다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '무난',
#   '하다',
#   '다니다',
#   '좋다',
#   '회사',
#   '업계',
#   '평균',
#   '그',
#   '자체',
#   '좋다',
#   '회사',
#   '위치',
#   '사실',
#   '특별하다',
#   '크다',
#   '게',
#   '장점',
#   '이',
#   '랄건',
#   '없다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '점심',
#   '지우다',
#   '없다',
#   '급여',
#   '에',
#   '포함',
#   '이라고',
#   '하지만',
#   '애매하다',
#   '급여',
#   '명절',
#   '상여',
#   '일절',
#   '없다',
#   '복지',
#   '없다',
#   '그냥',
#   '저',
#   '냥',
#   '회사',
#   '인',
#   '느낌',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '자유',
#   '롭고',
#   '플레이',
#   '도시',
#   '이용',
#   '이',
#   '자유',
#   '롭고',
#   '복지',
#   '좋다',
#   '편임',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '영업',
#   '사원',
#   '들',
#   '전화',
#   '가',
#   '많다',
#   '크다',
#   '임',
#   '커서',
#   '응대',
#   '가',
#   '힘들다',
#   '직원',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '복지로',
#   '마사지',
#   '를',
#   '2000원',
#   '주다',
#   '받다',
#   '수',
#   '있다',
#   '특성',
#   '부서',
#   '를',
#   '제외',
#   '하고는',
#   '그래도',
#   '회사',
#   '분위기',
#   '가',
#   '좋다',
#   '편',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '개발자',
#   '로서',
#   '의',
#   '커리어',
#   '사망',
#   '공수',
#   '를',
#   '말',
#   '도',
#   '안되다',
#   '적다',
#   '따오다',
#   '업무',
#   '가',
#   '하다',
#   '번',
#   '에',
#   '몰리다',
#   '본부',
#   '평가',
#   '가',
#   '실적',
#   '순이',
#   '아니다',
#   '대표',
#   '의',
#   '애정도',
#   '순',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '또또',
#   '사랑',
#   '팀바팀',
#   '이지만',
#   '근무',
#   '강도',
#   '가',
#   '높다',
#   '않다',
#   '계',
#   '열사',
#   '할인',
#   '혜택',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '오래되다',
#   '사람',
#   '이',
#   '많다',
#   '고',
#   '인물',
#   '이',
#   '많다',
#   '답답하다',
#   '소금',
#   '보다',
#   '짜다',
#   '연봉',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '복지',
#   '포인트',
#   '있다',
#   '법',
#   '크다',
#   '역',
#   '에서',
#   '회사',
#   '가깝다',
#   '움',
#   '카페테리아',
#   '있다',
#   '회식',
#   '없다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '복지',
#   '쓸다',
#   '대가',
#   '많다',
#   '않다',
#   '야근',
#   '많다',
#   '주말',
#   '출근',
#   '각오',
#   '야근',
#   '수당',
#   '없다',
#   '연봉',
#   '높다',
#   '않다',
#   '워',
#   '라벨',
#   '포기',
#   '하다',
#   '함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '자유롭다',
#   '쓰다',
#   '육아',
#   '병행',
#   '하다',
#   '수',
#   '있다',
#   '제도',
#   '사용',
#   '가능',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '운영',
#   '업무',
#   '에',
#   '대한',
#   '인정',
#   '안해',
#   '줌',
#   '차장',
#   '이상',
#   '너무',
#   '고여',
#   '있다',
#   '윗',
#   '물이',
#   '더',
#   '능력',
#   '이',
#   '없다',
#   '경우',
#   '가',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '팀바팀',
#   '이지만',
#   '나름',
#   '워',
#   '라',
#   '밸',
#   '지키다',
#   '짐',
#   '사람',
#   '자다',
#   '안',
#   '자르다',
#   '청계천',
#   '바로',
#   '앞',
#   '회사',
#   '사람',
#   '들',
#   '이',
#   '순하다',
#   '편',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '동',
#   '종',
#   '업계',
#   '대비',
#   '연봉',
#   '수준',
#   '낮다',
#   '편',
#   '근데',
#   '업계',
#   '대비',
#   '사내',
#   '문화',
#   '도',
#   '후진',
#   '적',
#   'IT',
#   '회사',
#   '지만',
#   '재택근무',
#   '는',
#   '찾아보다',
#   '수도',
#   '없다',
#   '임원',
#   '얼굴',
#   '외우다',
#   '인사',
#   '하',
#   '라고',
#   '지시',
#   '내려오다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '사용',
#   '편하다',
#   '너무',
#   '길다',
#   '붙이다',
#   '누가',
#   '보다',
#   '바쁘다',
#   '시기',
#   '아니다',
#   'SAP',
#   '모듈',
#   '교육',
#   '수강',
#   '가능',
#   '연봉',
#   '이',
#   '낮다',
#   '편이',
#   '아니다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '중간',
#   '라인',
#   '없다',
#   '과',
#   '차장',
#   '신입',
#   '들어오다',
#   '일',
#   '가르치다',
#   '사람',
#   '도',
#   '없다',
#   '알다',
#   '배우다',
#   '야하다',
#   '신입',
#   '이',
#   '신입',
#   '을',
#   '가르치다',
#   '있다',
#   '교육',
#   '은',
#   '차다',
#   '직원',
#   '관리',
#   '조차',
#   '안되다',
#   '덕분',
#   '에',
#   '일',
#   '좀',
#   '잘',
#   '하다',
#   '일이',
#   '몰리다',
#   '그래서',
#   '난',
#   '탈출',
#   '함',
#   '연봉',
#   '통보',
#   '는',
#   '받다',
#   '보다',
#   '협상',
#   '은',
#   '안',
#   '해보다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '자유롭다',
#   '분위기',
#   '며',
#   '자기',
#   '하다',
#   '일만',
#   '하다',
#   '크게',
#   '터치',
#   '가',
#   '없다',
#   '회사',
#   '자신',
#   '이',
#   '하다',
#   '일만',
#   '하다',
#   '크게',
#   '터치',
#   '당하다',
#   '일이',
#   '없다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '이',
#   '많다',
#   '않다',
#   '딱딱하다',
#   '분위기',
#   '가',
#   '있다',
#   '요즘',
#   '다',
#   '하다',
#   '유연근무제',
#   '가',
#   '명목',
#   '상',
#   '으로만',
#   '존재',
#   '하다',
#   '신규',
#   '기술',
#   '에',
#   '대해',
#   '인색하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '기업',
#   '문화',
#   '가',
#   '좋다',
#   '사람',
#   '들',
#   '이',
#   '전반',
#   '적',
#   '으로',
#   '선하다',
#   '착하다',
#   '직원',
#   '중심',
#   '으로',
#   '많다',
#   '해주다',
#   '함',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '착하다',
#   '강조',
#   '하다',
#   '보다',
#   '기업',
#   '의',
#   '부족함',
#   '이',
#   '많이',
#   '보임',
#   '튀어',
#   '나가야',
#   '되다',
#   '착하다',
#   '함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '사용',
#   '자유',
#   '사람',
#   '들',
#   '둥글둥글',
#   '업무',
#   '압박',
#   '이',
#   '없다',
#   '업',
#   '무량',
#   '은',
#   '많다',
#   '경력',
#   '에',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '사무직',
#   '수당',
#   '없다',
#   '2023년',
#   '도가',
#   '맞다',
#   '의심',
#   '되다',
#   '낮다',
#   '연봉',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '장기',
#   '근속',
#   '자',
#   '가',
#   '제법',
#   '많다',
#   '신입',
#   '이',
#   '오다',
#   '배우다',
#   '좋다',
#   '구',
#   '조',
#   '헬',
#   '스케',
#   '어',
#   '안마',
#   '2천원',
#   '에',
#   '가능',
#   '부서',
#   '별다르다',
#   '꽤',
#   '자유롭다',
#   '분위기',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '야근',
#   '이',
#   '많다',
#   '사람',
#   '들',
#   '이',
#   '있다',
#   '직무',
#   '별',
#   '차이',
#   '가',
#   '매우',
#   '심',
#   '한편',
#   '아침',
#   '9시',
#   '엘레베이터',
#   '사람',
#   '너무',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '웅플',
#   '무료',
#   '이용',
#   '호텔',
#   '제휴',
#   '이외',
#   '에는',
#   '없다',
#   '청계천',
#   '가깝다',
#   '정도',
#   '랄',
#   '끄다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '장점',
#   '외',
#   '의',
#   '모든',
#   '것',
#   '이',
#   '단점',
#   '이다',
#   '낮다',
#   '연봉',
#   '적다',
#   '복지',
#   '명절',
#   '선물',
#   '이',
#   '자사',
#   '제품',
#   '임',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '를',
#   '눈치',
#   '보디',
#   '않다',
#   '쓰다',
#   '많다',
#   '이다',
#   '못',
#   '쓰다',
#   '눈치',
#   '는',
#   '케바케',
#   '나쁘다',
#   '않다',
#   '움',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '과차',
#   '부가',
#   '많다',
#   '승진',
#   '힘드다',
#   '엘리베이터',
#   '타다',
#   '힘드다',
#   '전문',
#   '직종',
#   '이라기',
#   '엔',
#   '무리',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '가',
#   '자유',
#   '롭고',
#   '마사지',
#   '사가',
#   '있다',
#   '근무시간',
#   '에',
#   '가다',
#   '아무',
#   '도',
#   '눈치',
#   '알다',
#   '좋다',
#   '종로',
#   '한',
#   '복판',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '타',
#   'IT',
#   '회사',
#   '연봉',
#   '들다',
#   '부럽다',
#   '약간',
#   '의',
#   '꼰',
#   '분위기',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '체계',
#   '적',
#   '인',
#   '신입',
#   '교육',
#   '시스템',
#   '생일',
#   '자',
#   '복지',
#   '및',
#   '한',
#   '달',
#   '에',
#   '한번',
#   '헬',
#   '스케',
#   '어',
#   '계',
#   '열사',
#   '할인',
#   '정당하다',
#   '수당',
#   '지급',
#   '이',
#   '인상',
#   '적',
#   '이다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연차',
#   '사용',
#   '이',
#   '자유롭다',
#   '하나',
#   '실상',
#   '은',
#   '그렇다',
#   '못',
#   '하다',
#   '당연하다',
#   '실적',
#   '압박',
#   '이',
#   '있다',
#   '그',
#   '실적',
#   '이',
#   '알음',
#   '알음',
#   '공개',
#   '되어다',
#   '줄',
#   '세우다',
#   '되다',
#   '분위기',
#   '가',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '구성원',
#   '들',
#   '이',
#   '착하다',
#   '편이',
#   '고',
#   '회사',
#   '에서',
#   '착하다',
#   '만들다',
#   '노력',
#   '하고',
#   '있다',
#   '모',
#   '난',
#   '사람',
#   '은',
#   '많다',
#   '않다',
#   '편',
#   '인거',
#   '같다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '실력',
#   '이',
#   '진짜',
#   '있다',
#   '건지다',
#   '아니다',
#   '실력',
#   '이',
#   '없다',
#   '남아',
#   '있다',
#   '건지다',
#   '모르다',
#   '사람',
#   '들',
#   '이',
#   '좀',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '청계천',
#   '주변',
#   '에',
#   '위치',
#   '회사',
#   '이름',
#   '은',
#   '그래도',
#   '씽크빅땜',
#   '에',
#   '알아주다',
#   '회사',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '문어',
#   '발',
#   '식',
#   '자회사',
#   '확장',
#   '경',
#   '영기획',
#   '조',
#   '정실',
#   '이라는',
#   '비서',
#   '집단',
#   '화',
#   '문화',
#   '위',
#   '에서',
#   '다',
#   '챙기다',
#   '직원',
#   '월급',
#   '은',
#   '쥐꼬리',
#   '만큼',
#   '줄다',
#   '인사',
#   '제도',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '업무',
#   '메뉴얼',
#   '이',
#   '자다',
#   '갖추다',
#   '있다',
#   '신입',
#   '들',
#   '도',
#   '아이',
#   '들',
#   '을',
#   '좋아하다',
#   '화상',
#   '지도',
#   '교사',
#   '업무',
#   '에',
#   '의지',
#   '만',
#   '있다',
#   '자다',
#   '배우다',
#   '수',
#   '있다',
#   '연차',
#   '도',
#   '유동',
#   '적',
#   '으로',
#   '자다',
#   '쓸다',
#   '수',
#   '있다',
#   '시간',
#   '단위',
#   '로',
#   '업무',
#   '시간',
#   '도',
#   '조정',
#   '가능',
#   '하다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '교사',
#   '들',
#   '자리',
#   '가',
#   '너무',
#   '옆',
#   '에',
#   '붙다',
#   '수업',
#   '에',
#   '집중',
#   '하다',
#   '어리다',
#   '때',
#   '도',
#   '있다',
#   '칸막이',
#   '를',
#   '만들다',
#   '좀더',
#   '쾌적하다',
#   '환경',
#   '을',
#   '제공',
#   '하다',
#   '수업',
#   '에',
#   '더',
#   '도움',
#   '이',
#   '되다',
#   '것',
#   '같다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '프로젝트',
#   '만',
#   '아니다',
#   '연차',
#   '의',
#   '자유',
#   '가',
#   '있다',
#   '법적',
#   '인',
#   '한도',
#   '내',
#   '에서만',
#   '법',
#   '을',
#   '잘',
#   '지키다',
#   '부바',
#   '부지',
#   '만',
#   '경력',
#   '쌓다',
#   '이직',
#   '하다',
#   '딱이다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '유도',
#   '리가',
#   '없다',
#   '그',
#   '놈',
#   '의',
#   '규정',
#   '타령',
#   '돈',
#   '은',
#   '개발자',
#   '가',
#   '벌다',
#   '정작',
#   '운영',
#   '을',
#   '담당',
#   '하다',
#   '부서',
#   '는',
#   '지다',
#   '들이다',
#   '회사',
#   '왕',
#   '인',
#   '줄암',
#   'IT',
#   '회사',
#   '답지',
#   '못',
#   '하다',
#   '복장',
#   '유연',
#   '근무',
#   '재택근무',
#   '그렇다',
#   '할복',
#   '지',
#   '이렇다',
#   '없다',
#   '퇴사',
#   '후',
#   '이다',
#   '놀다',
#   '재',
#   '입사',
#   '하',
#   '면',
#   '연봉',
#   '과',
#   '직급',
#   '을',
#   '올리다',
#   '재',
#   '입사',
#   '한',
#   '사례',
#   '가',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '교육',
#   '관련',
#   '하다',
#   '지원',
#   '을',
#   '자다',
#   '해주다',
#   '정기',
#   '휴가',
#   '주다',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '통보',
#   '되다',
#   'it',
#   '기업',
#   '임',
#   '에도',
#   '윗',
#   '분들',
#   '의',
#   '마인드',
#   '는',
#   '구식이다',
#   '점',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '회사',
#   '씨',
#   '스템',
#   '도',
#   '체계',
#   '적',
#   '이다',
#   '업무',
#   '하다',
#   '사람',
#   '들',
#   '마인드',
#   '도',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '크게',
#   '단점',
#   '을',
#   '꼽',
#   '을',
#   '수',
#   '는',
#   '없다',
#   '다소',
#   '보다',
#   '강하다',
#   '분',
#   '들',
#   '이',
#   '있다',
#   '것',
#   '으로',
#   '기억',
#   '한',
#   '다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '야근',
#   '식',
#   '대',
#   '지원',
#   '업무',
#   '분담',
#   '체계',
#   '로',
#   '여류',
#   '로운',
#   '워',
#   '라',
#   '벨',
#   '가능',
#   'udemy',
#   '를',
#   '통한',
#   '무료',
#   '자기',
#   '학습',
#   '관리',
#   '가능',
#   '등',
#   '복지',
#   '가',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '1년',
#   '차',
#   '2년',
#   '차',
#   '근',
#   '무자',
#   '들',
#   '의',
#   '잦다',
#   '이탈',
#   '장기',
#   '근무',
#   '자중',
#   '진급',
#   '이',
#   '힘들다',
#   '사람',
#   '들',
#   '의',
#   '타부',
#   '서',
#   '이동',
#   '이',
#   '좋다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '사람',
#   '들',
#   '이',
#   '다른',
#   '곳',
#   '에',
#   '비다',
#   '착하다',
#   '함',
#   '종로',
#   '3',
#   '가다',
#   '위치',
#   '괜찮다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '복지',
#   '별로',
#   '고',
#   '인물',
#   '들',
#   '별로',
#   'IT',
#   '직',
#   '군',
#   '이지만',
#   '실력',
#   '없이',
#   '밑',
#   '에',
#   '사람',
#   '능력',
#   '뽑다',
#   '먹다',
#   '는걸',
#   '로',
#   '버티다',
#   '상사',
#   '들',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '1',
#   '여자',
#   '가',
#   '다니다',
#   '좋다',
#   '여성',
#   '우대',
#   '2',
#   '가족',
#   '적',
#   '인',
#   '문화',
#   '3',
#   '한때',
#   '대기업',
#   '이다',
#   '네',
#   '임',
#   '벨',
#   '류',
#   '가',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '1',
#   '고',
#   '인물',
#   '이',
#   '많다',
#   '꼰',
#   '대',
#   '문화',
#   '임',
#   '2',
#   '연봉',
#   '이',
#   '짬',
#   '업계',
#   '평균',
#   '을',
#   '못',
#   '맞추다',
#   '줌',
#   '3',
#   '기업',
#   '이',
#   '기울다',
#   '보임',
#   '코웨이',
#   '사다',
#   '다시',
#   '파다',
#   '4',
#   '사원',
#   '대리',
#   '급',
#   '이',
#   '없다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '신입',
#   '이',
#   '다니다',
#   '괜찮다',
#   '조건',
#   '과',
#   '복지',
#   '라고',
#   '생각',
#   '하다',
#   '보수',
#   '적',
#   '인',
#   '회사',
#   '에',
#   '및',
#   '사내',
#   '정책',
#   '이라',
#   '첫',
#   '회사',
#   '로',
#   '경험',
#   '하다',
#   '나쁘다',
#   '않다',
#   '회사',
#   '이름',
#   '이',
#   '많이',
#   '알려지다',
#   '나중',
#   '에',
#   '이직',
#   '하다',
#   '스텝업',
#   '으로',
#   '나쁘다',
#   '않다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '팀바팀',
#   '부바',
#   '부',
#   '이나',
#   '대체로',
#   'IT',
#   '쪽',
#   '은',
#   '업무',
#   '후',
#   '연락',
#   '이',
#   '오다',
#   '경우',
#   '가',
#   '많다',
#   '기존',
#   '복지',
#   '들',
#   '이',
#   '하나',
#   '씩',
#   '사라지다',
#   '있다',
#   '정규직',
#   '은',
#   '시장',
#   '평균',
#   '연봉',
#   '에',
#   '못',
#   '미치다',
#   '경우',
#   '가',
#   '대다수',
#   '과거',
#   '의',
#   '영광',
#   '에',
#   '취해',
#   '발전',
#   '이',
#   '없다',
#   '임',
#   '직원',
#   '이',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '팀',
#   '바이',
#   '팀',
#   '이기다',
#   '수평',
#   '적',
#   '인',
#   '분위기',
#   '이다',
#   '안정',
#   '적',
#   '인',
#   '회사',
#   '를',
#   '원하다',
#   '딱',
#   '맞다',
#   '겁니다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '직원',
#   '에',
#   '대한',
#   '애착',
#   '이',
#   '하나',
#   '도',
#   '없다',
#   '직원',
#   '들',
#   '끼리',
#   '으쌰으쌰',
#   '하다',
#   '살다',
#   '회사',
#   '이다',
#   '연',
#   '차수',
#   '당',
#   '야근',
#   '수당',
#   '이렇다',
#   '하나',
#   '도',
#   '없다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '워',
#   '라',
#   '밸',
#   '이',
#   '보장',
#   '되어다',
#   '팀',
#   '별로',
#   '다르다',
#   '운영',
#   '팀',
#   '은',
#   '칼퇴',
#   '가능',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '팀',
#   '별로',
#   '근무',
#   '환경',
#   '이',
#   '너무',
#   '다르다',
#   '조',
#   '화가',
#   '필요하다',
#   '본부',
#   '별로',
#   '도',
#   '차다',
#   '다르다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '그나마',
#   '교육비',
#   '지원',
#   '및',
#   '시험',
#   '지',
#   '원',
#   '비',
#   '가',
#   '가장',
#   '좋다',
#   '여기',
#   '서',
#   '자격증',
#   '이',
#   '것',
#   '저',
#   '것',
#   '따다',
#   '현재',
#   '는',
#   '이',
#   '직함',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '무조건',
#   '눈치',
#   '보다',
#   '야근',
#   '하고',
#   '팀',
#   '장',
#   '에',
#   '의하다',
#   '좌지우지',
#   '되다',
#   '편',
#   '회의',
#   '를',
#   '가다',
#   '그냥',
#   '이',
#   '거해',
#   '라',
#   '하다',
#   '그냥',
#   '하다',
#   '함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '딱하다',
#   '없다',
#   '같다',
#   '그나마',
#   '있다',
#   '종로',
#   '에',
#   '회사',
#   '가',
#   '위치',
#   '하고',
#   '있다',
#   '점',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '지금',
#   '은',
#   '아니다',
#   '수',
#   '있다',
#   '출퇴근',
#   '시',
#   '자리',
#   '돌아다니다',
#   '다',
#   '인사',
#   '하다',
#   '하다',
#   '술',
#   '잘',
#   '먹다',
#   '자랑',
#   '이다',
#   '하다',
#   '꼰',
#   '대',
#   '가',
#   '많다',
#   '정말',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '적당하다',
#   '복지',
#   '52시간',
#   '지키다',
#   '하지만',
#   '적당하다',
#   '야근',
#   '자유롭다',
#   '복장',
#   '과',
#   '적당하다',
#   '눈치',
#   '보이다',
#   '연차',
#   '사용',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   'Si',
#   '업종',
#   '이다',
#   '보다',
#   '갑사',
#   '의',
#   '눈치',
#   '를',
#   '많이',
#   '보다',
#   'Sap',
#   '개발',
#   '및',
#   '유지',
#   '보수',
#   '관리',
#   '하다',
#   '보다',
#   '개발자',
#   '의',
#   '성장',
#   '은',
#   '잘',
#   '모르다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '눈치',
#   '안보',
#   '고',
#   '쓸다',
#   '수',
#   '있다',
#   '음',
#   '같이',
#   '일',
#   '하다',
#   '사람',
#   '들',
#   '이',
#   '사이',
#   '가',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '사내',
#   '분위기',
#   '가',
#   '부바',
#   '부가',
#   '심하다',
#   '외주',
#   '직원',
#   '들',
#   '과',
#   '정',
#   '직원',
#   '들',
#   '의',
#   '분리',
#   '가',
#   '심하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '체계',
#   '적',
#   '인',
#   '교육',
#   '시스템',
#   '이',
#   '있다',
#   '조',
#   '직문',
#   '화',
#   '가',
#   '수직',
#   '적',
#   '이지',
#   '않다',
#   '문화',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '조',
#   '직장',
#   '들',
#   '이',
#   '권위',
#   '적',
#   '이지',
#   '않다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '프로젝트',
#   '에',
#   '따르다',
#   '편차',
#   '가',
#   '있다',
#   '야근',
#   '이',
#   '많다',
#   '경우',
#   '가',
#   '많다',
#   '대신',
#   '대체',
#   '휴무',
#   '제도',
#   '가',
#   '존재',
#   '함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '를',
#   '윗사람',
#   '눈치',
#   '안보',
#   '고',
#   '쓸다',
#   '잇다',
#   '그리고',
#   '또다른',
#   '장점',
#   '은',
#   '음',
#   'ㅎㅎㅎㅎㅎㅎ',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '의외로',
#   '개발',
#   '프로젝트',
#   '에',
#   '대한',
#   '문서',
#   '화가',
#   '너무',
#   '안되다',
#   '기존',
#   '기업',
#   '에선',
#   '귀찮다',
#   '지금',
#   '은',
#   '너무',
#   '정보',
#   '가',
#   '없다',
#   '빡새',
#   '요',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '교육',
#   '사업',
#   '으로',
#   '출발',
#   '하다',
#   '외부',
#   '강사',
#   '를',
#   '초빙',
#   '한',
#   '사내',
#   '교육',
#   '의',
#   '기회',
#   '가',
#   '많다',
#   '육아휴직',
#   '도',
#   '자유롭다',
#   '쓸다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '방판',
#   '사업',
#   '을',
#   '벌리다',
#   '놓다',
#   '건',
#   '많다',
#   '성과',
#   '가',
#   '없다',
#   '씽크빅',
#   '빼다',
#   '비',
#   '전이',
#   '별로',
#   '없다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '퇴근',
#   '연차',
#   '눈',
#   '치안',
#   '봄',
#   '팀바팀',
#   '괜찮다',
#   '보이',
#   '늘다',
#   '연봉',
#   '비교',
#   '적',
#   '수직',
#   '적',
#   '인',
#   '문화',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '팀',
#   '이',
#   '잘',
#   '못',
#   '걸리다',
#   '집',
#   '에',
#   '걍',
#   '못',
#   '간다',
#   'Si',
#   '늘다',
#   '사내',
#   '복지',
#   '를',
#   '그냥',
#   '못',
#   '누리다',
#   '생각',
#   '하다',
#   '돼다',
#   '집',
#   '에',
#   '못',
#   '들어가다',
#   '못',
#   '씻다',
#   '하다',
#   '경우',
#   '가',
#   '부지',
#   '기수',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '착하다',
#   '좋다',
#   '관리자',
#   '가',
#   '많다',
#   '내',
#   '상황',
#   '을',
#   '이해',
#   '해주다',
#   '해결',
#   '해주다',
#   '고함',
#   '가족',
#   '같다',
#   '분위기',
#   '가',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '중간',
#   '관리자',
#   '들',
#   '은',
#   '너무',
#   '좋다',
#   '그',
#   '윗',
#   '선',
#   '관리자',
#   '들',
#   '은',
#   '매우',
#   '별로',
#   '임',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '회사',
#   '위치',
#   '가',
#   '우선',
#   '좋다',
#   '연차',
#   '나름',
#   '눈치',
#   '안보',
#   '고',
#   '사용',
#   '가능',
#   '사람',
#   '들',
#   '도',
#   '무난',
#   '하다',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '급여',
#   '이외',
#   '에',
#   '돈',
#   '이',
#   '들어오다',
#   '곳',
#   '이',
#   '없다',
#   '계약',
#   '연봉',
#   '그',
#   '이상',
#   '그이',
#   '하다',
#   '받다',
#   '함',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '강압',
#   '적',
#   '인',
#   '분위기',
#   '는',
#   '아니다',
#   '가끔',
#   '이벤트',
#   '같다',
#   '진행',
#   '함',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '정규직',
#   '이',
#   '관리자',
#   '만',
#   '있다',
#   '대단하다',
#   '급여',
#   '가',
#   '너무',
#   '짬',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '사람',
#   '서울',
#   '연차',
#   '사용',
#   '눈치',
#   'x',
#   '복지',
#   '카드',
#   '안마',
#   '사내',
#   '카페',
#   '유',
#   '데미',
#   '강좌',
#   '최근',
#   '모니터',
#   '지급',
#   '석식',
#   '지원',
#   '체계',
#   '적',
#   '인',
#   '온보딩',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '무늬',
#   '만',
#   '자율',
#   '출근',
#   '제',
#   '포괄',
#   '임금',
#   '야근',
#   '연봉',
#   '인상',
#   '률',
#   '출장',
#   '파견',
#   '역',
#   '피라미드',
#   '구조',
#   '로',
#   '인하다',
#   '꼰대',
#   '있다',
#   '기',
#   '숧',
#   '스택',
#   '이',
#   '너무',
#   '특이하다',
#   '고여',
#   '서',
#   '이직',
#   '이',
#   '힘들다',
#   '이직',
#   '을',
#   '해도',
#   'SI',
#   '가다',
#   '대부분',
#   'SI',
#   '인',
#   '거',
#   '자체',
#   '만으로',
#   '개발자',
#   '로서',
#   '커리어',
#   '고민',
#   '하다',
#   '함',
#   '레거시',
#   '리팩토링',
#   '프로젝트',
#   '거의',
#   '없다',
#   '부바',
#   '부지',
#   '만',
#   'git',
#   '안',
#   '쓰다',
#   '곳도',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '사람',
#   '들',
#   '이',
#   '좋다',
#   '연차',
#   '이렇다',
#   '눈치',
#   '안보',
#   '고',
#   '걍',
#   '쓰다',
#   '위계',
#   '질서',
#   '이렇다',
#   '없다',
#   '걍',
#   '다',
#   '들다',
#   '다',
#   '좋다',
#   '회사',
#   '이미지',
#   '도',
#   '좋다',
#   '편이',
#   '고',
#   '암튼',
#   '다',
#   '좋다',
#   'IT',
#   '기업',
#   '으로서',
#   '자사',
#   '만의',
#   '솔루션',
#   '을',
#   '지속',
#   '적',
#   '으로',
#   '만들다',
#   '제품',
#   '출시',
#   '하다',
#   '노력',
#   '도',
#   '보기',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   'IT',
#   '개발자',
#   '역량',
#   '키우다',
#   '조금',
#   '힘드다',
#   '곳',
#   'ㅠㅠ',
#   '코로나',
#   '터지다',
#   'SI',
#   '프로젝트',
#   '수주',
#   '보다는',
#   '그래도',
#   '자사',
#   '의',
#   '솔루션',
#   '들',
#   '을',
#   '만들다',
#   '키우다',
#   '노력',
#   '이',
#   '보이',
#   '지만',
#   '그',
#   '솔루션',
#   '에',
#   '들어가다',
#   '기술',
#   '들',
#   '에',
#   '대한',
#   '투자',
#   '는',
#   '굉장하다',
#   '약하다',
#   '그리고',
#   '복지',
#   '와',
#   '연봉',
#   '이',
#   '그래도',
#   '낮다',
#   '많이',
#   '올려주다',
#   '많이',
#   '올려주다',
#   '그래도',
#   '기본',
#   '은',
#   '너무',
#   '낮다',
#   'ㅠㅠ',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '눈치',
#   '보지',
#   '얺',
#   '고',
#   '휴가',
#   '가능하다',
#   '본인',
#   '이',
#   '원하다',
#   '많이',
#   '배우다',
#   '잇다',
#   '곳',
#   '이다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '캐시',
#   '크다',
#   '부재',
#   '천',
#   '어',
#   '라운드',
#   '의',
#   '포인트',
#   '를',
#   '찾아보다',
#   '어렵다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '워',
#   '라벨',
#   '재다',
#   '지키다',
#   '짐',
#   '사람',
#   '들',
#   '좋다',
#   '연차',
#   '눈치',
#   '안',
#   '보다',
#   '헬',
#   '스케',
#   '어',
#   '받다',
#   '광화문',
#   '출퇴근',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '평균',
#   '이하',
#   '의',
#   '연봉',
#   '그룹',
#   '사',
#   '혜택',
#   '없다',
#   '복지',
#   '혜택',
#   '약하다',
#   '은근',
#   '보수',
#   '적',
#   '인',
#   '마인드',
#   '의',
#   '경',
#   '영진',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '회사',
#   '전체',
#   '에',
#   '배려',
#   '가',
#   '있다',
#   '분위기',
#   '팀바팀',
#   '이',
#   '있다',
#   '야근',
#   '도',
#   '필요',
#   '에',
#   '따라서',
#   '만',
#   '하다',
#   '필수',
#   '적',
#   '이진',
#   '않다',
#   '동호회',
#   '가',
#   '자다',
#   '되어다',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '마땅하다',
#   '복지',
#   '도',
#   '없다',
#   '회사',
#   '연봉',
#   '도',
#   '만족하다',
#   '만',
#   '한',
#   '수준',
#   '은',
#   '아니다',
#   '주',
#   '사업',
#   '보다는',
#   '계열',
#   '사의',
#   '성과',
#   '에',
#   '따르다',
#   '영향',
#   '을',
#   '받다',
#   '면',
#   '이',
#   '크다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '직원',
#   '분들',
#   '이',
#   '친절하다',
#   '합리',
#   '적',
#   '이고',
#   '체계',
#   '가',
#   '자다',
#   '잡히다',
#   '있다',
#   '느끼다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '회사',
#   '재정',
#   '이',
#   '어렵다',
#   '돈',
#   '되다',
#   '건',
#   '다',
#   '하다',
#   '느낌',
#   '이',
#   '랄',
#   '끄다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '유연하다',
#   '분위기',
#   '연차',
#   '자유롭다',
#   '사용',
#   '사람',
#   '들',
#   '착하다',
#   '사무실',
#   '접근성',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '잡무',
#   '많다',
#   '연봉',
#   '안',
#   '오르다',
#   '인',
#   '세다',
#   '없다',
#   '개발',
#   '역량',
#   '쌓다',
#   '어려움',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '안마',
#   '를',
#   '저렴하다',
#   '이용',
#   '하다',
#   '사내',
#   '카페',
#   '가',
#   '있다',
#   '김밥',
#   '맛있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '모니터',
#   '자기',
#   '돈',
#   '으로',
#   '구매',
#   '하다',
#   '함',
#   '연봉',
#   '이',
#   '동결',
#   '이라',
#   '근로',
#   '의욕',
#   '상실',
#   '임',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '지하',
#   '2',
#   '층',
#   '에',
#   '사내',
#   '커피숍',
#   '이',
#   '있다',
#   '지하',
#   '1',
#   '층',
#   '에',
#   '시설',
#   '좋다',
#   '사설',
#   '헬스장',
#   '복지',
#   '아니다',
#   '이',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '고',
#   '인물',
#   '파티',
#   '임',
#   '좋다',
#   '건물',
#   '과',
#   '이름',
#   '에',
#   '쉬다',
#   '옮기다',
#   '말다',
#   '네트워크',
#   '중심',
#   '의',
#   '영업',
#   '이라',
#   '혁신',
#   '적',
#   '이라고',
#   '생각',
#   '안',
#   '하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '업무',
#   '강도',
#   '낮다',
#   '편',
#   '에',
#   '공무원',
#   '분위기',
#   '사람',
#   '들',
#   '대체로',
#   '다',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '테이블',
#   '낮다',
#   '사업',
#   '부문',
#   '매출',
#   '규모',
#   '매우',
#   '작',
#   '음지',
#   '원',
#   '실',
#   '은',
#   '대우받다',
#   '못',
#   '하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '는',
#   '편하다',
#   '사용',
#   '하다',
#   '수',
#   '있다',
#   '같이',
#   '일',
#   '하다',
#   '사람',
#   '들',
#   '은',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '거의',
#   '없다',
#   '한',
#   '복지',
#   '연봉',
#   '상승',
#   '이',
#   '없다',
#   '보상',
#   '이',
#   '필요하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '부바',
#   '부',
#   '이지만',
#   '여성',
#   '분',
#   '들',
#   '에겐',
#   '출장',
#   '안',
#   '가다',
#   '해주다',
#   '분위기',
#   '이고',
#   '남자',
#   '면',
#   '출장',
#   '장려',
#   '하다',
#   '여성',
#   '분들',
#   '이',
#   '다니다',
#   '기',
#   '엔',
#   '좋다',
#   '것',
#   '같다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '꼰대',
#   '문화',
#   '는',
#   '없다',
#   '아직',
#   '회사',
#   '사업',
#   '성',
#   '이',
#   '부족하다',
#   '자본금',
#   '이',
#   '없다',
#   '남성',
#   '들',
#   '은',
#   'si',
#   '특성',
#   '상',
#   '출장',
#   '을',
#   '고려',
#   '하다',
#   '하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '약',
#   '백만원',
#   '상당',
#   '의',
#   '복지',
#   '카드',
#   '급여',
#   '는',
#   '밀리',
#   '지',
#   '않다',
#   '인',
#   '서울',
#   '같다',
#   '팀',
#   '같다',
#   '파트',
#   '의',
#   '인원',
#   '들',
#   '은',
#   '좋다',
#   '사람',
#   '들',
#   '이',
#   '많다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '낮다',
#   '연봉',
#   '젊다',
#   '꼰대들',
#   '이',
#   '많다',
#   '목소리',
#   '크다',
#   '사람',
#   '이',
#   '이기다',
#   '사내',
#   '정치',
#   '심하다',
#   '30',
#   '의',
#   '확률',
#   '로',
#   '연봉',
#   '동결',
#   '관리자',
#   '와',
#   '실무',
#   '자의',
#   '커뮤니케이션',
#   '단절',
#   '결정',
#   '되다',
#   '알다',
#   '심지어',
#   '안',
#   '알다',
#   '줄때',
#   '도',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '헬',
#   '스케',
#   '어',
#   '카페테리아',
#   '웅진',
#   '플레이도',
#   '시',
#   '복지',
#   '카드',
#   '서울',
#   '중심부',
#   '케이',
#   '스퀘어',
#   '새',
#   '빌딩',
#   '에',
#   '오다',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '근처',
#   '밥값',
#   '이',
#   '바',
#   '싸다',
#   '딱하다',
#   '크다',
#   '복지',
#   '는',
#   '없다',
#   '같다',
#   '개인주의',
#   '성향',
#   '이',
#   '있다',
#   '경력',
#   '입사',
#   '자',
#   '를',
#   '자다',
#   '안',
#   '챙기다',
#   '줌',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '눈치',
#   '껏',
#   '쓸다',
#   '복지',
#   '카드',
#   '도',
#   '있다',
#   '성장하다',
#   '밀다',
#   '하다',
#   '듯',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '중간',
#   '급',
#   '이',
#   '거의',
#   '없다',
#   '신입',
#   '천지',
#   '임',
#   '경력',
#   '은',
#   '다',
#   '나가다',
#   '신입',
#   '축제',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '헬',
#   '스케',
#   '어',
#   '좋다',
#   '대부분',
#   '사람',
#   '들',
#   '이',
#   '착하다',
#   '청계천',
#   '이',
#   '바로',
#   '앞',
#   '이라',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '은',
#   '업계',
#   '평균',
#   '수준',
#   '이라',
#   '불만',
#   '은',
#   '없다',
#   '워',
#   '라',
#   '밸',
#   '은',
#   '부바',
#   '부',
#   '장담',
#   '하다',
#   '수',
#   '없다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '를',
#   '사용',
#   '함',
#   '에',
#   '있다',
#   '눈치',
#   '가',
#   '없다',
#   '모',
#   '난사람',
#   '이',
#   '없다',
#   '두루',
#   '두루',
#   '친하다',
#   '지내다',
#   '회사',
#   '분위기',
#   '가',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '성',
#   '과금',
#   '이나',
#   '명절',
#   '떡값',
#   '연봉',
#   '의',
#   '아쉬움',
#   '이',
#   '크다',
#   '아무래도',
#   '성장하다',
#   '기업',
#   '이다',
#   '보다',
#   '직원',
#   '들',
#   '에게',
#   '돌아오다',
#   '혜택',
#   '이나',
#   '성과',
#   '에',
#   '대한',
#   '보상',
#   '이',
#   '적다',
#   '편입',
#   '니',
#   '다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '에',
#   '대한',
#   '부담',
#   '없다',
#   '물론',
#   '하다',
#   '일',
#   '에',
#   '문제',
#   '가',
#   '없다',
#   '전제',
#   '하',
#   '에',
#   '중견',
#   '기업',
#   '문화',
#   '가',
#   '있다',
#   '나름',
#   '의',
#   '존중',
#   '이',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '명절',
#   '떡값',
#   '없다',
#   '수사',
#   '원',
#   '이라고',
#   '해도',
#   '몇십',
#   '만원',
#   '정도',
#   '수준',
#   '관련',
#   '직종',
#   '회사',
#   '들',
#   '에',
#   '비다',
#   '좀',
#   '연봉',
#   '을',
#   '더',
#   '올려주다',
#   '필요',
#   '가',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '사내',
#   '건강',
#   '지원',
#   '시각장애인',
#   '마사지',
#   '자기계발',
#   '비',
#   '지원',
#   '연차',
#   '에',
#   '따르다',
#   '다르다',
#   '웅진',
#   '플레이',
#   '도시',
#   '이용',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '프로젝트',
#   '진행',
#   '시',
#   '야근',
#   '신청',
#   '이',
#   '주',
#   '52시간',
#   '제한',
#   '적',
#   '이라',
#   '자기',
#   '의지',
#   '로',
#   '인하다',
#   '근무',
#   '열정',
#   '페이',
#   '를',
#   '하다',
#   '함',
#   '가끔',
#   '특이',
#   '케이스',
#   '존재',
#   '하나',
#   '본인',
#   '이',
#   '알다',
#   '알아보다',
#   '본부장',
#   '이상',
#   '결재',
#   '나',
#   '야하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '적당하다',
#   '근로',
#   '강도',
#   '와',
#   '워',
#   '라',
#   '밸',
#   '을',
#   '강조',
#   '하다',
#   '문화',
#   '를',
#   '추구',
#   '함',
#   '역사',
#   '가',
#   '있다',
#   '회사',
#   '임',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '역사',
#   '에',
#   '의존',
#   '하다',
#   '과거',
#   '지향',
#   '적',
#   '기업',
#   '새',
#   '로움',
#   '에',
#   '대해',
#   '도전',
#   '하고',
#   '추구',
#   '하다',
#   '나가다',
#   '고',
#   '인물',
#   '이',
#   '너무나도',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '많다',
#   '이',
#   '들',
#   '이',
#   'IT',
#   '회사',
#   '인',
#   '줄',
#   '모르다',
#   'ERP',
#   '이력',
#   '이',
#   '탄탄하다',
#   '기업',
#   '지하',
#   '카페',
#   '있다',
#   '출퇴근',
#   '이',
#   '편하다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '급여',
#   '에',
#   '있다',
#   '주변',
#   '과',
#   '맞다',
#   '않다',
#   '테이블',
#   '이며',
#   '올드',
#   '한',
#   '마인드',
#   '가',
#   '아직',
#   '존재',
#   '고',
#   '인물',
#   '파티',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '휴가',
#   '편하다',
#   '쓸다',
#   '사람',
#   '간',
#   '관계',
#   '분위기',
#   '좋다',
#   '업무',
#   '난이도',
#   '낮다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '직원',
#   '들',
#   '의',
#   '실력',
#   '이',
#   '낮다',
#   '외주',
#   '인력',
#   '으로',
#   '채우다',
#   '운영',
#   '하다',
#   '함그',
#   '에',
#   '대한',
#   '보상',
#   '이',
#   '없다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '자기',
#   '계발',
#   '비용',
#   '지원',
#   '1년',
#   '주기',
#   '건강검진',
#   '지원',
#   '11시',
#   '40분',
#   '부터',
#   '점심시간',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '포괄',
#   '이라서',
#   '야근',
#   '이나',
#   '휴일',
#   '수당',
#   '받다',
#   '어렵다',
#   '보너스',
#   '나',
#   '성과급',
#   '이',
#   '없다',
#   '아쉬움',
#   '연봉',
#   '인상',
#   '어려움',
# ...
#   '낮다',
#   '연봉',
#   '팀',
#   '바이',
#   '팀',
#   '업무',
#   '의',
#   '불균형',
#   '팀',
#   '에',
#   '따르다',
#   '야근',
#   '을',
#   '당',
#   '연',
#   '시',
#   '여기',
#   '는',
#   '분위기',
#   '쓸데없다',
#   '정치',
#   '질',
#   '을',
#   '하다',
#   '본인',
#   '들',
#   '만의',
#   '친목',
#   '을',
#   '만들다',
#   '일부',
#   '의',
#   '사람',
#   '들',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '업무',
#   '적',
#   '인',
#   '역량',
#   '이',
#   '있다',
#   '신입',
#   '이라도',
#   '업무',
#   '를',
#   '자유롭다',
#   '하다',
#   '수',
#   '있다',
#   '본인',
#   '의',
#   '역량',
#   '을',
#   '펴다',
#   '치기',
#   '가',
#   '쉬움',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '부바',
#   '부다',
#   '또한',
#   '이렇다',
#   '것',
#   '을',
#   '선호',
#   '하다',
#   '수',
#   '있다',
#   '부서',
#   '별로',
#   '묶이다',
#   '맡다',
#   '프로젝트',
#   '가',
#   '다르다',
#   '소통',
#   '의',
#   '기회',
#   '가',
#   '적다',
#   '가장',
#   '크다',
#   '단점',
#   '은',
#   '신입',
#   '을',
#   '많이',
#   '뽑다',
#   '또한',
#   '그',
#   '분들',
#   '이',
#   '많이',
#   '퇴사',
#   '하',
#   '심다',
#   '일이',
#   '빡세',
#   '서',
#   '이다',
#   '급여',
#   '가',
#   '많이',
#   '낮다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '공채',
#   '들',
#   '은',
#   '일',
#   '을',
#   '배우다',
#   '좋다',
#   '조건',
#   '경력',
#   '직',
#   '은',
#   '알다',
#   '살아나다',
#   '함',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '쥐꼬리',
#   '만',
#   '한',
#   '월급',
#   '이정',
#   '도',
#   '강도',
#   '이정',
#   '도',
#   '능력',
#   '이면',
#   '다른',
#   '곳',
#   '은',
#   '최소',
#   '1000만원',
#   '더',
#   '받다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '당일',
#   '돌발',
#   '연차',
#   '제도',
#   '운영',
#   '나름',
#   '체계',
#   '가',
#   '잡히다',
#   '공채',
#   '제도',
#   '사옥',
#   '의',
#   '지리',
#   '적',
#   '접근성',
#   '대',
#   '외적',
#   '이미지',
#   '기',
#   '혼자',
#   '에게',
#   '좋다',
#   '복지',
#   '제도',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '과거',
#   '의',
#   '영광',
#   '속',
#   '에서',
#   '순진하다',
#   '업계',
#   '신입',
#   '들',
#   '과',
#   '3',
#   '4년',
#   '차',
#   '애매하다',
#   '경력',
#   '직',
#   '들',
#   '의',
#   '환상',
#   '으로',
#   '존립',
#   '하고',
#   '있다',
#   '대',
#   '행사',
#   '아예',
#   '다른',
#   '회사',
#   '라',
#   '해도',
#   '무방',
#   '하다',
#   '정도',
#   '로',
#   '팀별',
#   '조',
#   '직문',
#   '화',
#   '가',
#   '다르다',
#   '구성원',
#   '들',
#   '의',
#   '성향',
#   '과',
#   '업무',
#   '역량',
#   '도',
#   '천차만별',
#   '임',
#   '인사',
#   '적',
#   '체',
#   '되다',
#   '임원진',
#   '들',
#   '은',
#   '인력',
#   '운영',
#   '에',
#   '무관심하다',
#   '그',
#   '들',
#   '간의',
#   '반',
#   '목',
#   '과',
#   '불화',
#   '정치',
#   '질',
#   '에',
#   '힘',
#   '을',
#   '쏟다',
#   '때문',
#   '에',
#   '직원',
#   '들',
#   '이',
#   '소',
#   '속',
#   '감',
#   '을',
#   '느끼다',
#   '규합',
#   '되다',
#   '만무',
#   '10',
#   '명',
#   '이하',
#   '대',
#   '행사',
#   '에서',
#   '하',
#   '듯이',
#   '이',
#   '곳',
#   '역시',
#   '사원',
#   '대리',
#   '에게',
#   '과도',
#   '한',
#   '오',
#   '너',
#   '십',
#   '을',
#   '부여',
#   '한',
#   '다',
#   '반면',
#   '과',
#   '차장',
#   '급',
#   '부터는',
#   '제',
#   '역할',
#   '을',
#   '하다',
#   '수수방관',
#   '상부',
#   '에',
#   '아첨',
#   '하고',
#   '자기과시',
#   '욕',
#   '이',
#   '매우',
#   '강하다',
#   '전형',
#   '적',
#   '인',
#   '여우',
#   '스타일',
#   '의',
#   '직원',
#   '들',
#   '이',
#   '인정받다',
#   '조직',
#   '으로',
#   '묵묵하다',
#   '성실하다',
#   '일',
#   '하다',
#   '사람',
#   '들',
#   '은',
#   '일',
#   '을',
#   '하다',
#   '하다',
#   '후려치다',
#   '당하다',
#   '개인주의',
#   '로',
#   '둔갑',
#   '되다',
#   '무한',
#   '이기주의',
#   '가',
#   '팽배',
#   '한',
#   '집단',
#   '으로',
#   '어느',
#   '정도',
#   '무시',
#   '못',
#   '하다',
#   '연차',
#   '가',
#   '쌓이다',
#   '기혼',
#   '경력',
#   '직',
#   '이',
#   '독고',
#   '다이로',
#   '월',
#   '루하',
#   '며',
#   '다니다',
#   '좋다',
#   '기업',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '연차',
#   '자유롭다',
#   '사용',
#   '가능',
#   '팀바팀',
#   '이지만',
#   '자유롭다',
#   '분위기',
#   '터치',
#   '안함',
#   '크다',
#   '규모',
#   '의',
#   '프로젝트',
#   '고객',
#   '사가',
#   '많다',
#   '첫',
#   '직장',
#   '으로',
#   '레퍼',
#   '쌓다',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '단점',
#   '1',
#   '연봉',
#   '단점',
#   '2',
#   '연봉',
#   '단점',
#   '3',
#   '연봉',
#   '연봉',
#   '낮다',
#   '직급',
#   '수당',
#   '상여',
#   '인',
#   '세다',
#   '없다',
#   '아',
#   '인',
#   '세다',
#   '봉투',
#   '주다',
#   '하다',
#   '너무',
#   '적다',
#   '인',
#   '세다',
#   '말',
#   '하다',
#   '싫다',
#   '고',
#   '인물',
#   '이',
#   '많다',
#   '아래',
#   '만',
#   '계속',
#   '바뀌다',
#   '디지털',
#   '인력',
#   '부족',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '야근',
#   '식대',
#   '제공',
#   '팀',
#   '에',
#   '따르다',
#   '분위기',
#   '가',
#   '다르다',
#   '근무',
#   '분위기',
#   '좋다',
#   '편',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '대',
#   '행사',
#   '라는',
#   '한계',
#   '로',
#   '실제',
#   '진행',
#   '하다',
#   '업무',
#   '가',
#   '클라이언트',
#   '실무',
#   '자의',
#   '의사',
#   '에',
#   '따르다',
#   '좌지우지',
#   '되다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '커리어',
#   '쌓다',
#   '좋다',
#   'PR',
#   '사관학교',
#   '다운',
#   '면모',
#   '를',
#   '볼',
#   '수',
#   '있다',
#   '그래도',
#   '외부',
#   '에서',
#   '보다',
#   '홍보',
#   '계',
#   '의',
#   '삼성',
#   '이다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '고',
#   '인물',
#   '천지',
#   '라',
#   '뭘',
#   '어찌',
#   '하다',
#   '안',
#   '바뀌다',
#   '절대',
#   '안',
#   '바뀌다',
#   '그냥',
#   '고생',
#   '고',
#   '생해',
#   '서',
#   '경력',
#   '쌓다',
#   '이직',
#   '하다',
#   '답일',
#   '수도',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '복지',
#   '가',
#   '중소기업',
#   '치고는',
#   '꽤',
#   '자다',
#   '돼다',
#   '때문',
#   '에',
#   '기',
#   '혼자',
#   '가',
#   '안정',
#   '적',
#   '으로',
#   '다니다',
#   '기다',
#   '좋다',
#   '그만큼',
#   '오래',
#   '버티다',
#   '사람',
#   '은',
#   '없다',
#   '누리다',
#   '사람',
#   '은',
#   '많다',
#   '않다',
#   '듯',
#   '소규모',
#   '로',
#   '시작',
#   '하다',
#   '성장하다',
#   '기업',
#   '이다',
#   '보다',
#   '베다',
#   '처',
#   '문화',
#   '와',
#   '대기업',
#   '문화',
#   '가',
#   '공존',
#   '자다',
#   '맞다',
#   '괜찮다',
#   '듯',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '규모',
#   '나',
#   '하다',
#   '일',
#   '에',
#   '비다',
#   '월급',
#   '이',
#   '많다',
#   '않다',
#   '그',
#   '에',
#   '비다',
#   '공채',
#   '시험',
#   '은',
#   '어마',
#   '무시',
#   '한',
#   '깐깐하다',
#   '자랑',
#   '야근',
#   '이',
#   '많다',
#   '직종',
#   '인데',
#   '도',
#   '야근',
#   '수당',
#   '이',
#   '없다',
#   '보람',
#   '이',
#   '크다',
#   '않다',
#   '팀',
#   '바이',
#   '팀',
#   '이지만',
#   '야근',
#   '하다',
#   '사람',
#   '만',
#   '주',
#   '구',
#   '장창',
#   '야근',
#   '미혼',
#   '이',
#   '누리다',
#   '수',
#   '있다',
#   '복지',
#   '가',
#   '적다',
#   '아니다',
#   '거의',
#   '없다',
#   '보다',
#   '되다',
#   '듯',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '국내',
#   '1',
#   '위',
#   'pr',
#   '기업',
#   '이',
#   '것',
#   '저',
#   '것',
#   '다양하다',
#   '해보다',
#   '순',
#   '있다',
#   '메뉴얼',
#   '은',
#   '없다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '이',
#   '너무',
#   '낮다',
#   '팀바팀',
#   '으로',
#   '워',
#   '라',
#   '밸',
#   '측정',
#   '하다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '젊다',
#   '조직',
#   '이다',
#   '보다',
#   '상하',
#   '관계',
#   '의',
#   '보수',
#   '적',
#   '인',
#   '문화',
#   '는',
#   '없다',
#   '물론',
#   '팀',
#   '과',
#   '상사',
#   '에',
#   '따르다',
#   '개인',
#   '차다',
#   '있다',
#   '전반',
#   '적',
#   '인',
#   '조',
#   '직문',
#   '화',
#   '는',
#   '젊다',
#   '오픈',
#   '되다',
#   '편',
#   '홍보',
#   '업계',
#   '에서',
#   '인지도',
#   '있다',
#   '크다',
#   '규모',
#   '의',
#   '회사',
#   '라',
#   '크다',
#   '클라이언트',
#   '와',
#   '일',
#   '하다',
#   '있다',
#   '기회',
#   '가',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '팀',
#   '마다',
#   '격차',
#   '가',
#   '크다',
#   '일',
#   '하다',
#   '스타일',
#   '부터',
#   '클라이언트',
#   '종류',
#   '나',
#   '규모',
#   '까지',
#   '팀별',
#   '격차',
#   '가',
#   '커서',
#   '누구',
#   '는',
#   '행복하다',
#   '회사',
#   '생활',
#   '누구',
#   '는',
#   '힘드다',
#   '회사',
#   '생활',
#   '이',
#   '되다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '본인',
#   '의',
#   '의지',
#   '만',
#   '있다',
#   '일',
#   '은',
#   '정말',
#   '제대로',
#   '자다',
#   '배우다',
#   '수',
#   '있다',
#   '자유롭다',
#   '분위기',
#   '출퇴근',
#   '시간',
#   '이나',
#   '자리',
#   '를',
#   '지키다',
#   '것',
#   '보다',
#   '주어지다',
#   '일',
#   '을',
#   '자다',
#   '해내다',
#   '데',
#   '집중',
#   '함',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '전반',
#   '적',
#   '으로',
#   '자유',
#   '롭고',
#   '활기차다',
#   '분위기',
#   '속',
#   '에',
#   '은근',
#   '꼰대',
#   '마인드',
#   '경',
#   '영진',
#   '나',
#   '의',
#   '5년',
#   '후',
#   '10년',
#   '후',
#   '가',
#   '저',
#   '모습',
#   '이다',
#   '하다',
#   '고민',
#   '에',
#   '이직',
#   '률',
#   '이',
#   '높다',
#   '원년',
#   '멤버',
#   '에',
#   '대한',
#   '의존',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '일',
#   '을',
#   '미치다',
#   '경험',
#   '해보다',
#   '수',
#   '있다',
#   '함께',
#   '일',
#   '하다',
#   '분',
#   '들',
#   '이',
#   '업무',
#   '에',
#   '대한',
#   '프라',
#   '우드',
#   '가',
#   '높다',
#   '공채',
#   '제도',
#   '가',
#   '있다',
#   '동기',
#   '들',
#   '이',
#   '있다',
#   '점',
#   '이',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '굳이',
#   '왜',
#   '프레',
#   '인',
#   '에서',
#   '일',
#   '하다',
#   '대한',
#   '답',
#   '이',
#   '없다',
#   '급하다',
#   '경력',
#   '을',
#   '쌓다',
#   '야하다',
#   '케이스',
#   '라면',
#   '인정',
#   '하',
#   '지만',
#   '오래',
#   '다니다',
#   '좋다',
#   '직장',
#   '은',
#   '절대',
#   '아니다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '팀',
#   '마다',
#   '다르다',
#   '야근',
#   '하다',
#   '분위기',
#   '는',
#   '아니다',
#   '대',
#   '행사',
#   '에서',
#   '삶',
#   '과',
#   '일',
#   '의',
#   '균형',
#   '을',
#   '찾다',
#   '게',
#   '쉬다',
#   '않다',
#   '프레',
#   '인',
#   '은',
#   '가능하다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '노',
#   '는',
#   '사람',
#   '너무',
#   '많다',
#   '일도',
#   '하다',
#   '사람',
#   '만',
#   '함',
#   '조금',
#   '더',
#   '직원',
#   '들',
#   '신경',
#   '써주다',
#   '이직',
#   '률',
#   '이',
#   '낮다',
#   '않다',
#   '여',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '좋다',
#   '임원',
#   '분들',
#   '특히',
#   '여',
#   '성',
#   '임원',
#   '분들',
#   '이',
#   '많다',
#   '부서',
#   '에',
#   '따르다',
#   '수평',
#   '적',
#   '이고',
#   '편하다',
#   '분위기',
#   '에서',
#   '일',
#   '하다',
#   '것',
#   '이',
#   '가능하다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '연봉',
#   '이',
#   '업계',
#   '의',
#   '비슷하다',
#   '규모',
#   '의',
#   '에이전시',
#   '대비',
#   '너무',
#   '낮다',
#   '그리고',
#   '설립',
#   '자의',
#   '마인드',
#   '가',
#   '쿨하다',
#   '척',
#   '하지만',
#   '하나',
#   '도',
#   '안',
#   '쿨하다',
#   '합리',
#   '적',
#   '인척',
#   '하지만',
#   '하나',
#   '도',
#   '안',
#   '합리',
#   '적',
#   '인',
#   '면',
#   '이',
#   '많다',
#   '스트레스',
#   '받다',
#   '때',
#   '가',
#   '많다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '팀바팀',
#   '이라고',
#   '일',
#   '잘',
#   '하다',
#   '팀',
#   '원',
#   '만나다',
#   '좋다',
#   '거',
#   '같다',
#   '맨날',
#   '야근',
#   '하다',
#   '일',
#   '은',
#   '빨리',
#   '배우다',
#   '수',
#   '있다',
#   '신입',
#   '이든',
#   '인턴',
#   '이든',
#   '경력',
#   '이든',
#   '뭐',
#   '든',
#   '들어오다',
#   '자기',
#   '업무',
#   '를',
#   '맡다',
#   '진행',
#   '하다',
#   '경험',
#   '이',
#   '있다',
#   '건',
#   '장점',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '내',
#   '가',
#   '속',
#   '한',
#   '회사',
#   '에',
#   '대한',
#   '애정',
#   '이',
#   '있다',
#   '직원',
#   '이',
#   '안',
#   '보이다',
#   '회사',
#   '에',
#   '자부심',
#   '을',
#   '가지',
#   '고',
#   '일',
#   '을',
#   '하다',
#   '수',
#   '있다',
#   '분위기',
#   '면',
#   '만족하다',
#   '그렇다',
#   '분위기',
#   '전혀',
#   '아니다',
#   '다',
#   '들다',
#   '언제',
#   '튀다',
#   '고민',
#   '중',
#   '인',
#   '느낌',
#   '단순하다',
#   '중소기업',
#   '이라서',
#   '라고',
#   '하다',
#   '문제',
#   '가',
#   '아니다',
#   '홍보',
#   '일',
#   '을',
#   '좋아하다',
#   '사람',
#   '이면',
#   '모르다',
#   '회사',
#   '때문',
#   '에',
#   '다니다',
#   '맘',
#   '은',
#   '안',
#   '들',
#   '게',
#   '해주다',
#   '회사',
#   '라는',
#   '게',
#   '가장',
#   '크다',
#   '단점',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '비교',
#   '적',
#   '자유롭다',
#   '연차',
#   '사용',
#   '유연',
#   '적',
#   '인',
#   '출퇴근',
#   '시간',
#   '수평',
#   '적',
#   '조직',
#   '구조',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '명성',
#   '에',
#   '못',
#   '미치다',
#   '연봉',
#   '개인주의',
#   '적',
#   '인',
#   '분위기',
#   '로',
#   '때로는',
#   '경력',
#   '입',
#   '사자',
#   '들',
#   '은',
#   '조직',
#   '적응하다',
#   '쉬다',
#   '않다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '수평',
#   '적',
#   '인',
#   '조직',
#   '문화',
#   '팀바팀',
#   '이지만',
#   '전반',
#   '적',
#   '으로',
#   '워',
#   '라',
#   '밸',
#   '좋다',
#   '편',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '일부',
#   '팀',
#   '제외',
#   '하고',
#   '연봉',
#   '이',
#   '높다',
#   '않다',
#   '매출',
#   '대비',
#   '하다',
#   '낮다',
#   '편',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '자유롭다',
#   '연차',
#   '사용',
#   '영업',
#   '압박',
#   '이',
#   '거의',
#   '없다',
#   '기',
#   '혼자',
#   '를',
#   '위',
#   '한',
#   '복지',
#   '가',
#   '자다',
#   '갖추다',
#   '있다',
#   '홍보',
#   '업계',
#   '에서',
#   '마지막',
#   '회사',
#   '로',
#   '다니다',
#   '좋다',
#   '곳',
#   '여',
#   '성',
#   '직원',
#   '이',
#   '절대다수',
#   '라',
#   '개인주의',
#   '적',
#   '성향',
#   '이',
#   '강하다',
#   '수직',
#   '적',
#   '인',
#   '위계',
#   '질서',
#   '가',
#   '부담스럽다',
#   '사람',
#   '들',
#   '이',
#   '다니다',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '무능력하다',
#   '게으르다',
#   '과',
#   '차장',
#   '급',
#   '인력',
#   '이',
#   '많다',
#   '실무',
#   '는',
#   '사원',
#   '대리',
#   '중심',
#   '으로',
#   '인력',
#   '을',
#   '갈아',
#   '넣다',
#   'PM',
#   '처럼',
#   '일',
#   '하다',
#   '요구',
#   '하다',
#   '분위기',
#   '연봉',
#   '적',
#   '은',
#   '실무',
#   '자',
#   '들',
#   '에게는',
#   '오',
#   '너',
#   '십',
#   '을',
#   '강조',
#   '하다',
#   '정작',
#   'PM',
#   '역할',
#   '을',
#   '하다',
#   '하다',
#   '사람',
#   '은',
#   '무책임하다',
#   '역량',
#   '이',
#   '부족하다',
#   '강',
#   '건너',
#   '불',
#   '구경',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '비교',
#   '적',
#   '자유롭다',
#   '연차',
#   '사용',
#   '직원',
#   '연령',
#   '대',
#   '낮다',
#   '공유',
#   '오피스',
#   '로',
#   '이사',
#   '하고',
#   '접근성',
#   '이나',
#   '업무',
#   '환경',
#   '크게',
#   '개선',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '경직',
#   '되다',
#   '분위기',
#   '업',
#   '무량',
#   '많다',
#   '저녁',
#   '약속',
#   '불가능',
#   '기',
#   '혼자',
#   '가',
#   '아니다',
#   '체감',
#   '하다',
#   '수',
#   '없다',
#   '복지',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '함께',
#   '일',
#   '하다',
#   '사람',
#   '이',
#   '누구',
#   '냐',
#   '에',
#   '따르다',
#   '다르다',
#   '수',
#   '있다',
#   '전반',
#   '적',
#   '인',
#   '기업',
#   '분위기',
#   '는',
#   '딱딱하다',
#   '수직',
#   '적',
#   '이진',
#   '않다',
#   '것',
#   '같다',
#   '여러',
#   '분야',
#   '의',
#   '업무',
#   '를',
#   '경험',
#   '해보다',
#   '수',
#   '있다',
#   '것',
#   '은',
#   '좋다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '전반',
#   '적',
#   '인',
#   '복지',
#   '가',
#   '좀',
#   '아쉽다',
#   '느껴지다',
#   '크다',
#   '대기업',
#   '아니다',
#   '이상',
#   '이',
#   '정도',
#   '면',
#   '준수',
#   '한',
#   '편',
#   '인',
#   '것',
#   '같다',
#   '하다',
#   '다만',
#   '행정',
#   '적',
#   '인',
#   '면',
#   '에서',
#   '주먹구구',
#   '식',
#   '인',
#   '것',
#   '처럼',
#   '느껴지다',
#   '수도',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '개인',
#   '의',
#   '능력',
#   '을',
#   '마음껏',
#   '펼치다',
#   '수',
#   '있다',
#   '독특하다',
#   '대표',
#   '로',
#   '인하다',
#   '티나',
#   '는',
#   '기업',
#   '문화',
#   '를',
#   '누리다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '회사',
#   '내',
#   '정치',
#   '판이',
#   '있다',
#   '보여주다',
#   '식',
#   '복지',
#   '가',
#   '많다',
#   '위아래',
#   '가',
#   '없다',
#   '잘',
#   '보다',
#   '이기',
#   '식',
#   '아부',
#   '만',
#   '판',
#   '을',
#   '침',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '공유',
#   '오피스',
#   '의',
#   '쾌적',
#   '하다',
#   '근무',
#   '환경',
#   '팀',
#   '마다',
#   '다르다',
#   '본인',
#   '이',
#   '속',
#   '한',
#   '팀',
#   '은',
#   '개인',
#   '에게',
#   '과도',
#   '한',
#   '업무',
#   '를',
#   '부여',
#   '하다',
#   '않다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '대',
#   '행사',
#   '특성',
#   '일',
#   '수',
#   '있다',
#   '같다',
#   '프레',
#   '인',
#   '안',
#   '에서도',
#   '팀',
#   '간',
#   '차이',
#   '가',
#   '심하다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '자유롭다',
#   '연차',
#   '사용',
#   '출근시간',
#   '을',
#   '8',
#   '30',
#   '9',
#   '30',
#   '사이',
#   '로',
#   '정',
#   '하다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '홍보',
#   '대',
#   '행사',
#   '들',
#   '특징',
#   '이겠다',
#   '클라이언트',
#   '들',
#   '이',
#   '요구',
#   '하다',
#   '것',
#   '들',
#   '을',
#   '너무',
#   '다',
#   '들어주다',
#   '팀',
#   '원',
#   '들이다',
#   '죽다',
#   '신경안',
#   '쓰다',
#   '클라이언트',
#   '요구',
#   '만',
#   '다',
#   '맞추다',
#   '대',
#   '외적인',
#   '이미지',
#   '는',
#   '좋다',
#   '내부',
#   '불만',
#   '은',
#   '커지다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '다양하다',
#   '클라이언트',
#   '를',
#   '담당',
#   '해보다',
#   '있다',
#   '커리어',
#   '개발',
#   '하다',
#   '좋다',
#   '자유롭다',
#   '분위기',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '원하다',
#   '클라이언트',
#   '를',
#   '담당',
#   '하다',
#   '쉬다',
#   '않다',
#   '비딩',
#   '에',
#   '대한',
#   '압박',
#   '있다',
#   '상사',
#   '팀원',
#   '들',
#   '에',
#   '따르다',
#   '팀',
#   '분위기',
#   '나',
#   '커리어',
#   '개발',
#   '에',
#   '있다',
#   '지장',
#   '이',
#   '있다',
#   '있다',
#   '회사',
#   '네',
#   '임밸류',
#   '치고',
#   '연봉',
#   '은',
#   '제각각',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ['(',
#   '긍정',
#   ')',
#   '대다수',
#   '가',
#   '30',
#   '대다',
#   '중반',
#   '을',
#   '넘다',
#   '않다',
#   '때문',
#   '에',
#   '꼰대',
#   '문화',
#   '가',
#   '덜하다',
#   '쉬다',
#   '땐',
#   '쉬',
#   '고',
#   '일',
#   '하다',
#   '땐',
#   '일',
#   '하자',
#   '는',
#   '합리',
#   '적',
#   '인',
#   '분위기',
#   '내',
#   '가',
#   '있다',
#   '팀',
#   '은',
#   '업무',
#   '적',
#   '특성',
#   '덕분',
#   '에',
#   '다양하다',
#   '회사',
#   '들',
#   '과',
#   '일',
#   '하다',
#   '수',
#   '있다',
#   '경력',
#   '을',
#   '쌓다',
#   '갈다',
#   '수',
#   '있다',
#   '장점',
#   '이',
#   '있다',
#   '내',
#   '가',
#   '속',
#   '하다',
#   '팀',
#   '이',
#   '대형',
#   '고객',
#   '사',
#   '대기업',
#   '이면',
#   '멋지다',
#   '커리어',
#   '를',
#   '만들다',
#   '갈다',
#   '수',
#   '있다',
#   '물론',
#   '그만큼',
#   '일',
#   '의',
#   '강도',
#   '가',
#   '높다',
#   '뜻',
#   '이다',
#   '그래도',
#   '년',
#   '차갑다',
#   '적다',
#   '사원',
#   '에겐',
#   '좋다',
#   '직업',
#   '같다',
#   '학력',
#   '도',
#   '높다',
#   '능력',
#   '도',
#   '좋다',
#   '사람',
#   '들',
#   '이',
#   '많다',
#   '배우다',
#   '게',
#   '많다',
#   '.',
#   '(/',
#   '긍정',
#   ').',
#   '(',
#   '부정',
#   ')',
#   '복지',
#   '가',
#   '없다',
#   '것',
#   '이',
#   '문제',
#   '이다',
#   '트렌드',
#   '쫓다',
#   '직업',
#   '이기',
#   '에',
#   '도서',
#   '포인트',
#   '라도',
#   '주다',
#   '하다',
#   '그렇다',
#   '소소하다',
#   '즐거움',
#   '조차',
#   '없다',
#   '추석',
#   '설',
#   '에도',
#   '상여금',
#   '없이',
#   '선물',
#   '만',
#   '주다',
#   '이',
#   '마저도',
#   '자기',
#   '가',
#   '집',
#   '에',
#   '들다',
#   '가야',
#   '함',
#   '월급',
#   '이',
#   '정말',
#   '적다',
#   '대기업',
#   '에서',
#   '어시스턴트',
#   '로',
#   '일',
#   '하다',
#   '친구',
#   '랑',
#   '월급',
#   '이',
#   '같다',
#   '수준',
#   '돈',
#   '을',
#   '많이',
#   '벌다',
#   '싶다',
#   '이',
#   '곳',
#   '으로는',
#   '발도',
#   '들이다',
#   '서다',
#   '안되다',
#   '한국',
#   '에는',
#   'pr',
#   '업체',
#   '를',
#   '동등',
#   '한',
#   '위치',
#   '로',
#   '놓다',
#   '일',
#   '하다',
#   '심부름',
#   '업체',
#   '처럼',
#   '부리다',
#   '기업',
#   '들',
#   '이',
#   '종종',
#   '있다',
#   '현',
#   '타',
#   '를',
#   '맞다',
#   '수',
#   '있다',
#   '.',
#   '(/',
#   '부정',
#   ')'],
#  ...]

# %%
print('리뷰의 평균 길이 :',sum(map(len, train))/len(train))
# Out:
# 리뷰의 평균 길이 : 73.08132543839672
