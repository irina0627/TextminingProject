# %%
import pandas as pd
import re
from pandas import DataFrame

# %%
df = pd.read_csv('./gongo_preprocessing1.csv',encoding = 'utf-8')
print(len(df))
# Out:
# 5744

# %%
df["index"] = df.index

# %%
for i, string in enumerate(df['주요 업무']):
    if type(string)!=str:
        continue
    else:
        df['주요 업무'][i] = re.compile(r'[^\w\s]').sub('',string)
# Out:
# C:\Users\Andlab\AppData\Local\Temp\ipykernel_7728\185607077.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['주요 업무'][i] = re.compile(r'[^\w\s]').sub('',string)

# %%
for i, string in enumerate(df['자격요건 및 우대사항']):
    if type(string)!=str:
        continue
    else:
        df['자격요건 및 우대사항'][i] = re.compile(r'[^\w\s]').sub('',string)
# Out:
# C:\Users\Andlab\AppData\Local\Temp\ipykernel_7728\3310608402.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['자격요건 및 우대사항'][i] = re.compile(r'[^\w\s]').sub('',string)

# %%
# 'ㆍ'제거
df["주요 업무"] = df["주요 업무"].str.replace(pat=r'[ㆍ]', repl=r'', regex=True)
df['주요 업무']

df["자격요건 및 우대사항"] = df["자격요건 및 우대사항"].str.replace(pat=r'[ㆍ]', repl=r'', regex=True)
df['자격요건 및 우대사항']

# '\n'제거
df["주요 업무"] = df["주요 업무"].str.replace(pat=r'[\n\t\r]', repl=r'', regex=True)
df['주요 업무']

df["자격요건 및 우대사항"] = df["자격요건 및 우대사항"].str.replace(pat=r'[\n\t\r]', repl=r'', regex=True)
df['자격요건 및 우대사항']
# Out:
# 0        BI 및 ETL 관련 분야 경력 5년 이상이신 분이 필요해요 DW 데이터 모델링 ...
# 1                                                     NaN
# 2       자격 조건 SQL 상급 파이썬 중급 Data Visualization 소프트웨어Ta...
# 3        기업재무 총괄 책임자 경험 1년 이상  해당 직무 경력 10년 이상 회계법인 경험...
# 4        동종 업계 퍼포먼스CRM 마케팅 관련 경력 1년 이상 CRM 퍼널 지표 기본 개념...
#                               ...
# 5739     유관 업무 경력자 다양한 포지션의 팀원들과 소통하는 원활한 커뮤니케이션 능력 문제...
# 5740    학력  학사 이상 4년제 이상경력  경력 5년 이상상장사 공시 경험자IFRS 상장사...
# 5741     스타트업 혹은 성장하는 기업에서 스케일업 경험이 있으신 분 재무회계 경력 5년 이...
# 5742     유관 경력 5년 이상 또는 관련 자격증회계사 세무사 보유자 매출 300억 이상 외...
# 5743     경력  1년  3년 회계결산업무 경력 보유자사원주임급  더존 회계프로그램 사용 가...
# Name: 자격요건 및 우대사항, Length: 5744, dtype: object

# %%
len(df)
# Out:
# 5744

# %%
df.isnull().sum()
# Out:
# 회사명               0
# 고용 형태             0
# 스킬                0
# 기업 소개           537
# 주요 업무             3
# 자격 요건             0
# 우대 사항           413
# 채용 절차          1930
# 복리후생            455
# 회사위치             36
# 직무_lv1            0
# 직무_lv2            0
# 자격요건 및 우대사항     413
# index             0
# dtype: int64

# %%
#결측치 제거
df.dropna(subset = ['주요 업무','자격요건 및 우대사항'], inplace=True)
df
# Out:
#             회사명 고용 형태                                                 스킬  \
# 0     캐롯손해보험(주)   정규직               ['Oracle', 'BI', 'SQL', 'dw', 'etl']
# 2          잡플래닛   정규직  ['데이터분석', 'BI', 'python', 'SQL', 'Tableau', 'P...
# 3       (주)포바이포   정규직                     ['재무', '세무조사', '손익분석', '재무총괄']
# 4       (주)바이트랩   정규직                           ['마케팅', 'CRM', '프로모션기획']
# 7     (주)프레인글로벌   정규직    ['기획', '마케팅', '브랜딩', '홍보', '퍼포먼스마케팅', '커뮤니케이션']
# ...         ...   ...                                                ...
# 5739   (주)글로카로카   정규직                   ['경영지원', '회계', '세무', '경리', '자금']
# 5740    동인기연(주)   정규직               ['회계', '세무', '회계관리', '세무관리', 'IFRS']
# 5741  (주)디홀릭커머스   정규직                   ['재무', '회계', '세무', '결산', '재무제표']
# 5742     루에랑(주)   정규직                           ['재무', '회계', '세무', '결산']
# 5743  (주)슈퍼메이커즈   정규직    ['총무', '재무', '회계', '세무', '정산', '부가가치세', '자금계획']
#
#                                                   기업 소개  \
# 0     캐롯손해보험은 한화, SKT, 현대자동차, 알토스벤쳐스, 스틱인베스트먼트 등 대형 ...
# 2     더 나은 선택은 없을까?\r\n 지금 이 순간에도 잡플래닛을 방문하는 월 300만명...
# 3     “Into the NEW ERA” \r\n\r\n2017년에 설립된 주식회사 포바이...
# 4     고객들이 꾸준히 찾는 브랜드를 운영하며 미디어커머스 업계 1위를 향한 지속 가능한 ...
# 7     섬세이는 자연의 특징, 현상, 더 나아가 기능까지 제품에 담아 우리가 원할 때 원하...
# ...                                                 ...
# 5739  글로벌 호텔이 “나의 취향에 맞는 확장형 주거공간 & 업무공간”이 된다는 미션을 통...
# 5740  (주)동인기연은 1992년 창립하여 ALUMINUM TUBE 및 압출 형재를 가공하...
# 5741  세계로 뻗어가는 글로벌 이커머스 플랫폼, 디홀릭커머스에서 함께할 인재를 모십니다.\...
# 5742  [루에랑]은, #Your First Korean Food, \r\n'가장 멋진 한국...
# 5743  슈퍼키친은 슈퍼메이커즈가 2017년 설립한 HMR(가정간편식) 전문 브랜드입니다.\...
#
#                                                   주요 업무  \
# 0      캐롯 주행계약 관련 지표 생성 및 제공해요 Datawarehouse 및 Data ...
# 2      전사 Business Intelligence  Dashboard Report 개발...
# 3      재무총괄회계세무자금 연간 경영계획 수립 장기적 재무적 손익분석 및 예측 MA 업무...
# 4      신규 고객 유치 및 기존 고객 유지를 위한 프로모션 기획 및 운영 AB 테스트를 ...
# 7     섬세이 브랜드의 바운더리 및 팀원의 시야를 확장시킵니다 해외 신규 제휴처 확보 및 ...
# ...                                                 ...
# 5739                 일반 경리 회계 자금 관리 정부 프로젝트 자금 관리 경영 지원
# 5740                 회계 관리 IFRS 연결회계세무 관리세무 회계 관련 업무 전반
# 5741   결산 총괄 회계 및 세무 이슈 대응 총괄 연결별도 재무제표 작성 및 경영진 보고 ...
# 5742   자금 업무자금 운용 계획 및 수립 법인 회계 결산 및 각종 세무 신고법인세 세무조...
# 5743   더존 아이큐브 전표입력 법인카드 정산 및 관리 월 분기 연 단위 재무제표 작성 부...
#
#                                                   자격 요건  \
# 0     • BI 및 ETL 관련 분야 경력 5년 이상이신 분이 필요해요.\r\n• DW 데...
# 2     [자격 조건]\r\n• SQL 상급, 파이썬 중급\r\n• Data Visualiz...
# 3     • 기업재무 총괄 책임자 경험 1년 이상 \r\n• 해당 직무 경력 10년 이상\r...
# 4     • 동종 업계 퍼포먼스/CRM 마케팅 관련 경력 1년 이상\r\n• CRM (퍼널 ...
# 7     • 2~5년차, 학력 무관\r\n• 영어 소통하는 것에 능숙하신 분\r\n• 미국 ...
# ...                                                 ...
# 5739  • 유관 업무 경력자\r\n• 다양한 포지션의 팀원들과 소통하는 원활한 커뮤니케이션...
# 5740             ㆍ학력 : 학사 이상 (4년제 이상)\r\nㆍ경력 : 경력 5년 이상
# 5741  • 스타트업 혹은 성장하는 기업에서 스케일업 경험이 있으신 분\r\n• 재무회계 경...
# 5742  • 유관 경력 5년 이상 또는 관련 자격증(회계사, 세무사) 보유자\r\n• 매출 ...
# 5743  • 경력 : 1년 ~ 3년 회계결산업무 경력 보유자(사원~주임급) \t\t\t\t\...
#
#                                                   우대 사항  \
# 0     • BI 툴 활용 및 Hadoop에 대한 연동을 이해하신 분이면 좋아요.\r\n• ...
# 2     [우대 사항]\r\n• Statistics, Econometrics, Applied...
# 3     • 빠르게 성장하는 IT / 스타트업을 경험해보신 분\r\n• 1년 이상의 CFO ...
# 4     • 커머스 업계에서의 마케팅 경력을 보유하신 분\r\n• 커머스 브랜드에 관심과 이...
# 7                         • 해외에서 제품 및 서비스를 홍보 및 판매해보신 분
# ...                                                 ...
# 5739  • 관련 학과 전공자\r\n• 회계 관련 자격증 소지자 우대\r\n• 회계 프로그램...
# 5740  ㆍ상장사 공시 경험자\r\nㆍIFRS 상장사 감사 유경험자\r\nㆍ해외 종속법인 연...
# 5741    • E-commerce 분야에서 근무한 경험이 있으신 분\r\n• 일본어 가능하신 분
# 5742  • 루에랑의 미션, 비전에 공감하시는 분("가장 멋진 한국의 경험을 전세계 시골할머...
# 5743  • MS Office 활용 우수자 \t\t\t\t\t\t\t\t\t\r\n• 더존 ...
#
#                                                   채용 절차  \
# 0     • 해당 직무는 수시채용으로, 채용 완료 시 공고가 마감될 수 있어요.\r\n• 지...
# 2     [전형 프로세스]\r\n• 서류전형 -> 1차 실무 인터뷰 -> 2차 협업부서 인터...
# 3                                                   NaN
# 4                 📄서류전형 ▶️ 👤면접 인터뷰 ▶️ ⭐처우 협의 ▶️ 🎉 합격 발표
# 7                          서류전형 -> 면접전형 -> 처우협의 -> 최종합격
# ...                                                 ...
# 5739                                                NaN
# 5740                                                NaN
# 5741                                                NaN
# 5742                                                NaN
# 5743                                                NaN
#
#                                                    복리후생  \
# 0     [성장을 위한 휴식]\r\n• 매년 복지포인트 200만원\r\n• 설 차례비 지급\...
# 2      - 분 단위 시차 출퇴근제 (오전 7시~ 오전 10시 사이 자율 출퇴근)\r\n ...
# 3     [근무환경]\r\n- 월요일 출근 1pm - 퇴근 7pm  (화~금 10am-7pm...
# 4     • 조식 제공 (주 1회)\r\n• 리프레시 휴가\r\n• 시차출퇴근제\r\n• 자...
# 7     • 기본 복리후생 (4대 보험 가입, 퇴직금, 경조금 지급, 연차 및 휴가 지급)\...
# ...                                                 ...
# 5739  ㆍ워케이션 1달 살기 지원\r\nㆍ모두 건강한 생활! 전직원 정밀 건강검진\r\nㆍ...
# 5740  • 경조사 지원\r\n• 동호회 지원\r\n• 유류비 지원\r\n• 연 1회 1주간...
# 5741  • 최고급 장비 및 소프트웨어 제공\r\n• 업무 참고 도서 및 개발 서적 제공\r...
# 5742  ▷기본 복지\r\n• 젊은 식품회사, 평균나이 29세 \r\n• 영어 이름과 직급 ...
# 5743  • 경조휴가 및 경조사비 지원\r\n• 스낵바 운영(과자, 음료, 주류 등등)\r\...
#
#                                    회사위치        직무_lv1  \
# 0     서울 중구 을지로100 파인에비뉴 B동 20층, 캐롯손해보험       ['데이터']
# 2        서울특별시 강남구 테헤란로 509 엔씨타워 I, 10층       ['데이터']
# 3          서울 서초구 강남대로 479, 12층,13층,14층     ['기획/경영']
# 4                서울 강남구 테헤란로108길 25, 4층  ['마케팅/시장조사']
# 7                서울 중구 칠패로 37, 12층, 14층  ['마케팅/시장조사']
# ...                                 ...           ...
# 5739              서울 서초구 강남대로30길 17, 3층     ['금융/재무']
# 5740             경기 김포시 통진읍 대곶북로 370-26     ['금융/재무']
# 5741          서울시 중구 세종대로39 대한상공회의소 11층     ['금융/재무']
# 5742              서울 서초구 강남대로 27, 1306호     ['금융/재무']
# 5743               경기도 부천시 원미로 246(춘의동)     ['금융/재무']
#
#                                  직무_lv2  \
# 0                           ['BI 엔지니어']
# 2                           ['BI 엔지니어']
# 3     ['CEO (Chief Executive Officer)']
# 4                               ['CRM']
# 7           ['CRM', '마케팅', '마케팅커뮤니케이션']
# ...                                 ...
# 5739                            ['회계사']
# 5740                            ['회계사']
# 5741                            ['회계사']
# 5742                            ['회계사']
# 5743                            ['회계사']
#
#                                             자격요건 및 우대사항  index
# 0      BI 및 ETL 관련 분야 경력 5년 이상이신 분이 필요해요 DW 데이터 모델링 ...      0
# 2     자격 조건 SQL 상급 파이썬 중급 Data Visualization 소프트웨어Ta...      2
# 3      기업재무 총괄 책임자 경험 1년 이상  해당 직무 경력 10년 이상 회계법인 경험...      3
# 4      동종 업계 퍼포먼스CRM 마케팅 관련 경력 1년 이상 CRM 퍼널 지표 기본 개념...      4
# 7      25년차 학력 무관 영어 소통하는 것에 능숙하신 분 미국 시장에 대한 이해도가 높...      7
# ...                                                 ...    ...
# 5739   유관 업무 경력자 다양한 포지션의 팀원들과 소통하는 원활한 커뮤니케이션 능력 문제...   5739
# 5740  학력  학사 이상 4년제 이상경력  경력 5년 이상상장사 공시 경험자IFRS 상장사...   5740
# 5741   스타트업 혹은 성장하는 기업에서 스케일업 경험이 있으신 분 재무회계 경력 5년 이...   5741
# 5742   유관 경력 5년 이상 또는 관련 자격증회계사 세무사 보유자 매출 300억 이상 외...   5742
# 5743   경력  1년  3년 회계결산업무 경력 보유자사원주임급  더존 회계프로그램 사용 가...   5743
#
# [5328 rows x 14 columns]

# %%
len(df)
# Out:
# 5328

# %%
#csv로 저장
df.to_csv(".//preprocessed_gongo_final.csv",index = False, encoding='utf-8')
