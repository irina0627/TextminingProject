# %% [markdown]
# ## [텍스트마이닝] 잡플래닛 기업 리뷰, 공고 데이터 합치기

# %%
#-*- coding:utf-8-sig -*-

# %%
import os
import pandas as pd

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/dataset/jobplanet_data_-120~-30.zip' -d '/content/drive/MyDrive/Colab Notebooks/dataset'

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/dataset/jobplanet_data_-30~.zip' -d '/content/drive/MyDrive/Colab Notebooks/dataset'

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/dataset/데이터.zip' -d '/content/drive/MyDrive/Colab Notebooks/dataset'

# %%
# total # of job categories
folder_path = "C:/Users/Andlab/jupyter_study/TextminingProject/crawling code/dataset"
file_list = os.listdir(folder_path)
file_count = len(file_list)
print(file_count)
# Out:
# 158

# %%
# check
# os.listdir('/content/drive/MyDrive/Colab Notebooks/dataset')

# %%
filenames = os.listdir(folder_path)
count_gongo = 0
count_review = 0

gongo_list = []
review_list = []

for filename in filenames:
  jobname, datatype = filename.strip('.csv').split('_')
  count_gongo+=1
  gongo_list.append(filename)
  # if datatype == '공고':
  #   count_gongo+=1
  #   gongo_list.append(filename)
  # elif datatype == '리뷰':
  #   count_review+=1
  #   review_list.append(filename)
print(count_gongo)
print(count_review)
# Out:
# 158
# 0

# %% [markdown]
# ## 공고 데이터프레임 합치기

# %%
gongo_df = pd.DataFrame()
for gongo in gongo_list:
  df = pd.read_csv(folder_path+'/'+gongo)
  # df['직종']=gongo.strip('.csv').split('_')[0]
  # print(gongo,"----",len(df))
  gongo_df = pd.concat([gongo_df, df])
print(len(gongo_df))
# Out:
# 5744

# %%
gongo_df.to_csv('C:/Users/Andlab/jupyter_study/TextminingProject/concatdataset/gongo_df.csv', index=False, encoding="utf-8-sig")

# %%
gongo_df
# Out:
#           회사명 고용 형태                                                 스킬  \
# 0   캐롯손해보험(주)   정규직               ['Oracle', 'BI', 'SQL', 'dw', 'etl']
# 1       (주)웅진   정규직                                       ['POWER BI']
# 2        잡플래닛   정규직  ['데이터분석', 'BI', 'python', 'SQL', 'Tableau', 'P...
# 0     (주)포바이포   정규직                     ['재무', '세무조사', '손익분석', '재무총괄']
# 0     (주)바이트랩   정규직                           ['마케팅', 'CRM', '프로모션기획']
# ..        ...   ...                                                ...
# 27   (주)글로카로카   정규직                   ['경영지원', '회계', '세무', '경리', '자금']
# 28    동인기연(주)   정규직               ['회계', '세무', '회계관리', '세무관리', 'IFRS']
# 29  (주)디홀릭커머스   정규직                   ['재무', '회계', '세무', '결산', '재무제표']
# 30     루에랑(주)   정규직                           ['재무', '회계', '세무', '결산']
# 31  (주)슈퍼메이커즈   정규직    ['총무', '재무', '회계', '세무', '정산', '부가가치세', '자금계획']
#
#                                                 기업 소개  \
# 0   캐롯손해보험은 한화, SKT, 현대자동차, 알토스벤쳐스, 스틱인베스트먼트 등 대형 ...
# 1                                                 NaN
# 2   더 나은 선택은 없을까?\r\n 지금 이 순간에도 잡플래닛을 방문하는 월 300만명...
# 0   “Into the NEW ERA” \r\n\r\n2017년에 설립된 주식회사 포바이...
# 0   고객들이 꾸준히 찾는 브랜드를 운영하며 미디어커머스 업계 1위를 향한 지속 가능한 ...
# ..                                                ...
# 27  글로벌 호텔이 “나의 취향에 맞는 확장형 주거공간 & 업무공간”이 된다는 미션을 통...
# 28  (주)동인기연은 1992년 창립하여 ALUMINUM TUBE 및 압출 형재를 가공하...
# 29  세계로 뻗어가는 글로벌 이커머스 플랫폼, 디홀릭커머스에서 함께할 인재를 모십니다.\...
# 30  [루에랑]은, #Your First Korean Food, \r\n'가장 멋진 한국...
# 31  슈퍼키친은 슈퍼메이커즈가 2017년 설립한 HMR(가정간편식) 전문 브랜드입니다.\...
#
#                                                 주요 업무  \
# 0   • 캐롯 주행/계약 관련 지표 생성 및 제공해요.\r\n• Data-warehous...
# 1   - MS Power Platform 프로젝트 수행 및 기술지원 (Automate, ...
# 2   [조직소개]\r\n잡플래닛의 데이터 조직은 Data 1st전략으로 서비스의 핵심 자...
# 0   • 재무총괄(회계/세무/자금)\r\n• 연간 경영계획 수립\r\n• 장기적 재무적 ...
# 0   • 신규 고객 유치 및 기존 고객 유지를 위한 프로모션 기획 및 운영\r\n• A/...
# ..                                                ...
# 27   • 일반 경리, 회계, 자금 관리\r\n• 정부 프로젝트 자금 관리\r\n• 경영 지원
# 28  ㆍ회계 관리 (IFRS, 연결회계)\r\nㆍ세무 관리\r\nㆍ세무, 회계 관련 업무 전반
# 29  • 결산 총괄\r\n• 회계 및 세무 이슈 대응 총괄\r\n• 연결/별도 재무제표 ...
# 30  • 자금 업무(자금 운용 계획 및 수립)\r\n• 법인 회계 결산 및 각종 세무 신...
# 31  • 더존 아이큐브 전표입력\t\t\t\t\t\t\t\t\t\r\n• 법인카드 정산 ...
#
#                                                 자격 요건  \
# 0   • BI 및 ETL 관련 분야 경력 5년 이상이신 분이 필요해요.\r\n• DW 데...
# 1   【지원자격】 \n - 모집직급: 대리~과장 \n - MS Power Platform...
# 2   [자격 조건]\r\n• SQL 상급, 파이썬 중급\r\n• Data Visualiz...
# 0   • 기업재무 총괄 책임자 경험 1년 이상 \r\n• 해당 직무 경력 10년 이상\r...
# 0   • 동종 업계 퍼포먼스/CRM 마케팅 관련 경력 1년 이상\r\n• CRM (퍼널 ...
# ..                                                ...
# 27  • 유관 업무 경력자\r\n• 다양한 포지션의 팀원들과 소통하는 원활한 커뮤니케이션...
# 28             ㆍ학력 : 학사 이상 (4년제 이상)\r\nㆍ경력 : 경력 5년 이상
# 29  • 스타트업 혹은 성장하는 기업에서 스케일업 경험이 있으신 분\r\n• 재무회계 경...
# 30  • 유관 경력 5년 이상 또는 관련 자격증(회계사, 세무사) 보유자\r\n• 매출 ...
# 31  • 경력 : 1년 ~ 3년 회계결산업무 경력 보유자(사원~주임급) \t\t\t\t\...
#
#                                                 우대 사항  \
# 0   • BI 툴 활용 및 Hadoop에 대한 연동을 이해하신 분이면 좋아요.\r\n• ...
# 1                                                 NaN
# 2   [우대 사항]\r\n• Statistics, Econometrics, Applied...
# 0   • 빠르게 성장하는 IT / 스타트업을 경험해보신 분\r\n• 1년 이상의 CFO ...
# 0   • 커머스 업계에서의 마케팅 경력을 보유하신 분\r\n• 커머스 브랜드에 관심과 이...
# ..                                                ...
# 27  • 관련 학과 전공자\r\n• 회계 관련 자격증 소지자 우대\r\n• 회계 프로그램...
# 28  ㆍ상장사 공시 경험자\r\nㆍIFRS 상장사 감사 유경험자\r\nㆍ해외 종속법인 연...
# 29    • E-commerce 분야에서 근무한 경험이 있으신 분\r\n• 일본어 가능하신 분
# 30  • 루에랑의 미션, 비전에 공감하시는 분("가장 멋진 한국의 경험을 전세계 시골할머...
# 31  • MS Office 활용 우수자 \t\t\t\t\t\t\t\t\t\r\n• 더존 ...
#
#                                                 채용 절차  \
# 0   • 해당 직무는 수시채용으로, 채용 완료 시 공고가 마감될 수 있어요.\r\n• 지...
# 1                                                 NaN
# 2   [전형 프로세스]\r\n• 서류전형 -> 1차 실무 인터뷰 -> 2차 협업부서 인터...
# 0                                                 NaN
# 0               📄서류전형 ▶️ 👤면접 인터뷰 ▶️ ⭐처우 협의 ▶️ 🎉 합격 발표
# ..                                                ...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                                  복리후생  \
# 0   [성장을 위한 휴식]\r\n• 매년 복지포인트 200만원\r\n• 설 차례비 지급\...
# 1                                                 NaN
# 2    - 분 단위 시차 출퇴근제 (오전 7시~ 오전 10시 사이 자율 출퇴근)\r\n ...
# 0   [근무환경]\r\n- 월요일 출근 1pm - 퇴근 7pm  (화~금 10am-7pm...
# 0   • 조식 제공 (주 1회)\r\n• 리프레시 휴가\r\n• 시차출퇴근제\r\n• 자...
# ..                                                ...
# 27  ㆍ워케이션 1달 살기 지원\r\nㆍ모두 건강한 생활! 전직원 정밀 건강검진\r\nㆍ...
# 28  • 경조사 지원\r\n• 동호회 지원\r\n• 유류비 지원\r\n• 연 1회 1주간...
# 29  • 최고급 장비 및 소프트웨어 제공\r\n• 업무 참고 도서 및 개발 서적 제공\r...
# 30  ▷기본 복지\r\n• 젊은 식품회사, 평균나이 29세 \r\n• 영어 이름과 직급 ...
# 31  • 경조휴가 및 경조사비 지원\r\n• 스낵바 운영(과자, 음료, 주류 등등)\r\...
#
#                                  회사위치                           직무(복수선택)  \
# 0   서울 중구 을지로100 파인에비뉴 B동 20층, 캐롯손해보험                        ['BI 엔지니어']
# 1                       서울 중구 청계천로 24             ['클라우드 개발', 'BI 엔지니어']
# 2      서울특별시 강남구 테헤란로 509 엔씨타워 I, 10층                        ['BI 엔지니어']
# 0        서울 서초구 강남대로 479, 12층,13층,14층  ['CEO (Chief Executive Officer)']
# 0              서울 강남구 테헤란로108길 25, 4층                            ['CRM']
# ..                                ...                                ...
# 27              서울 서초구 강남대로30길 17, 3층                            ['회계사']
# 28             경기 김포시 통진읍 대곶북로 370-26                            ['회계사']
# 29          서울시 중구 세종대로39 대한상공회의소 11층                            ['회계사']
# 30              서울 서초구 강남대로 27, 1306호                            ['회계사']
# 31               경기도 부천시 원미로 246(춘의동)                            ['회계사']
#
#            직무_lv1                             직무_lv2
# 0         ['데이터']                        ['BI 엔지니어']
# 1   ['개발', '데이터']             ['클라우드 개발', 'BI 엔지니어']
# 2         ['데이터']                        ['BI 엔지니어']
# 0       ['기획/경영']  ['CEO (Chief Executive Officer)']
# 0    ['마케팅/시장조사']                            ['CRM']
# ..            ...                                ...
# 27      ['금융/재무']                            ['회계사']
# 28      ['금융/재무']                            ['회계사']
# 29      ['금융/재무']                            ['회계사']
# 30      ['금융/재무']                            ['회계사']
# 31      ['금융/재무']                            ['회계사']
#
# [5744 rows x 13 columns]

# %% [markdown]
# ### 리뷰 데이터프레임 합치기

# %%
review_df = pd.DataFrame()
for review in review_list:
  df = pd.read_csv(folder_path+'/'+review)
  df['직종']=gongo.strip('.csv').split('_')[0]
  # print(review,"----",len(df))
  review_df = pd.concat([review_df, df])
print(len(review_df))
# Out:
# 515741

# %%
review_df.to_csv('/content/drive/MyDrive/Colab Notebooks/result/review_df.csv', index=False, encoding="utf-8-sig")

# %%
review_df
# Out:
#            날짜     직무     고용 현황   별점  \
# 0          서울    NaN  마케팅/시장조사  5.0
# 1          서울    NaN        개발  5.0
# 2          서울    NaN     영업/제휴  5.0
# 3          서울    NaN     영업/제휴  5.0
# 4    2023. 07  기획/경영       전직원  4.0
# ..        ...    ...       ...  ...
# 124  2018. 04   연구개발       전직원  2.0
# 125  2017. 09   연구개발       전직원  2.0
# 126  2016. 05   연구개발       전직원  1.0
# 127  2015. 09   연구개발       현직원  2.0
# 128  2014. 04     기타       현직원  3.0
#
#                                                     요약  \
# 0    "좋은회사 라는 말이 어울리는 곳. 똑똑하고 선한 사람들과 함께 열심히 일하고 성장...
# 1                            "회사가 너무 좋아서 좋다는걸 널리 알리고픔"
# 2                       "전체적으로 훌륭함. 기업 문화, 분위기 모두 좋음."
# 3                       "왜 잡플 평점이 높은지 알 수 있었음. 분위기 최고"
# 4                             "젊은 사람들이 많은 편하고 자유로운 회사"
# ..                                                 ...
# 124  "제대로된 회사에서 일했던 개발자라면 얼마안있어 멘붕을 맛볼수있는 개발구조이다. 한...
# 125  "덴탈 종합 스캔 서비스를 제공하려는 회사입니다\r국내보다는 해외에 중점을 두고 있...
# 126  "조금만 다녀보면 보여지는 모습과 얼마나 다른지 알수있다.\r혹시 입사를 하고자 하...
# 127              "다양한 일을 접해볼 수 있다. 스스로 성장하는 인재를 선호한다."
# 128                                      "기회를 제공한 회사다"
#
#                                                     장점  \
# 0    \n좋은 사람들과 함께 좋은 서비스를 만들어 나간다는 자부심을 갖고 일할 수 있다....
# 1    \n행복하게 일하면서 내 일에 책임감과 오너십을 가지고 뛰어난 사람들과 자유롭게 일...
# 2    \n연차 자유롭게 쓸 수 있음. 문화가 매우 영함. 자유로운 분위기라서 대다수가 매...
# 3    \n스타트업치고 규모가 크다, 구성원이 인턴제외 한 30명 정도. \r사무실 위치도...
# 4    \n복지, 급여, 사내문화 등 측면에서 직원들에게 잘해주려 함\r사무실이 넓고 쾌적...
# ..                                                 ...
# 124  \n연차쓰는게 자유로운편. 그외 분위기 자체가 약간 프리한편. 사내 카페가 있어서 ...
# 125  \n연차 사용이 자유로운 편이고 사내카페가 있어 무료커피가 제공됩니다\r안암 지하철...
# 126  \n매출은 나온다.\r중소기업치고 연봉도 높은편.\r기업 평점이 무려 3점대. (회...
# 127  \n대부분의 제품을 수출하는 회사로 경쟁력이 있다.\r경기를 적게타는 편이라고 알고...
# 128                                        \n자유로운 복장\n
#
#                                                     단점  \
# 0                \n어린 조직이기 때문에 스스로 만들어나가야 하는 부분이 많다.\n
# 1    \n다들 너무 어리고 경험이 부족한 조직이라 믿고 따를 롤모델이 필요하다면 맞지 않...
# 2    \n딱히 없는듯함. 굳이 찾자면 사무실이 오픈형이라는 점? 라운지에서 업무봐도 돼서...
# 3    \n아무래도 스타트업이다 보니 살짝 체계가 부족하다. 그때 그때 주먹구구식으로 흘러...
# 4    \n경영진이 의사결정을 할 때 데이터보다 직관에 기반한 판단을 많이 함\r회사 분위...
# ..                                                 ...
# 124  \n일단 개발자 입장에서 어마어마한 스트레스를 받는다. 일정은 나와있는데 설계된 것...
# 125  \n1. 야근 강요\r요즘같은 시대에 대놓고 야근을 강요합니다. 야근의 수준도 9시...
# 126  \n경영진 말이 대부분이 거짓이다.\r오랜기간 재직한 직원들은 사장의 라인이거나 무...
# 127  \n기업관리가 체계적이지 못하고 편파적인 부분이 있어서 관리 누수가 있다.\r보여지...
# 128                                          \n일이 많다\n
#
#                                            경영진에게 바라는 점            직종
# 0         \n지금처럼 구성원들에게 건강한 동기부여를 하면서 성장해나갔으면 좋겠습니다.\n  특허변리사
# 1                       \n충분히 잘해주고 계셔서 바라는 점은 별로 없다.\n  특허변리사
# 2        \n이거 또한 딱히 없음. 얘기도 잘 들어주고 지원도 꽤 해주는편이라 만족함.\n  특허변리사
# 3    \n지금처럼 경영하신다면 분명 앞으로 사업도 점차 성장할 수 있으리라 생각합니다. ...  특허변리사
# 4                       \n데이터에 기반한 의사결정이 많아졌으면 좋겠습니다\n  특허변리사
# ..                                                 ...           ...
# 124  \n언제까지 주먹구구식으로 제품개발 및 서비스를 진행할 것인지 모르겠다. 직원 평가...  특허변리사
# 125  \n직원들에 대해 평등한 기회와 조건으로 대하세요\r학벌 기존 회사 출신으로 편가르...  특허변리사
# 126  \n어차피 안바뀔거 안다. 그래도 적자면\r젠틀한척 스마트한척 이제 그만\r알사람은...  특허변리사
# 127  \n인간을 중심으로 하는 경영이 필요하며, 권한과 책임을 적절히 부여하여야 하고 문...  특허변리사
# 128                                               \n\n  특허변리사
#
# [515741 rows x 9 columns]
