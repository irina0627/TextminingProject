# %% [markdown]
# ## [텍스트마이닝] 잡플래닛 기업 리뷰, 공고 데이터 합치기

# %%
#-*- coding:utf-8-sig -*-

# %%
import os
import pandas as pd

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/dataset/jobplanet_data_-120~-30.zip' -d '/content/drive/MyDrive/Colab Notebooks/dataset'

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/dataset/jobplanet_data_-30~.zip' -d '/content/drive/MyDrive/Colab Notebooks/dataset'

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/dataset/데이터.zip' -d '/content/drive/MyDrive/Colab Notebooks/dataset'

# %%
# total # of job categories
folder_path = "/content/drive/MyDrive/Colab Notebooks/dataset"
file_list = os.listdir(folder_path)
file_count = len(file_list)
print(file_count)
# Out:
# 312

# %%
# check
# os.listdir('/content/drive/MyDrive/Colab Notebooks/dataset')

# %%
filenames = os.listdir(folder_path)
count_gongo = 0
count_review = 0

gongo_list = []
review_list = []

for filename in filenames:
  jobname, datatype = filename.strip('.csv').split('_')
  if datatype == '공고':
    count_gongo+=1
    gongo_list.append(filename)
  elif datatype == '리뷰':
    count_review+=1
    review_list.append(filename)
print(count_gongo)
print(count_review)
# Out:
# 157
# 155

# %%
for gongo in gongo_list[:10]:
  print(gongo.strip('.csv').split('_')[0])
# Out:
# CEO (Chief Executive Officer)
# COO (Chief Operation Officer)
# CRM
# CTO (Chief Technology Officer)
# DBA(Database Admin.)
# ERP
# iOS 개발
# IT솔루션영업
# 판매매장관리
# 패션섬유디자인

# %% [markdown]
# ## 공고 데이터프레임 합치기

# %%
gongo_df = pd.DataFrame()
for gongo in gongo_list:
  df = pd.read_csv(folder_path+'/'+gongo)
  df['직종']=gongo.strip('.csv').split('_')[0]
  # print(gongo,"----",len(df))
  gongo_df = pd.concat([gongo_df, df])
print(len(gongo_df))
# Out:
# 7052

# %%
gongo_df.to_csv('/content/drive/MyDrive/Colab Notebooks/result/gongo_df.csv', index=False, encoding="utf-8-sig")

# %%
gongo_df
# Out:
#          회사명                                              주요 업무  \
# 0     (주)코드잇                   ★ 2023 코드잇 인재 채용: 전 직군 스톡옵션 제공 ★
# 1    (주)포바이포  “Into the NEW ERA” \r\n\r\n2017년에 설립된 주식회사 포바이...
# 2     (주)코드잇                   ★ 2023 코드잇 인재 채용: 전 직군 스톡옵션 제공 ★
# 3    (주)포바이포  “Into the NEW ERA” \r\n\r\n2017년에 설립된 주식회사 포바이...
# 0   (주)데이터뱅크  고액의 1:1 과외 대신 AI 채점기가 나의 영어 스피킹, 라이팅을 실시간으로, 스...
# ..       ...                                                ...
# 3   (주)길교이앤씨                            (주)길교이앤씨 설계팀 경력 (대리~차장)
# 4   (주)길교이앤씨                                  길교이앤씨 기술연구소 경력 채용
# 0     (주)딥엑스  딥엑스는 NPU 설계 원천기술을 보유하고 있으며 현재 공격적으로 원천기술을 권리화 ...
# 1     (주)티오더                                                NaN
# 2     (주)메디트  Fulfill Your Potential!\r\n\r\n메디트(Medit)에서 글로...
#
#                                                 자격 요건  \
# 0   • 배움과 성장의 기쁨을 알리고자 하는 코드잇의 비전에 공감하고 사업 분야에 대한 ...
# 1   • 기업재무 총괄 책임자 경험 1년 이상 \r\n• 해당 직무 경력 10년 이상\r...
# 2   • 배움과 성장의 기쁨을 알리고자 하는 코드잇의 비전에 공감하고 사업 분야에 대한 ...
# 3   • 기업재무 총괄 책임자 경험 1년 이상 \r\n• 해당 직무 경력 10년 이상\r...
# 0   • 글로벌 서비스 기획/제작 및 출시까지 성공적인 프로젝트를 리딩한 경험이 있으신 ...
# ..                                                ...
# 3   • 학력 : 전문대졸 이상\r\n• 직무관련 전공자 (토목공학 및 구조공학)\r\n...
# 4   • 학력 : 대졸 이상\r\n• 전공 : 토목공학 및 구조공학\r\n• 경력 : 1...
# 0   • 컴퓨터구조, 컴퓨터하드웨어, ASIC, SoC, 메모리시스템, 디지털하드웨어 관...
# 1   • 업무 유관경력 있으신 분(2~5년)\n• 특허명세서 작성 및 검토 업무 경험이 ...
# 2   • 특허 명세서 작성 및 검토 업무 경력\r\n• 공과 대학 졸업 및 관련 전공자\...
#
#                                                 채용 절차  \
# 0   【 이렇게 합류하게 돼요 】\r\n1. 서류 접수  2. 사전 과제  3. 인터뷰 ...
# 1                                                 NaN
# 2   【 이렇게 합류하게 돼요 】\r\n1. 서류 접수  2. 사전 과제  3. 인터뷰 ...
# 3                                                 NaN
# 0   1. 이력서 검토\r\n2. 캐주얼 티타임\r\n3. 인터뷰\r\n4. 계약 체결\...
# ..                                                ...
# 3                                                 NaN
# 4                                                 NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                             서류 심사 -> 1차 면접 -> 2차 면접
#
#                                                  복리후생  \
# 0   1. 최고의 팀원에게 최고의 보상을 제공해요.\r\n• 최고의 동료들이 모인 팀\r...
# 1   [근무환경]\r\n- 월요일 출근 1pm - 퇴근 7pm  (화~금 10am-7pm...
# 2   1. 최고의 팀원에게 최고의 보상을 제공해요.\r\n• 최고의 동료들이 모인 팀\r...
# 3   [근무환경]\r\n- 월요일 출근 1pm - 퇴근 7pm  (화~금 10am-7pm...
# 0   • 유연근무제 운영 (오전 8시 ~ 오후 1시 사이 자유로운 출퇴근)\r\n• 주 ...
# ..                                                ...
# 3   • 장기근속자 포상\r\n• 구내식당 (전액 회사부담)\r\n• 우수사원 시상\r\...
# 4   • 장기근속자 포상\r\n• 구내식당 (전액 회사부담)\r\n• 우수사원 시상\r\...
# 0   • 4대보험 (국민연금, 건강보험, 산재보험, 고용보험) 가입\r\n• 업무Tool...
# 1                                                 NaN
# 2   [복지]\r\n1. 근무 환경\r\n- 유연근무제\r\n- 수평적인 호칭 체계\r\...
#
#                                       회사위치                             직종
# 0      서울특별시 중구 청계천로 100 시그니처타워 동관 10층 코드잇  CEO (Chief Executive Officer)
# 1             서울 서초구 강남대로 479, 12층,13층,14층  CEO (Chief Executive Officer)
# 2      서울특별시 중구 청계천로 100 시그니처타워 동관 10층 코드잇  CEO (Chief Executive Officer)
# 3             서울 서초구 강남대로 479, 12층,13층,14층  CEO (Chief Executive Officer)
# 0                 서울특별시 강남구 테헤란로86길 12, 2층  COO (Chief Operation Officer)
# ..                                     ...                            ...
# 3                        경북 포항시 남구 철강로 306                     토목설계
# 4                        경북 포항시 남구 철강로 306                     토목설계
# 0   경기도 성남시 분당구 판교역로 241번길 20, 미래에셋벤쳐타워 5F                   특허변리사
# 1            서울시 영등포구 여의대로 108, 파크원타워2 46층                   특허변리사
# 2                      서울특별시 영등포구 양평로25길 8                   특허변리사
#
# [7052 rows x 7 columns]

# %% [markdown]
# ### 리뷰 데이터프레임 합치기

# %%
review_df = pd.DataFrame()
for review in review_list:
  df = pd.read_csv(folder_path+'/'+review)
  df['직종']=gongo.strip('.csv').split('_')[0]
  # print(review,"----",len(df))
  review_df = pd.concat([review_df, df])
print(len(review_df))
# Out:
# 515741

# %%
review_df.to_csv('/content/drive/MyDrive/Colab Notebooks/result/review_df.csv', index=False, encoding="utf-8-sig")

# %%
review_df
# Out:
#            날짜     직무     고용 현황   별점  \
# 0          서울    NaN  마케팅/시장조사  5.0
# 1          서울    NaN        개발  5.0
# 2          서울    NaN     영업/제휴  5.0
# 3          서울    NaN     영업/제휴  5.0
# 4    2023. 07  기획/경영       전직원  4.0
# ..        ...    ...       ...  ...
# 124  2018. 04   연구개발       전직원  2.0
# 125  2017. 09   연구개발       전직원  2.0
# 126  2016. 05   연구개발       전직원  1.0
# 127  2015. 09   연구개발       현직원  2.0
# 128  2014. 04     기타       현직원  3.0
#
#                                                     요약  \
# 0    "좋은회사 라는 말이 어울리는 곳. 똑똑하고 선한 사람들과 함께 열심히 일하고 성장...
# 1                            "회사가 너무 좋아서 좋다는걸 널리 알리고픔"
# 2                       "전체적으로 훌륭함. 기업 문화, 분위기 모두 좋음."
# 3                       "왜 잡플 평점이 높은지 알 수 있었음. 분위기 최고"
# 4                             "젊은 사람들이 많은 편하고 자유로운 회사"
# ..                                                 ...
# 124  "제대로된 회사에서 일했던 개발자라면 얼마안있어 멘붕을 맛볼수있는 개발구조이다. 한...
# 125  "덴탈 종합 스캔 서비스를 제공하려는 회사입니다\r국내보다는 해외에 중점을 두고 있...
# 126  "조금만 다녀보면 보여지는 모습과 얼마나 다른지 알수있다.\r혹시 입사를 하고자 하...
# 127              "다양한 일을 접해볼 수 있다. 스스로 성장하는 인재를 선호한다."
# 128                                      "기회를 제공한 회사다"
#
#                                                     장점  \
# 0    \n좋은 사람들과 함께 좋은 서비스를 만들어 나간다는 자부심을 갖고 일할 수 있다....
# 1    \n행복하게 일하면서 내 일에 책임감과 오너십을 가지고 뛰어난 사람들과 자유롭게 일...
# 2    \n연차 자유롭게 쓸 수 있음. 문화가 매우 영함. 자유로운 분위기라서 대다수가 매...
# 3    \n스타트업치고 규모가 크다, 구성원이 인턴제외 한 30명 정도. \r사무실 위치도...
# 4    \n복지, 급여, 사내문화 등 측면에서 직원들에게 잘해주려 함\r사무실이 넓고 쾌적...
# ..                                                 ...
# 124  \n연차쓰는게 자유로운편. 그외 분위기 자체가 약간 프리한편. 사내 카페가 있어서 ...
# 125  \n연차 사용이 자유로운 편이고 사내카페가 있어 무료커피가 제공됩니다\r안암 지하철...
# 126  \n매출은 나온다.\r중소기업치고 연봉도 높은편.\r기업 평점이 무려 3점대. (회...
# 127  \n대부분의 제품을 수출하는 회사로 경쟁력이 있다.\r경기를 적게타는 편이라고 알고...
# 128                                        \n자유로운 복장\n
#
#                                                     단점  \
# 0                \n어린 조직이기 때문에 스스로 만들어나가야 하는 부분이 많다.\n
# 1    \n다들 너무 어리고 경험이 부족한 조직이라 믿고 따를 롤모델이 필요하다면 맞지 않...
# 2    \n딱히 없는듯함. 굳이 찾자면 사무실이 오픈형이라는 점? 라운지에서 업무봐도 돼서...
# 3    \n아무래도 스타트업이다 보니 살짝 체계가 부족하다. 그때 그때 주먹구구식으로 흘러...
# 4    \n경영진이 의사결정을 할 때 데이터보다 직관에 기반한 판단을 많이 함\r회사 분위...
# ..                                                 ...
# 124  \n일단 개발자 입장에서 어마어마한 스트레스를 받는다. 일정은 나와있는데 설계된 것...
# 125  \n1. 야근 강요\r요즘같은 시대에 대놓고 야근을 강요합니다. 야근의 수준도 9시...
# 126  \n경영진 말이 대부분이 거짓이다.\r오랜기간 재직한 직원들은 사장의 라인이거나 무...
# 127  \n기업관리가 체계적이지 못하고 편파적인 부분이 있어서 관리 누수가 있다.\r보여지...
# 128                                          \n일이 많다\n
#
#                                            경영진에게 바라는 점            직종
# 0         \n지금처럼 구성원들에게 건강한 동기부여를 하면서 성장해나갔으면 좋겠습니다.\n  특허변리사
# 1                       \n충분히 잘해주고 계셔서 바라는 점은 별로 없다.\n  특허변리사
# 2        \n이거 또한 딱히 없음. 얘기도 잘 들어주고 지원도 꽤 해주는편이라 만족함.\n  특허변리사
# 3    \n지금처럼 경영하신다면 분명 앞으로 사업도 점차 성장할 수 있으리라 생각합니다. ...  특허변리사
# 4                       \n데이터에 기반한 의사결정이 많아졌으면 좋겠습니다\n  특허변리사
# ..                                                 ...           ...
# 124  \n언제까지 주먹구구식으로 제품개발 및 서비스를 진행할 것인지 모르겠다. 직원 평가...  특허변리사
# 125  \n직원들에 대해 평등한 기회와 조건으로 대하세요\r학벌 기존 회사 출신으로 편가르...  특허변리사
# 126  \n어차피 안바뀔거 안다. 그래도 적자면\r젠틀한척 스마트한척 이제 그만\r알사람은...  특허변리사
# 127  \n인간을 중심으로 하는 경영이 필요하며, 권한과 책임을 적절히 부여하여야 하고 문...  특허변리사
# 128                                               \n\n  특허변리사
#
# [515741 rows x 9 columns]
